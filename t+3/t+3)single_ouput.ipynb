# %% [markdown]
# ### Import related package

# %%
## Import tensorflow package for modeling
import torch
from torch.autograd import Variable
import torch.optim as optim

## Data processing
import pandas as pd
import numpy as np

## Min-max normalization
from sklearn.preprocessing import MinMaxScaler

## Plot the graph
import matplotlib.pyplot as plt
# %matplotlib inline

## Initializing module
from sklearn.linear_model import LinearRegression
np.set_printoptions(suppress=True)

## Copy module
import copy

## Used to calculate the training time
import time

## Set the GUP environment
import os
import sys

from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker

# %%
os.chdir('/home/Oring-AI/Model_I/DINKLE/t+3')

# %%
## Set up the display
torch.set_printoptions(sci_mode=False)

# %% [markdown]
# ### Control memory usage space for GPU

# %%
## 查詢有無可用 GPU
torch.cuda.is_available()
## 查詢可用 GPU 的數量
torch.cuda.device_count()
##目前設備
print("目前設備：",torch.cuda.current_device())
## 目前設備名
print("目前設備名：",torch.cuda.get_device_name(0))
# Out:
# 目前設備： 0
# 目前設備名： GeForce GTX 1070 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# ## Print out some info

# %%
def accuracy_cacl(pred_value, actual_value):
    
#     yo, loss, tape = network.forward()
    performance = []
    performance.append(torch.mean(torch.abs(pred_value - actual_value)))
    performance.append(torch.std(torch.abs(pred_value - actual_value)))
    performance.append(torch.mean(torch.abs((pred_value - actual_value) / actual_value))) 
    performance.append(torch.sqrt(torch.mean((pred_value - actual_value)**2)))
    
    for i in range(2000,3001,1000):
        correct_times = torch.nonzero(torch.abs(pred_value - actual_value) <= i, as_tuple =False)
        accuracy = correct_times.shape[0]/pred_value.shape[0]
        performance.append(accuracy)
                       
    return performance

# %%
def plot_result(name, pred_value, actual_value,block_index):
    
#     fig, ax = plt.subplots(2,2,figsize=(20,10), sharex=True, sharey=True)
    fig, ax = plt.subplots(1,figsize=(20,10), sharex=True, sharey=True)
#     ax.set_xlim(0,pred_value.shape[0])  
    
    
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.plot(pred_value, label="LLAAT")
    ax.plot(actual_value, label="Actual")
    ax.set_title("Forecasted performance for l=%d" %(1))
    ax.legend()
        
    #fig.text(0.5, 0, "Stage of training", ha='center', fontsize=20)
    #fig.text(0, 0.5, "Copper price value", va='center', rotation='vertical')

    fig.suptitle("In the %s process in the M=%d window"%(name, block_index))
    fig.tight_layout()
#     fig.savefig("In the %s process in the M=%d window.png"%(name, block_index),dpi=300,bbox_inches='tight')

# %%
def plot_adopted_node(network,block_index):
    
    fig, ax = plt.subplots(figsize=(20,5))
#     ax.set_xticklabels([i for i in range(network.nb_node_acceptable.shape[0]+5)])
    
    ax.set_title("Total amount of adopted hidden nodes in the training process in the M=%d window"%(block_index))
    ax.plot(network.nb_node_acceptable,"-o")

    ax.set_xlabel("Stage of training")
    ax.set_ylabel("Hidden nodes")
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
#     fig.savefig("hidden nodes in the training process in the M=%d window"%(block_index),dpi=300,bbox_inches='tight')

# %%
def evaluation_table(evaluation_results, block_index, name, performance, nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node):

    
    new_result = pd.DataFrame({

        "Window_index":block_index,
        "Stage":name,
        "MAE" : round(performance[0].item(),2),
        "SD of absolute error":round(performance[1].item(),2),
        "MAPE" : "%.2f"%(performance[2]*100).item(),
        "RMSE" : round(performance[3].item(),2),
#         "Accuracy(2000)" : [round(performance[4]*100,2)],
        "Accuracy(3000)" : [round(performance[5]*100,2)],
        "Step4":nb_step4,
        "Step6.1":nb_step6_1,
        "Step6.2":nb_step6_2,
        "Time":time,
        "Adopted_hidden_node":adopted_hidden_node
    })

    evaluation_results = evaluation_results.append(new_result, ignore_index=True)
    
    return evaluation_results

# %%
def validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled, x_test, y_test, start, end, block_index, evaluation_results_train, evaluation_results_test):

    ## Training_Step
#    print("<<Training step>>")
    print("The training time(s):",end - start)
    time = end - start
    yo, loss= network.forward()
    
    ## N - outlier
    pre_train = yo.data.cpu()
    true_train = network.y.data.cpu()
    
    pred_value_train = torch.FloatTensor(sc.inverse_transform(pre_train))
    actual_value_train = torch.FloatTensor(sc.inverse_transform(true_train))
    accuracy_train = accuracy_cacl(pred_value_train,actual_value_train)

    ## B
    pred_value_test = torch.FloatTensor(sc.inverse_transform(network.forecast(x_test).data.cpu()))
    accuracy_test = accuracy_cacl(pred_value_test, y_test)
    
#     total_time = nb_step4 + nb_step6_1 + nb_step6_2
#     print("<<The percentage of each step>>")
#     print("Step 4: %.2f%%"%((nb_step4/total_time)*100))
#     print("Step 6.1: %.2f%%"%((nb_step6_1/total_time)*100))
#     print("Step 6.2: %.2f%%"%((nb_step6_2/total_time)*100))
    
#     print("-"*60)
#     print("Total frequency of cramming occurrences:",nb_step6_2)

#     print("-"*60)
#     print("The amount of hidden node that be pruned:",network.nb_node_pruned)

#     print("-"*60)
    adopted_hidden_node = network.nb_node_acceptable[-1].item()
#     print("The amount of adopted hidden nodes:",network.nb_node_acceptable[-1].item())

#     print("-"*60)
#     print("<<Accuracy in training step>>")
#     print("The MAE for l = 1: %.2f" %(accuracy_train[0]))
#     print("The MAPE for l = 1: %.2f%%" %(accuracy_train[1]))
#     print("The RMSE for l = 1: %.2f" %(accuracy_train[2]))
#     print("The accuracy(2000) for l = 1: %.2f%%" %(accuracy_train[3]*100))
#     print("The accuracy(3000) for l = 1: %.2f%%" %(accuracy_train[4]*100))

    print("The forecast copper price for the third week:", pred_value_test[-4:].tolist())
    print("<<Performance measurement>>")
    print("The MAE: %.1f" %(accuracy_test[0]))
    print("The standard deviation of absolute error: %.1f" %(accuracy_test[1]))
    print("The MAPE: %.1f%%" %(accuracy_test[2]))
    print("The RMSE: %.1f" %(accuracy_test[3]))
#    print("The accuracy(2000) for l = 1: %.1f%%" %(accuracy_test[4]*100))
    print("The accuracy(3000): %.1f%%" %(accuracy_test[5]*100))
    print("-"*120)

    
    evaluation_table_train = evaluation_table(evaluation_results_train, block_index, "Training", accuracy_train,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    evaluation_table_test = evaluation_table(evaluation_results_test, block_index, "Inferencing", accuracy_test,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    pre_LDSS = sc.inverse_transform(network.forecast(x_test).data.cpu())
#     pd.DataFrame(pre_LDSS).to_csv("pre_LDSS_%d.csv"%(block_index), index=False)
    
#     plot_result("training",pred_value_train, actual_value_train,block_index)
#     plot_result("inferencing",pred_value_test, y_test,block_index)
#     plot_adopted_node(network,block_index)
    
    return(evaluation_table_train, evaluation_table_test)

# %% [markdown]
# ### Preprocessing the data

# %%
def read(path):
    return pd.read_csv(path)

# %%
def buildTrain(train, pastWeek=4, futureWeek=4, defaultWeek=1):
    X_train, Y_train = [], []
    for i in range(train.shape[0]-futureWeek-pastWeek):
        X = np.array(train.iloc[i:i+defaultWeek])
        X = np.append(X,train["CCSP"].iloc[i+defaultWeek:i+pastWeek])
        X_train.append(X.reshape(X.size))
        Y_train.append(np.array(train.iloc[i+pastWeek:i+pastWeek+futureWeek]["CCSP"]))
    return np.array(X_train), np.array(Y_train)

# %% [markdown]
# ### Min-max normalization

# %%
## Use min-max normalization to scale the data to the range from 1 to 0
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ### Design get_data() to get data

# %%
def get_data(futureWeek):
    
    ## Read weekly copper price data
    path = "WeeklyFinalData.csv"
    data = read(path)
    
    date = data["Date"]
    data.drop("Date", axis=1, inplace=True)
    
    ## Add time lag (pastWeek=4, futureWeek=1)
    x_data, y_data = buildTrain(data, futureWeek=futureWeek)


    return (x_data, y_data)

# %% [markdown]
# ### Network class

# %%
class Network(torch.nn.Module):
    
    def __init__(self, nb_neuro, x_train_scaled, y_train_scaled):
        
        super(Network, self).__init__()
        self.linear1 = torch.nn.Linear(x_train_scaled.shape[1], nb_neuro).cuda()
        self.linear2 = torch.nn.Linear(nb_neuro, 1).cuda()
        
        
        # Stop criteria - threshold
        self.threshold_for_error = 0.12
        self.threshold_for_lr = 1e-4
        
        # Input data 
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
        
        # Learning rate
        self.learning_rate = 1e-3
        
        # Whether the network is acceptable, default as False
        self.acceptable = False
        
        # Some record for experiment
        self.nb_node_pruned = 0
        self.nb_node_acceptable=torch.IntTensor([nb_neuro])
        
        self.limit = nb_neuro
        
    ## Forecast the test data
    def forecast(self, x_test):
    
        x_test = torch.FloatTensor(x_test).cuda()
        activation_value = self.linear1(x_test).clamp(min=0)
        forecast_value = self.linear2(activation_value)
       
        return forecast_value

    ## Reset the x and y data
    def setData(self, x_train_scaled, y_train_scaled):
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
    
    ## Add the new data to the x and y data
    def addData(self, new_x_train, new_y_train):

        self.x = torch.cat([self.x, new_x_train.reshape(1,-1).cuda()],0)
        self.y = torch.cat([self.y, new_y_train.reshape(-1,1).cuda()],0)
    
    ## forward operation
    def forward(self, reg_strength=0):
       
        y1 = self.linear1(self.x).clamp(min=0)
        yo = self.linear2(y1)

        # performance measure
        param_val= torch.sum(torch.pow(self.linear2.bias.data,2))+torch.sum(torch.pow(self.linear2.weight.data,2))+torch.sum(torch.pow(self.linear1.bias.data,2))+torch.sum(torch.pow(self.linear1.weight.data,2))
        reg_term= reg_strength/((self.linear2.bias.data.shape[0]*(self.linear2.weight.data.shape[1]+1)) +(self.linear1.bias.data.shape[0]*(self.linear1.weight.data.shape[1]+1)))*param_val
        loss = torch.nn.functional.mse_loss(yo,self.y)+reg_term
        loss = loss.cuda()
        return(yo, loss)

    # backward operation
    def backward_Adadelta(self,loss):    

        optimizer = optim.Adadelta(self.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### Initializing module (Check)

# %%
def initializing(network, initial_x, initial_y):
#     print("Initializing module")
    ## Find each minimum output value y
    min_y = torch.min(initial_y, axis=0)
    ## Subtract min_y from each y
    res_y = initial_y-min_y.values
    
    ## Use linear regression to find the initial W1,b1,Wo,bo
    reg = LinearRegression().fit(initial_x, res_y)
    
    ## Set up the initial parameter of the network
    network.linear1.weight = torch.nn.Parameter(torch.FloatTensor(reg.coef_).cuda())
    network.linear1.bias = torch.nn.Parameter(torch.FloatTensor(reg.intercept_).cuda())
    network.linear2.weight=torch.nn.Parameter(torch.FloatTensor([[1]]).cuda())
    network.linear2.bias = torch.nn.Parameter(torch.FloatTensor(min_y.values).cuda())
    
#     print(reg.coef_)
#     print(reg.intercept_)

    ## Set up the acceptable of the initial network as True
    network.acceptable =True

# %% [markdown]
# ### Selecting module (Check)

# %%
def selecting(network, x_train_scaled, y_train_scaled):
    
#     print("<<Selecting module>>")
    loss = []
    temp_network = copy.deepcopy(network)
    
    ## Put each data into network to calculate the loss value
    for i in range(x_train_scaled.shape[0]):
        temp_network.setData(x_train_scaled[i].reshape(1,-1), y_train_scaled[i].reshape(-1,1))
        loss.append((temp_network.forward()[1].item(),i))
#         print(network.state_dict())
#         print(temp_network.y)
#         print("-"*20)
#         print(temp_network.forward()[1])
#         print("-"*20)
#     ## Sort the data according to the loss value from smallest to largest, and save the data index in sorted_index
    sorted_index = [sorted_data[1] for sorted_data in sorted(loss, key = lambda x:x[0])]
    
    
    ## Print out some info for debug
#     print("The loss value of k:",loss[sorted_index[0]])
#     print("The second_loss value of k:",loss[sorted_index[1]])
#     print("Selecting module finish!")
#     print("Loss",loss)
#     print(network.state_dict())
    
    return sorted_index

# %% [markdown]
# ### Matching

# %%
def matching(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(10000):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ### Matching for reorganizing

# %%
def matching_for_reorganizing(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module for reorganizing>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(500):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished(o) - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished(o) - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ## Cramming module (Check)

# %%
def cramming(network):
    
    torch.random.manual_seed(0)
#     print("<<Cramming module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Find unsatisfied data:K
    yo, loss = network.forward()
    undesired_index = torch.nonzero(torch.abs(yo-network.y) > network.threshold_for_error+0.001, as_tuple =False)

    ## Print out the undesired_index for debug
#     print("不滿足個數：",undesired_index.shape[0])
#     print("The index of the undesired data:",undesired_index)

    
    if undesired_index.shape[0] == 1:
        
        # Unsatisfied situation
        ## Find the index of the unsatisfied data
        k_data_num = undesired_index[0][0]

        undesired_data = torch.reshape(network.x[k_data_num,:], [1,-1])

        ## Remove the data that does not meet the error term
        left_data = network.x[:k_data_num,:]
        right_data = network.x[k_data_num+1:,:]
        remain_tensor = torch.cat([left_data, right_data], 0)


        ## Use the random method to find out the gamma and zeta
        while True:

            ## Find m-vector gamma: r
            ## Use the random method to generate the gamma that can make the conditions met
            gamma = torch.rand(size=[1,network.x.shape[1]]).cuda()
            subtract_undesired_data = torch.sub(remain_tensor, undesired_data)
            matmul_value = torch.mm(gamma,torch.t(subtract_undesired_data))

            if torch.all(matmul_value != 0):
                break

        while True:

            ## Find the tiny value: zeta
            ## Use the random method to generate the zeta that can make the conditions met
            zeta = torch.rand(size=[1]).cuda()

            if torch.all(torch.mul(torch.add(zeta,matmul_value),torch.sub(zeta,matmul_value))<0):
                break


        k_l = undesired_index[0][1]
        
        ## The weight of input layer to hidden layer I
        w10 = gamma
        w11 = gamma
        w12 = gamma

        W1_new = torch.cat([w10,w11,w12],0)
        

        ## The bias of input layer to hidden layer I
        matual_value = torch.mm(gamma,torch.t(undesired_data))
       
        
        b10 = torch.sub(zeta,matual_value)
        b11 = -1*matual_value
        b12 = torch.sub(-1*zeta,matual_value)

        b1_new = torch.reshape(torch.cat([b10,b11,b12],0),[3])

        ## The weight of hidden layer I to output layer
        gap = network.y[k_data_num, k_l]-yo[k_data_num, k_l]

        wo0_value = gap/zeta
        wo1_value = (-2*gap)/zeta
        wo2_value = gap/zeta

        Wo_new = torch.reshape(torch.cat([wo0_value,wo1_value,wo2_value],0),[1,-1])

        ## Add new neuroes to the network
        network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight.data, W1_new]))
        network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias.data, b1_new]))
        network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight.data, Wo_new],1))


        yo, loss = network.forward()
        
        ## Determine if cramming is successful and print out the corresponding information
        if torch.all(torch.abs(yo-network.y) <= network.threshold_for_error):
            network.acceptable = True 
#             print("Cramming success!")

        else:
#             print("Cramming failed!")
            pass
    
    else:
#         print("條件不合，不能Cramming")
        pass

# %% [markdown]
# ### Regularizing module (Check)

# %%
def regularizing(network):

#     print("<<Regularizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    ## Record the number of executions
    times_enlarge = 0
    times_shrink = 0
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3

    ## Set epoch to 100
    for i in range(100):

        ## Store the parameter of the network
        network_pre = copy.deepcopy(network)
        yo, loss = network.forward(1e-3)
        loss_pre = loss
        
        ## Backward operation to obtain w'
        network.backward_Adadelta(loss)
        yo, loss = network.forward(1e-3)

        # Confirm whether the adjusted loss value is smaller than the current one
        if loss <= loss_pre:
            
            ## Identify that all forecast value has met the error term
            if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):
                
                ## If true, multiply the learning rate by 1.2
                network.learning_rate *= 1.2
                times_enlarge += 1

            else:

                ## Else, restore w and end the process
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-因為沒有顧好預測誤差")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

        # If the adjusted loss value is not smaller than the current one
        else:

            ## If the learning rate is greater than the threshold for learning rate
            if network.learning_rate > network.threshold_for_lr:
                
                ## Restore the w and multiply the learning rate by 0.7
                network = copy.deepcopy(network_pre)
                network.learning_rate *= 0.7
                times_shrink += 1

             ## If the learning rate is smaller than the threshold for learning rate
            else:
                
                ## Restore the w
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-Learning不能這麼小")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

#     print("第\"%d\"回合Regularizing module完畢"%(i+1))
#     print("Number of enlarge:",times_enlarge)
#     print("Number of shrink:",times_shrink)
    return(network)

# %% [markdown]
# ### Reorganizing module (Check)

# %%
def reorganizing(network):
#     print("<<Reorganizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    limit = 4
    if network.linear1.bias.shape[0] <= limit:
        network = regularizing(network)
        return(network)
    
    else:
        
        ## Set up the k = 1, and p = the number of hidden node
        k = 1
    #     p = network.W1.shape[1]
        p = network.linear1.weight.data.shape[0]

        while True:

            ## If k > p, end of Process
            if k > p or p<=limit:

#                 print("Reorganizing result: The final number of neuro is ",p)
                return(network)

            ## Else, Process is ongoing
            else:

                ## Using the regularizing module to adjust the network
                network = regularizing(network)

                ## Store the network and w
                network_pre = copy.deepcopy(network)

                ## Set up the acceptable of the network as false
                network.acceptable = False
                
            
                ## Ignore the K hidden node
                network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight[:k-1],network.linear1.weight[k:]],0))
                network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias[:k-1],network.linear1.bias[k:]]))
                network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight[:,:k-1],network.linear2.weight[:,k:]],1))

                
                ## Using the matching module to adjust the network
                network = matching_for_reorganizing(network)

#                 print("是不是可以不要這個hidden node:",network.acceptable)

                ## If the resulting network is acceptable, this means that the k hidden node can be removed
                if network.acceptable:

#                     print("Drop out the nero number: %d / %d" %(k, p))
                    network.nb_node_pruned += 1
                    ## p--
                    p-=1

                ## Else, it means that the k hidden node cannot be removed
                else:

                    ## Restore the network and w
                    network = copy.deepcopy(network_pre)
#                     print("Cannot drop out the nero number: %d / %d" %(k, p))

                    ## k++
                    k+=1

# %%
evaluation_table_train = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
evaluation_table_test = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
    
x_data, y_data= get_data(4)
x_data = sc.fit_transform(x_data)
y_data = sc.fit_transform(y_data[:,2].reshape(-1,1))
threshold_for_error = 8000/(sc.data_max_-sc.data_min_)

data = range(x_data.shape[0])
# window_size => the length of training block
window_size = 212
# step_window => step size of each window
step_window = 4
# the split data
splits = []

## Moving window mechnism
for i in range(window_size, len(data), step_window):
    train = np.array(data[i-window_size:i])
#     test = np.array(data[i:i+step_window])
    test = np.array(data[i-window_size:i+step_window])
    splits.append(('TRAIN:', train, 'TEST:', test))


start = time.time()
for i_block in range(len(splits)):
# for i_block in range(2):
    block_start = time.time()
    ## Record the number of each step
    nb_step4 = 0
    nb_step6_1 = 0
    nb_step6_2 = 0
    
    print("The <<%d>> Window" %(i_block+1))
    
    x_train = x_data[splits[i_block][1]]
    x_test = x_data[splits[i_block][3]]
    y_train = y_data[splits[i_block][1]]
    y_test = y_data[splits[i_block][3]]
    
    x_train_scaled = torch.FloatTensor(x_train)
    x_test_scaled = torch.FloatTensor(x_test)
    y_train_scaled = torch.FloatTensor(y_train)
    y_test = sc.inverse_transform(y_test)

    if i_block == 0:
        lower = torch.mean(y_train_scaled)-torch.std(y_train_scaled)
        upper = torch.mean(y_train_scaled)+torch.std(y_train_scaled)
        nonoutlier_index = torch.nonzero((y_train_scaled[:,0]>lower)&(y_train_scaled[:,0]<upper), as_tuple =False).reshape([-1])
        
        initial_x = x_train_scaled[nonoutlier_index[:19]]
        initial_y = y_train_scaled[nonoutlier_index[:19]]
        
        x_train_scaled = np.delete(x_train_scaled, nonoutlier_index[:19], 0)
        y_train_scaled = np.delete(y_train_scaled, nonoutlier_index[:19], 0)
        
        network = Network(1,initial_x,initial_y)
        
        network.nb_node_acceptable = torch.IntTensor([1 for _ in range(initial_x.shape[0])])
        network.threshold_for_error = round(threshold_for_error[0],2)
        
        initializing(network, initial_x, initial_y)
        nb_step4 += initial_x.shape[0]
#         print("<<Initializing後看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
#         print("threshold_for_error:",network.threshold_for_error)
        remainder = int(window_size) - initial_x.shape[0]
    
    else:

        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        restart_index = int(x_train_scaled.shape[0])-step_window
#         print("其他區塊剛開始選的資料索引：",sorted_index[:restart_index])
        init_x = x_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,x_train_scaled.shape[1])
        init_y = y_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,1)
        network.setData(init_x, init_y)
        network.nb_node_acceptable = torch.IntTensor([network.linear1.bias.data.shape[0] for _ in range(init_x.shape[0])])
        network.nb_node_pruned = 0
        
        nb_step4 += init_x.shape[0]
#         print("<<其他區塊剛開始時看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
        
        remainder = int(window_size) - init_x.shape[0]
        x_train_scaled = np.delete(x_train_scaled, sorted_index[:restart_index], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[:restart_index], 0)
        

    for i in range(remainder):
#    for i in range(3):
        
        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        
        ## Add new data for training     
        network.addData(x_train_scaled[sorted_index[0]], y_train_scaled[sorted_index[0]])
        x_train_scaled = np.delete(x_train_scaled, sorted_index[0], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[0], 0)
        
        yo,loss = network.forward()
        pre_network = copy.deepcopy(network)
        
        if not torch.all(torch.abs(network.y-yo)<=network.threshold_for_error):

            network.acceptable = False
            network = matching(network)
            
            
            if network.acceptable == False:
                
                network = copy.deepcopy(pre_network)
                cramming(network)

                if network.acceptable == False:
                    sys.exit(0)  
                
                nb_step6_2 += 1

            else:
                nb_step6_1 += 1

        else:
            nb_step4 += 1

        network = reorganizing(network)
        yo,loss = network.forward()
        
        network.nb_node_acceptable = torch.cat([network.nb_node_acceptable, torch.IntTensor([network.linear1.bias.data.shape[0]])],0)

#     print("<<The performance of %d window>>"%(i_block+1))
    block_end = time.time()
    evaluation_table_train, evaluation_table_test = validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled,x_test_scaled, y_test, block_start, block_end,i_block+1,evaluation_table_train,evaluation_table_test)

    evaluation_table_train.to_csv("evaluation_table_train.csv",index=False)
    evaluation_table_test.to_csv("evaluation_table_inferencing.csv",index=False)
# Out:
# The <<1>> Window
# The training time(s): 48.06362748146057
# The forecast copper price for the third week: [[39308.8828125], [40171.44140625], [41256.7109375], [41906.4296875]]
# <<Performance measurement>>
# The MAE: 1712.1
# The standard deviation of absolute error: 1425.1
# The MAPE: 0.0%
# The RMSE: 2225.5
# The accuracy(3000): 84.7%
# ------------------------------------------------------------------------------------------------------------------------
# The <<2>> Window
# The training time(s): 0.8964416980743408
# The forecast copper price for the third week: [[40763.14453125], [39963.43359375], [41019.97265625], [41289.46875]]
# <<Performance measurement>>
# The MAE: 1701.3
# The standard deviation of absolute error: 1393.2
# The MAPE: 0.0%
# The RMSE: 2196.9
# The accuracy(3000): 84.3%
# ------------------------------------------------------------------------------------------------------------------------
# The <<3>> Window
# The training time(s): 0.8938970565795898
# The forecast copper price for the third week: [[39662.98828125], [39774.234375], [40255.6484375], [41060.8046875]]
# <<Performance measurement>>
# The MAE: 1629.5
# The standard deviation of absolute error: 1291.6
# The MAPE: 0.0%
# The RMSE: 2077.4
# The accuracy(3000): 85.2%
# ------------------------------------------------------------------------------------------------------------------------
# The <<4>> Window
# The training time(s): 0.9338703155517578
# The forecast copper price for the third week: [[40038.2890625], [40798.46875], [41495.87109375], [42057.9140625]]
# <<Performance measurement>>
# The MAE: 1564.8
# The standard deviation of absolute error: 1291.1
# The MAPE: 0.0%
# The RMSE: 2026.8
# The accuracy(3000): 85.2%
# ------------------------------------------------------------------------------------------------------------------------
# The <<5>> Window
# The training time(s): 0.9161345958709717
# The forecast copper price for the third week: [[41000.890625], [40520.59375], [40782.19921875], [40980.03515625]]
# <<Performance measurement>>
# The MAE: 1515.1
# The standard deviation of absolute error: 1291.1
# The MAPE: 0.0%
# The RMSE: 1988.6
# The accuracy(3000): 86.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<6>> Window
# The training time(s): 0.9614450931549072
# The forecast copper price for the third week: [[40175.23046875], [39903.296875], [39718.2109375], [39593.53515625]]
# <<Performance measurement>>
# The MAE: 1488.8
# The standard deviation of absolute error: 1299.9
# The MAPE: 0.0%
# The RMSE: 1974.5
# The accuracy(3000): 86.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<7>> Window
# The training time(s): 1.0343382358551025
# The forecast copper price for the third week: [[38491.33984375], [38395.86328125], [38591.56640625], [38302.40625]]
# <<Performance measurement>>
# The MAE: 1428.7
# The standard deviation of absolute error: 1278.0
# The MAPE: 0.0%
# The RMSE: 1914.9
# The accuracy(3000): 87.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<8>> Window
# The training time(s): 0.9891941547393799
# The forecast copper price for the third week: [[38248.05078125], [38930.23046875], [39587.6484375], [40231.48046875]]
# <<Performance measurement>>
# The MAE: 1403.8
# The standard deviation of absolute error: 1255.0
# The MAPE: 0.0%
# The RMSE: 1881.1
# The accuracy(3000): 87.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<9>> Window
# The training time(s): 0.9092109203338623
# The forecast copper price for the third week: [[40174.66015625], [39732.0546875], [39285.65625], [38618.70703125]]
# <<Performance measurement>>
# The MAE: 1422.7
# The standard deviation of absolute error: 1227.2
# The MAPE: 0.0%
# The RMSE: 1877.0
# The accuracy(3000): 88.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<10>> Window
# The training time(s): 0.9096503257751465
# The forecast copper price for the third week: [[38011.08984375], [37989.046875], [38266.7421875], [37746.62890625]]
# <<Performance measurement>>
# The MAE: 1385.8
# The standard deviation of absolute error: 1196.5
# The MAPE: 0.0%
# The RMSE: 1829.1
# The accuracy(3000): 89.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<11>> Window
# The training time(s): 0.8923563957214355
# The forecast copper price for the third week: [[37022.5703125], [37076.03125], [37358.41796875], [37567.09765625]]
# <<Performance measurement>>
# The MAE: 1358.9
# The standard deviation of absolute error: 1182.8
# The MAPE: 0.0%
# The RMSE: 1799.8
# The accuracy(3000): 89.8%
# ------------------------------------------------------------------------------------------------------------------------
# The <<12>> Window
# The training time(s): 0.9001688957214355
# The forecast copper price for the third week: [[37655.07421875], [37559.7421875], [38258.63671875], [39143.7578125]]
# <<Performance measurement>>
# The MAE: 1433.4
# The standard deviation of absolute error: 1395.5
# The MAPE: 0.0%
# The RMSE: 1998.2
# The accuracy(3000): 88.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<13>> Window
# The training time(s): 1.0036885738372803
# The forecast copper price for the third week: [[41288.0625], [42569.0078125], [43517.2109375], [43999.1640625]]
# <<Performance measurement>>
# The MAE: 1444.4
# The standard deviation of absolute error: 1410.5
# The MAPE: 0.0%
# The RMSE: 2016.5
# The accuracy(3000): 88.0%
# ------------------------------------------------------------------------------------------------------------------------
# The <<14>> Window
# The training time(s): 0.8997812271118164
# The forecast copper price for the third week: [[44277.6484375], [43595.35546875], [43077.984375], [42758.43359375]]
# <<Performance measurement>>
# The MAE: 1477.0
# The standard deviation of absolute error: 1424.1
# The MAPE: 0.0%
# The RMSE: 2049.4
# The accuracy(3000): 87.0%
# ------------------------------------------------------------------------------------------------------------------------
# The <<15>> Window
# The training time(s): 1.0399901866912842
# The forecast copper price for the third week: [[43245.92578125], [44121.85546875], [44370.13671875], [44606.890625]]
# <<Performance measurement>>
# The MAE: 1525.5
# The standard deviation of absolute error: 1434.8
# The MAPE: 0.0%
# The RMSE: 2092.0
# The accuracy(3000): 86.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<16>> Window
# The training time(s): 0.9135231971740723
# The forecast copper price for the third week: [[45379.66015625], [46008.484375], [46056.609375], [45929.21484375]]
# <<Performance measurement>>
# The MAE: 1502.1
# The standard deviation of absolute error: 1398.5
# The MAPE: 0.0%
# The RMSE: 2050.1
# The accuracy(3000): 86.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<17>> Window
# The training time(s): 0.9116714000701904
# The forecast copper price for the third week: [[46400.60546875], [46258.7421875], [46302.83984375], [46016.21484375]]
# <<Performance measurement>>
# The MAE: 1428.5
# The standard deviation of absolute error: 1369.0
# The MAPE: 0.0%
# The RMSE: 1976.4
# The accuracy(3000): 87.0%
# ------------------------------------------------------------------------------------------------------------------------
# The <<18>> Window
# The training time(s): 0.9028596878051758
# The forecast copper price for the third week: [[46287.79296875], [46472.47265625], [46282.90234375], [46718.70703125]]
# <<Performance measurement>>
# The MAE: 1362.3
# The standard deviation of absolute error: 1315.8
# The MAPE: 0.0%
# The RMSE: 1891.9
# The accuracy(3000): 88.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<19>> Window
# The training time(s): 0.997394323348999
# The forecast copper price for the third week: [[47166.125], [47083.7734375], [46728.875], [46669.22265625]]
# <<Performance measurement>>
# The MAE: 1319.0
# The standard deviation of absolute error: 1267.6
# The MAPE: 0.0%
# The RMSE: 1827.3
# The accuracy(3000): 91.2%
# ------------------------------------------------------------------------------------------------------------------------
# The <<20>> Window
# The training time(s): 0.9199733734130859
# The forecast copper price for the third week: [[46207.671875], [46602.953125], [46612.55078125], [46380.2265625]]
# <<Performance measurement>>
# The MAE: 1279.9
# The standard deviation of absolute error: 1233.1
# The MAPE: 0.0%
# The RMSE: 1775.3
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<21>> Window
# The training time(s): 0.9858648777008057
# The forecast copper price for the third week: [[46695.296875], [46942.37890625], [46952.609375], [46972.140625]]
# <<Performance measurement>>
# The MAE: 1280.4
# The standard deviation of absolute error: 1207.5
# The MAPE: 0.0%
# The RMSE: 1758.0
# The accuracy(3000): 91.7%
# ------------------------------------------------------------------------------------------------------------------------
# The <<22>> Window
# The training time(s): 0.9590163230895996
# The forecast copper price for the third week: [[47756.109375], [48307.7265625], [49106.3046875], [49526.9296875]]
# <<Performance measurement>>
# The MAE: 1284.5
# The standard deviation of absolute error: 1171.2
# The MAPE: 0.0%
# The RMSE: 1736.5
# The accuracy(3000): 91.7%
# ------------------------------------------------------------------------------------------------------------------------
# The <<23>> Window
# The training time(s): 0.911522626876831
# The forecast copper price for the third week: [[50161.30078125], [50674.77734375], [51180.078125], [51111.6484375]]
# <<Performance measurement>>
# The MAE: 1273.2
# The standard deviation of absolute error: 1150.1
# The MAPE: 0.0%
# The RMSE: 1713.9
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<24>> Window
# The training time(s): 0.9057292938232422
# The forecast copper price for the third week: [[50717.21875], [49846.8671875], [50069.58984375], [50903.5703125]]
# <<Performance measurement>>
# The MAE: 1330.4
# The standard deviation of absolute error: 1199.0
# The MAPE: 0.0%
# The RMSE: 1789.1
# The accuracy(3000): 91.2%
# ------------------------------------------------------------------------------------------------------------------------
# The <<25>> Window
# The training time(s): 0.9082386493682861
# The forecast copper price for the third week: [[51850.09765625], [51850.09765625], [51850.09765625], [51850.09765625]]
# <<Performance measurement>>
# The MAE: 1348.4
# The standard deviation of absolute error: 1164.9
# The MAPE: 0.0%
# The RMSE: 1780.1
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<26>> Window
# The training time(s): 0.9467382431030273
# The forecast copper price for the third week: [[52027.23828125], [52027.23828125], [52027.23828125], [52027.23828125]]
# <<Performance measurement>>
# The MAE: 1364.3
# The standard deviation of absolute error: 1149.4
# The MAPE: 0.0%
# The RMSE: 1782.2
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<27>> Window
# The training time(s): 0.9021673202514648
# The forecast copper price for the third week: [[51697.3046875], [51822.48828125], [52182.5078125], [52498.12890625]]
# <<Performance measurement>>
# The MAE: 1370.2
# The standard deviation of absolute error: 1149.5
# The MAPE: 0.0%
# The RMSE: 1786.8
# The accuracy(3000): 92.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<28>> Window
# The training time(s): 0.9601988792419434
# The forecast copper price for the third week: [[52760.07421875], [52760.07421875], [52760.07421875], [52628.79296875]]
# <<Performance measurement>>
# The MAE: 1362.4
# The standard deviation of absolute error: 1142.6
# The MAPE: 0.0%
# The RMSE: 1776.4
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<29>> Window
# The training time(s): 0.9974853992462158
# The forecast copper price for the third week: [[51891.2109375], [51302.45703125], [50751.09765625], [50726.66796875]]
# <<Performance measurement>>
# The MAE: 1356.7
# The standard deviation of absolute error: 1139.1
# The MAPE: 0.0%
# The RMSE: 1769.8
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<30>> Window
# The training time(s): 0.9529709815979004
# The forecast copper price for the third week: [[50964.56640625], [51079.46484375], [50459.8828125], [49636.56640625]]
# <<Performance measurement>>
# The MAE: 1367.6
# The standard deviation of absolute error: 1127.0
# The MAPE: 0.0%
# The RMSE: 1770.5
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<31>> Window
# The training time(s): 1.0048456192016602
# The forecast copper price for the third week: [[49298.0546875], [49563.4921875], [49391.83984375], [49779.984375]]
# <<Performance measurement>>
# The MAE: 1340.0
# The standard deviation of absolute error: 1086.0
# The MAPE: 0.0%
# The RMSE: 1723.2
# The accuracy(3000): 93.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<32>> Window
# The training time(s): 0.9116065502166748
# The forecast copper price for the third week: [[51335.5625], [52024.6484375], [51282.609375], [51448.36328125]]
# <<Performance measurement>>
# The MAE: 1332.9
# The standard deviation of absolute error: 1083.5
# The MAPE: 0.0%
# The RMSE: 1716.2
# The accuracy(3000): 93.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<33>> Window
# The training time(s): 0.9606115818023682
# The forecast copper price for the third week: [[51487.46484375], [51643.70703125], [52252.203125], [52295.35546875]]
# <<Performance measurement>>
# The MAE: 1329.6
# The standard deviation of absolute error: 1087.2
# The MAPE: 0.0%
# The RMSE: 1715.9
# The accuracy(3000): 93.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<34>> Window
# The training time(s): 0.9015388488769531
# The forecast copper price for the third week: [[51747.5859375], [50844.984375], [50230.19921875], [50298.828125]]
# <<Performance measurement>>
# The MAE: 1335.9
# The standard deviation of absolute error: 1087.5
# The MAPE: 0.0%
# The RMSE: 1721.0
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<35>> Window
# The training time(s): 0.9036791324615479
# The forecast copper price for the third week: [[50263.24609375], [50732.015625], [51041.87109375], [51342.12109375]]
# <<Performance measurement>>
# The MAE: 1348.4
# The standard deviation of absolute error: 1095.4
# The MAPE: 0.0%
# The RMSE: 1735.7
# The accuracy(3000): 92.6%
# ------------------------------------------------------------------------------------------------------------------------
# The <<36>> Window
# The training time(s): 0.9710533618927002
# The forecast copper price for the third week: [[51184.46484375], [51130.390625], [51089.984375], [50763.26171875]]
# <<Performance measurement>>
# The MAE: 1360.7
# The standard deviation of absolute error: 1094.0
# The MAPE: 0.0%
# The RMSE: 1744.4
# The accuracy(3000): 93.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<37>> Window
# The training time(s): 0.9172074794769287
# The forecast copper price for the third week: [[51100.890625], [51290.796875], [51892.6484375], [52241.6796875]]
# <<Performance measurement>>
# The MAE: 1367.9
# The standard deviation of absolute error: 1095.9
# The MAPE: 0.0%
# The RMSE: 1751.2
# The accuracy(3000): 93.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<38>> Window
# The training time(s): 0.9734959602355957
# The forecast copper price for the third week: [[52364.98828125], [52342.3984375], [51633.5703125], [51473.125]]
# <<Performance measurement>>
# The MAE: 1396.2
# The standard deviation of absolute error: 1097.3
# The MAPE: 0.0%
# The RMSE: 1774.2
# The accuracy(3000): 93.1%
# ------------------------------------------------------------------------------------------------------------------------
# The <<39>> Window
# The training time(s): 0.9833524227142334
# The forecast copper price for the third week: [[50751.8671875], [50543.4375], [50867.9609375], [50647.69140625]]
# <<Performance measurement>>
# The MAE: 1398.7
# The standard deviation of absolute error: 1096.2
# The MAPE: 0.0%
# The RMSE: 1775.6
# The accuracy(3000): 93.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<40>> Window
# The training time(s): 0.9019689559936523
# The forecast copper price for the third week: [[50526.49609375], [50315.3125], [49415.8203125], [49010.16015625]]
# <<Performance measurement>>
# The MAE: 1402.4
# The standard deviation of absolute error: 1103.6
# The MAPE: 0.0%
# The RMSE: 1783.0
# The accuracy(3000): 93.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<41>> Window
# The training time(s): 0.8979330062866211
# The forecast copper price for the third week: [[48423.734375], [47997.7734375], [47740.80078125], [47679.20703125]]
# <<Performance measurement>>
# The MAE: 1394.4
# The standard deviation of absolute error: 1096.3
# The MAPE: 0.0%
# The RMSE: 1772.1
# The accuracy(3000): 93.5%
# ------------------------------------------------------------------------------------------------------------------------
# The <<42>> Window
# The training time(s): 0.9961068630218506
# The forecast copper price for the third week: [[47728.27734375], [47992.56640625], [48022.45703125], [48823.0703125]]
# <<Performance measurement>>
# The MAE: 1375.1
# The standard deviation of absolute error: 1058.5
# The MAPE: 0.0%
# The RMSE: 1733.8
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<43>> Window
# The training time(s): 0.9029111862182617
# The forecast copper price for the third week: [[49322.4296875], [49542.15234375], [49489.19140625], [49235.00390625]]
# <<Performance measurement>>
# The MAE: 1342.7
# The standard deviation of absolute error: 1061.5
# The MAPE: 0.0%
# The RMSE: 1710.1
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<44>> Window
# The training time(s): 0.89363694190979
# The forecast copper price for the third week: [[49011.06640625], [49426.05859375], [49001.48046875], [49098.16015625]]
# <<Performance measurement>>
# The MAE: 1326.5
# The standard deviation of absolute error: 1061.6
# The MAPE: 0.0%
# The RMSE: 1697.4
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<45>> Window
# The training time(s): 1.0350770950317383
# The forecast copper price for the third week: [[48998.4609375], [48623.58203125], [48321.828125], [47998.23046875]]
# <<Performance measurement>>
# The MAE: 1328.0
# The standard deviation of absolute error: 1062.6
# The MAPE: 0.0%
# The RMSE: 1699.2
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<46>> Window
# The training time(s): 0.9364535808563232
# The forecast copper price for the third week: [[47874.17578125], [48016.6640625], [47588.3046875], [47398.55859375]]
# <<Performance measurement>>
# The MAE: 1290.4
# The standard deviation of absolute error: 1049.2
# The MAPE: 0.0%
# The RMSE: 1661.6
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<47>> Window
# The training time(s): 0.8891854286193848
# The forecast copper price for the third week: [[47989.29296875], [48195.6015625], [48212.1171875], [48942.5390625]]
# <<Performance measurement>>
# The MAE: 1283.5
# The standard deviation of absolute error: 1046.5
# The MAPE: 0.0%
# The RMSE: 1654.5
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<48>> Window
# The training time(s): 0.9227550029754639
# The forecast copper price for the third week: [[49203.30078125], [49422.40625], [48934.2265625], [48304.875]]
# <<Performance measurement>>
# The MAE: 1300.1
# The standard deviation of absolute error: 1052.6
# The MAPE: 0.0%
# The RMSE: 1671.3
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<49>> Window
# The training time(s): 0.9090127944946289
# The forecast copper price for the third week: [[47951.43359375], [48321.0625], [48565.35546875], [49092.2421875]]
# <<Performance measurement>>
# The MAE: 1272.5
# The standard deviation of absolute error: 1044.6
# The MAPE: 0.0%
# The RMSE: 1644.8
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<50>> Window
# The training time(s): 0.9073994159698486
# The forecast copper price for the third week: [[49036.7890625], [48559.16015625], [48578.88671875], [48525.46875]]
# <<Performance measurement>>
# The MAE: 1265.7
# The standard deviation of absolute error: 1042.6
# The MAPE: 0.0%
# The RMSE: 1638.3
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<51>> Window
# The training time(s): 0.9249539375305176
# The forecast copper price for the third week: [[47861.34765625], [48047.00390625], [48268.46875], [48216.90234375]]
# <<Performance measurement>>
# The MAE: 1236.8
# The standard deviation of absolute error: 1038.1
# The MAPE: 0.0%
# The RMSE: 1613.2
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<52>> Window
# The training time(s): 0.9119179248809814
# The forecast copper price for the third week: [[47699.265625], [47415.8359375], [47429.4140625], [46692.4296875]]
# <<Performance measurement>>
# The MAE: 1242.8
# The standard deviation of absolute error: 1028.7
# The MAPE: 0.0%
# The RMSE: 1611.8
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<53>> Window
# The training time(s): 0.900615930557251
# The forecast copper price for the third week: [[47161.6328125], [47387.49609375], [48280.6015625], [48527.8046875]]
# <<Performance measurement>>
# The MAE: 1211.4
# The standard deviation of absolute error: 977.3
# The MAPE: 0.0%
# The RMSE: 1555.0
# The accuracy(3000): 96.8%
# ------------------------------------------------------------------------------------------------------------------------
# The <<54>> Window
# The training time(s): 0.9379658699035645
# The forecast copper price for the third week: [[48518.6171875], [48656.109375], [48472.5390625], [47402.55078125]]
# <<Performance measurement>>
# The MAE: 1222.8
# The standard deviation of absolute error: 1000.2
# The MAPE: 0.0%
# The RMSE: 1578.3
# The accuracy(3000): 96.3%
# ------------------------------------------------------------------------------------------------------------------------
# The <<55>> Window
# The training time(s): 0.9459538459777832
# The forecast copper price for the third week: [[45943.25390625], [46016.6953125], [45816.6796875], [45679.0078125]]
# <<Performance measurement>>
# The MAE: 1231.5
# The standard deviation of absolute error: 1038.4
# The MAPE: 0.0%
# The RMSE: 1609.3
# The accuracy(3000): 95.8%
# ------------------------------------------------------------------------------------------------------------------------
# The <<56>> Window
# The training time(s): 0.9719696044921875
# The forecast copper price for the third week: [[45095.15625], [44662.34375], [43542.5390625], [41955.33203125]]
# <<Performance measurement>>
# The MAE: 1271.2
# The standard deviation of absolute error: 1142.8
# The MAPE: 0.0%
# The RMSE: 1707.6
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<57>> Window
# The training time(s): 0.9013218879699707
# The forecast copper price for the third week: [[40249.42578125], [40728.54296875], [41691.8125], [41958.984375]]
# <<Performance measurement>>
# The MAE: 1243.2
# The standard deviation of absolute error: 1144.9
# The MAPE: 0.0%
# The RMSE: 1688.2
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<58>> Window
# The training time(s): 0.8965578079223633
# The forecast copper price for the third week: [[42908.44921875], [43604.09375], [43834.57421875], [44421.4609375]]
# <<Performance measurement>>
# The MAE: 1249.6
# The standard deviation of absolute error: 1124.5
# The MAPE: 0.0%
# The RMSE: 1679.3
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<59>> Window
# The training time(s): 0.9105725288391113
# The forecast copper price for the third week: [[44809.02734375], [45343.33203125], [46361.3359375], [47198.49609375]]
# <<Performance measurement>>
# The MAE: 1286.7
# The standard deviation of absolute error: 1112.9
# The MAPE: 0.0%
# The RMSE: 1699.5
# The accuracy(3000): 95.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<60>> Window
# The training time(s): 0.9474382400512695
# The forecast copper price for the third week: [[48160.5625], [49013.4296875], [49426.2578125], [50199.67578125]]
# <<Performance measurement>>
# The MAE: 1297.4
# The standard deviation of absolute error: 1116.5
# The MAPE: 0.0%
# The RMSE: 1710.0
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<61>> Window
# The training time(s): 1.0502657890319824
# The forecast copper price for the third week: [[51291.078125], [51291.68359375], [51154.21875], [50405.43359375]]
# <<Performance measurement>>
# The MAE: 1279.4
# The standard deviation of absolute error: 1098.3
# The MAPE: 0.0%
# The RMSE: 1684.5
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<62>> Window
# The training time(s): 1.0190887451171875
# The forecast copper price for the third week: [[50817.421875], [49942.23046875], [49102.51171875], [49137.32421875]]
# <<Performance measurement>>
# The MAE: 1279.8
# The standard deviation of absolute error: 1094.4
# The MAPE: 0.0%
# The RMSE: 1682.2
# The accuracy(3000): 94.9%
# ------------------------------------------------------------------------------------------------------------------------
# The <<63>> Window
# The training time(s): 0.9443991184234619
# The forecast copper price for the third week: [[49232.37890625], [48892.5390625], [48738.46875], [48560.515625]]
# <<Performance measurement>>
# The MAE: 1272.9
# The standard deviation of absolute error: 1085.3
# The MAPE: 0.0%
# The RMSE: 1671.1
# The accuracy(3000): 94.0%
# ------------------------------------------------------------------------------------------------------------------------
# The <<64>> Window
# The training time(s): 0.9001688957214355
# The forecast copper price for the third week: [[49543.97265625], [50097.93359375], [49928.48828125], [49849.203125]]
# <<Performance measurement>>
# The MAE: 1288.4
# The standard deviation of absolute error: 1088.9
# The MAPE: 0.0%
# The RMSE: 1685.3
# The accuracy(3000): 94.4%
# ------------------------------------------------------------------------------------------------------------------------
# The <<65>> Window
# The training time(s): 0.9031083583831787
# The forecast copper price for the third week: [[50495.7109375], [50584.7109375], [51274.9609375], [52499.41796875]]
# <<Performance measurement>>
# The MAE: 1323.5
# The standard deviation of absolute error: 1187.9
# The MAPE: 0.0%
# The RMSE: 1776.6
# The accuracy(3000): 94.4%
# ------------------------------------------------------------------------------------------------------------------------
