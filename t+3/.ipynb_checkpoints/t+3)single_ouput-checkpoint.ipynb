# %% [markdown]
# ### Import related package

# %%
## Import tensorflow package for modeling
import torch
from torch.autograd import Variable
import torch.optim as optim

## Data processing
import pandas as pd
import numpy as np

## Min-max normalization
from sklearn.preprocessing import MinMaxScaler

## Plot the graph
import matplotlib.pyplot as plt
# %matplotlib inline

## Initializing module
from sklearn.linear_model import LinearRegression
np.set_printoptions(suppress=True)

## Copy module
import copy

## Used to calculate the training time
import time
from datetime import datetime, timedelta
## Set the GUP environment
import os
import sys

from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker

# %%
os.chdir('/home/Oring-AI/Model_I/DINKLE/t+3')

# %%
## Set up the display
torch.set_printoptions(sci_mode=False)

# %% [markdown]
# ### Control memory usage space for GPU

# %%
## 查詢有無可用 GPU
torch.cuda.is_available()
## 查詢可用 GPU 的數量
torch.cuda.device_count()
##目前設備
print("目前設備：",torch.cuda.current_device())
## 目前設備名
print("目前設備名：",torch.cuda.get_device_name(0))
# Out:
# 目前設備： 0
# 目前設備名： GeForce GTX 1070 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# ## Print out some info

# %%
def accuracy_cacl(pred_value, actual_value):
    
#     yo, loss, tape = network.forward()
    performance = []
    performance.append(torch.mean(torch.abs(pred_value - actual_value)))
    performance.append(torch.std(torch.abs(pred_value - actual_value)))
    performance.append(torch.mean(torch.abs((pred_value - actual_value) / actual_value))) 
    performance.append(torch.sqrt(torch.mean((pred_value - actual_value)**2)))
    
    for i in range(2000,3001,1000):
        correct_times = torch.nonzero(torch.abs(pred_value - actual_value) <= i, as_tuple =False)
        accuracy = correct_times.shape[0]/pred_value.shape[0]
        performance.append(accuracy)
                       
    return performance

# %%
def plot_result(name, pred_value, actual_value,block_index):
    
#     fig, ax = plt.subplots(2,2,figsize=(20,10), sharex=True, sharey=True)
    fig, ax = plt.subplots(1,figsize=(20,10), sharex=True, sharey=True)
#     ax.set_xlim(0,pred_value.shape[0])  
    
    
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.plot(pred_value, label="LLAAT")
    ax.plot(actual_value, label="Actual")
    ax.set_title("Forecasted performance for l=%d" %(1))
    ax.legend()
        
    #fig.text(0.5, 0, "Stage of training", ha='center', fontsize=20)
    #fig.text(0, 0.5, "Copper price value", va='center', rotation='vertical')

    fig.suptitle("In the %s process in the M=%d window"%(name, block_index))
    fig.tight_layout()
#     fig.savefig("In the %s process in the M=%d window.png"%(name, block_index),dpi=300,bbox_inches='tight')

# %%
def plot_adopted_node(network,block_index):
    
    fig, ax = plt.subplots(figsize=(20,5))
#     ax.set_xticklabels([i for i in range(network.nb_node_acceptable.shape[0]+5)])
    
    ax.set_title("Total amount of adopted hidden nodes in the training process in the M=%d window"%(block_index))
    ax.plot(network.nb_node_acceptable,"-o")

    ax.set_xlabel("Stage of training")
    ax.set_ylabel("Hidden nodes")
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
#     fig.savefig("hidden nodes in the training process in the M=%d window"%(block_index),dpi=300,bbox_inches='tight')

# %%
def evaluation_table(evaluation_results, block_index, name, performance, nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node):

    
    new_result = pd.DataFrame({

        "Window_index":block_index,
        "Stage":name,
        "MAE" : round(performance[0].item(),2),
        "SD of absolute error":round(performance[1].item(),2),
        "MAPE" : "%.2f"%(performance[2]*100).item(),
        "RMSE" : round(performance[3].item(),2),
#         "Accuracy(2000)" : [round(performance[4]*100,2)],
        "Accuracy(3000)" : [round(performance[5]*100,2)],
        "Step4":nb_step4,
        "Step6.1":nb_step6_1,
        "Step6.2":nb_step6_2,
        "Time":time,
        "Adopted_hidden_node":adopted_hidden_node
    })

    evaluation_results = evaluation_results.append(new_result, ignore_index=True)
    
    return evaluation_results

# %%
def validation(last_date, network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled, x_test, y_test, start, end, block_index, evaluation_results_train, evaluation_results_test,performance_record):

    ## Training_Step
#    print("<<Training step>>")
#     print("The training time(s):",end - start)
    time = end - start
    yo, loss= network.forward()
    
    ## N - outlier
    pre_train = yo.data.cpu()
    true_train = network.y.data.cpu()
    
    pred_value_train = torch.FloatTensor(sc.inverse_transform(pre_train))
    actual_value_train = torch.FloatTensor(sc.inverse_transform(true_train))
    accuracy_train = accuracy_cacl(pred_value_train,actual_value_train)

    ## B
    pred_value_test = torch.FloatTensor(sc.inverse_transform(network.forecast(x_test).data.cpu()))
    accuracy_test = accuracy_cacl(pred_value_test, y_test)
    
#     total_time = nb_step4 + nb_step6_1 + nb_step6_2
#     print("<<The percentage of each step>>")
#     print("Step 4: %.2f%%"%((nb_step4/total_time)*100))
#     print("Step 6.1: %.2f%%"%((nb_step6_1/total_time)*100))
#     print("Step 6.2: %.2f%%"%((nb_step6_2/total_time)*100))
    
#     print("-"*60)
#     print("Total frequency of cramming occurrences:",nb_step6_2)

#     print("-"*60)
#     print("The amount of hidden node that be pruned:",network.nb_node_pruned)

#     print("-"*60)
    adopted_hidden_node = network.nb_node_acceptable[-1].item()
#     print("The amount of adopted hidden nodes:",network.nb_node_acceptable[-1].item())

#     print("-"*60)
#     print("<<Accuracy in training step>>")
#     print("The MAE for l = 1: %.2f" %(accuracy_train[0]))
#     print("The MAPE for l = 1: %.2f%%" %(accuracy_train[1]))
#     print("The RMSE for l = 1: %.2f" %(accuracy_train[2]))
#     print("The accuracy(2000) for l = 1: %.2f%%" %(accuracy_train[3]*100))
#     print("The accuracy(3000) for l = 1: %.2f%%" %(accuracy_train[4]*100))

    for i in range(pred_value_test.shape[0]):

        date = datetime.date(last_date[0]+timedelta(days=21*(i+1)))
        print("Beginning of this week: %s" %(datetime.date(last_date[0]+timedelta(days=7*(i)))))
        print("The forecasted copper price for the coming third week(%s): %.2f CNY$/Ton" %(date, pred_value_test[i]))
        print("<<Performance measurement>>")
        print("Mean of error: %.2f" %(accuracy_train[0]))
        print("Std of error: %.2f" %(accuracy_train[1]))
        print("The accuracy(3000): %.2f%%" %(accuracy_train[5]*100))
        print("-"*120)

       
              
        training_record = pd.DataFrame({
            
            "Date": [datetime.date(last_date[0]+timedelta(days=7*(i)))],
            "Mean of error": round(accuracy_train[0].item(),2),
            "SD of error": round(accuracy_train[1].item(),2)
        })
        
        performance_record = performance_record.append(training_record)
        
    evaluation_table_train = evaluation_table(evaluation_results_train, block_index, "Training", accuracy_train,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    evaluation_table_test = evaluation_table(evaluation_results_test, block_index, "Inferencing", accuracy_test,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    pre_LDSS = sc.inverse_transform(network.forecast(x_test).data.cpu())
#     pd.DataFrame(pre_LDSS).to_csv("pre_LDSS_%d.csv"%(block_index), index=False)
    
#     plot_result("training",pred_value_train, actual_value_train,block_index)
#     plot_result("inferencing",pred_value_test, y_test,block_index)
#     plot_adopted_node(network,block_index)
    
    return(evaluation_table_train, evaluation_table_test,performance_record)

# %% [markdown]
# ### Preprocessing the data

# %%
def read(path):
    return pd.read_csv(path)

# %%
def buildTrain(train, pastWeek=4, futureWeek=4, defaultWeek=1):
    X_train, Y_train = [], []
    for i in range(train.shape[0]-futureWeek-pastWeek):
        X = np.array(train.iloc[i:i+defaultWeek])
        X = np.append(X,train["CCSP"].iloc[i+defaultWeek:i+pastWeek])
        X_train.append(X.reshape(X.size))
        Y_train.append(np.array(train.iloc[i+pastWeek:i+pastWeek+futureWeek]["CCSP"]))
    return np.array(X_train), np.array(Y_train)

# %% [markdown]
# ### Min-max normalization

# %%
## Use min-max normalization to scale the data to the range from 1 to 0
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ### Design get_data() to get data

# %%
def get_data(futureWeek):
    
    ## Read weekly copper price data
    path = "WeeklyFinalData.csv"
    data = read(path)
    
    date = pd.DataFrame(data["Date"][3:])
    date["Date"] = pd.to_datetime(date["Date"], format="%Y/%m/%d")
#     datetime.strptime("2018-01-31", "%Y-%m-%d")
    data.drop("Date", axis=1, inplace=True)
    
    ## Add time lag (pastWeek=4, futureWeek=1)
    x_data, y_data = buildTrain(data, futureWeek=futureWeek)


    return (date, x_data, y_data)

# %% [markdown]
# ### Network class

# %%
class Network(torch.nn.Module):
    
    def __init__(self, nb_neuro, x_train_scaled, y_train_scaled):
        
        super(Network, self).__init__()
        self.linear1 = torch.nn.Linear(x_train_scaled.shape[1], nb_neuro).cuda()
        self.linear2 = torch.nn.Linear(nb_neuro, 1).cuda()
        
        
        # Stop criteria - threshold
        self.threshold_for_error = 0.12
        self.threshold_for_lr = 1e-4
        
        # Input data 
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
        
        # Learning rate
        self.learning_rate = 1e-3
        
        # Whether the network is acceptable, default as False
        self.acceptable = False
        
        # Some record for experiment
        self.nb_node_pruned = 0
        self.nb_node_acceptable=torch.IntTensor([nb_neuro])
        
        self.limit = nb_neuro
        
    ## Forecast the test data
    def forecast(self, x_test):
    
        x_test = torch.FloatTensor(x_test).cuda()
        activation_value = self.linear1(x_test).clamp(min=0)
        forecast_value = self.linear2(activation_value)
       
        return forecast_value

    ## Reset the x and y data
    def setData(self, x_train_scaled, y_train_scaled):
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
    
    ## Add the new data to the x and y data
    def addData(self, new_x_train, new_y_train):

        self.x = torch.cat([self.x, new_x_train.reshape(1,-1).cuda()],0)
        self.y = torch.cat([self.y, new_y_train.reshape(-1,1).cuda()],0)
    
    ## forward operation
    def forward(self, reg_strength=0):
       
        y1 = self.linear1(self.x).clamp(min=0)
        yo = self.linear2(y1)

        # performance measure
        param_val= torch.sum(torch.pow(self.linear2.bias.data,2))+torch.sum(torch.pow(self.linear2.weight.data,2))+torch.sum(torch.pow(self.linear1.bias.data,2))+torch.sum(torch.pow(self.linear1.weight.data,2))
        reg_term= reg_strength/((self.linear2.bias.data.shape[0]*(self.linear2.weight.data.shape[1]+1)) +(self.linear1.bias.data.shape[0]*(self.linear1.weight.data.shape[1]+1)))*param_val
        loss = torch.nn.functional.mse_loss(yo,self.y)+reg_term
        loss = loss.cuda()
        return(yo, loss)

    # backward operation
    def backward_Adadelta(self,loss):    

        optimizer = optim.Adadelta(self.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### Initializing module (Check)

# %%
def initializing(network, initial_x, initial_y):
#     print("Initializing module")
    ## Find each minimum output value y
    min_y = torch.min(initial_y, axis=0)
    ## Subtract min_y from each y
    res_y = initial_y-min_y.values
    
    ## Use linear regression to find the initial W1,b1,Wo,bo
    reg = LinearRegression().fit(initial_x, res_y)
    
    ## Set up the initial parameter of the network
    network.linear1.weight = torch.nn.Parameter(torch.FloatTensor(reg.coef_).cuda())
    network.linear1.bias = torch.nn.Parameter(torch.FloatTensor(reg.intercept_).cuda())
    network.linear2.weight=torch.nn.Parameter(torch.FloatTensor([[1]]).cuda())
    network.linear2.bias = torch.nn.Parameter(torch.FloatTensor(min_y.values).cuda())
    
#     print(reg.coef_)
#     print(reg.intercept_)

    ## Set up the acceptable of the initial network as True
    network.acceptable =True

# %% [markdown]
# ### Selecting module (Check)

# %%
def selecting(network, x_train_scaled, y_train_scaled):
    
#     print("<<Selecting module>>")
    loss = []
    temp_network = copy.deepcopy(network)
    
    ## Put each data into network to calculate the loss value
    for i in range(x_train_scaled.shape[0]):
        temp_network.setData(x_train_scaled[i].reshape(1,-1), y_train_scaled[i].reshape(-1,1))
        loss.append((temp_network.forward()[1].item(),i))
#         print(network.state_dict())
#         print(temp_network.y)
#         print("-"*20)
#         print(temp_network.forward()[1])
#         print("-"*20)
#     ## Sort the data according to the loss value from smallest to largest, and save the data index in sorted_index
    sorted_index = [sorted_data[1] for sorted_data in sorted(loss, key = lambda x:x[0])]
    
    
    ## Print out some info for debug
#     print("The loss value of k:",loss[sorted_index[0]])
#     print("The second_loss value of k:",loss[sorted_index[1]])
#     print("Selecting module finish!")
#     print("Loss",loss)
#     print(network.state_dict())
    
    return sorted_index

# %% [markdown]
# ### Matching

# %%
def matching(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(10000):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ### Matching for reorganizing

# %%
def matching_for_reorganizing(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module for reorganizing>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(500):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished(o) - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished(o) - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ## Cramming module (Check)

# %%
def cramming(network):
    
    torch.random.manual_seed(0)
#     print("<<Cramming module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Find unsatisfied data:K
    yo, loss = network.forward()
    undesired_index = torch.nonzero(torch.abs(yo-network.y) > network.threshold_for_error+0.001, as_tuple =False)

    ## Print out the undesired_index for debug
#     print("不滿足個數：",undesired_index.shape[0])
#     print("The index of the undesired data:",undesired_index)

    
    if undesired_index.shape[0] == 1:
        
        # Unsatisfied situation
        ## Find the index of the unsatisfied data
        k_data_num = undesired_index[0][0]

        undesired_data = torch.reshape(network.x[k_data_num,:], [1,-1])

        ## Remove the data that does not meet the error term
        left_data = network.x[:k_data_num,:]
        right_data = network.x[k_data_num+1:,:]
        remain_tensor = torch.cat([left_data, right_data], 0)


        ## Use the random method to find out the gamma and zeta
        while True:

            ## Find m-vector gamma: r
            ## Use the random method to generate the gamma that can make the conditions met
            gamma = torch.rand(size=[1,network.x.shape[1]]).cuda()
            subtract_undesired_data = torch.sub(remain_tensor, undesired_data)
            matmul_value = torch.mm(gamma,torch.t(subtract_undesired_data))

            if torch.all(matmul_value != 0):
                break

        while True:

            ## Find the tiny value: zeta
            ## Use the random method to generate the zeta that can make the conditions met
            zeta = torch.rand(size=[1]).cuda()

            if torch.all(torch.mul(torch.add(zeta,matmul_value),torch.sub(zeta,matmul_value))<0):
                break


        k_l = undesired_index[0][1]
        
        ## The weight of input layer to hidden layer I
        w10 = gamma
        w11 = gamma
        w12 = gamma

        W1_new = torch.cat([w10,w11,w12],0)
        

        ## The bias of input layer to hidden layer I
        matual_value = torch.mm(gamma,torch.t(undesired_data))
       
        
        b10 = torch.sub(zeta,matual_value)
        b11 = -1*matual_value
        b12 = torch.sub(-1*zeta,matual_value)

        b1_new = torch.reshape(torch.cat([b10,b11,b12],0),[3])

        ## The weight of hidden layer I to output layer
        gap = network.y[k_data_num, k_l]-yo[k_data_num, k_l]

        wo0_value = gap/zeta
        wo1_value = (-2*gap)/zeta
        wo2_value = gap/zeta

        Wo_new = torch.reshape(torch.cat([wo0_value,wo1_value,wo2_value],0),[1,-1])

        ## Add new neuroes to the network
        network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight.data, W1_new]))
        network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias.data, b1_new]))
        network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight.data, Wo_new],1))


        yo, loss = network.forward()
        
        ## Determine if cramming is successful and print out the corresponding information
        if torch.all(torch.abs(yo-network.y) <= network.threshold_for_error):
            network.acceptable = True 
#             print("Cramming success!")

        else:
#             print("Cramming failed!")
            pass
    
    else:
#         print("條件不合，不能Cramming")
        pass

# %% [markdown]
# ### Regularizing module (Check)

# %%
def regularizing(network):

#     print("<<Regularizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    ## Record the number of executions
    times_enlarge = 0
    times_shrink = 0
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3

    ## Set epoch to 100
    for i in range(100):

        ## Store the parameter of the network
        network_pre = copy.deepcopy(network)
        yo, loss = network.forward(1e-3)
        loss_pre = loss
        
        ## Backward operation to obtain w'
        network.backward_Adadelta(loss)
        yo, loss = network.forward(1e-3)

        # Confirm whether the adjusted loss value is smaller than the current one
        if loss <= loss_pre:
            
            ## Identify that all forecast value has met the error term
            if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):
                
                ## If true, multiply the learning rate by 1.2
                network.learning_rate *= 1.2
                times_enlarge += 1

            else:

                ## Else, restore w and end the process
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-因為沒有顧好預測誤差")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

        # If the adjusted loss value is not smaller than the current one
        else:

            ## If the learning rate is greater than the threshold for learning rate
            if network.learning_rate > network.threshold_for_lr:
                
                ## Restore the w and multiply the learning rate by 0.7
                network = copy.deepcopy(network_pre)
                network.learning_rate *= 0.7
                times_shrink += 1

             ## If the learning rate is smaller than the threshold for learning rate
            else:
                
                ## Restore the w
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-Learning不能這麼小")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

#     print("第\"%d\"回合Regularizing module完畢"%(i+1))
#     print("Number of enlarge:",times_enlarge)
#     print("Number of shrink:",times_shrink)
    return(network)

# %% [markdown]
# ### Reorganizing module (Check)

# %%
def reorganizing(network):
#     print("<<Reorganizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    limit = 4
    if network.linear1.bias.shape[0] <= limit:
        network = regularizing(network)
        return(network)
    
    else:
        
        ## Set up the k = 1, and p = the number of hidden node
        k = 1
    #     p = network.W1.shape[1]
        p = network.linear1.weight.data.shape[0]

        while True:

            ## If k > p, end of Process
            if k > p or p<=limit:

#                 print("Reorganizing result: The final number of neuro is ",p)
                return(network)

            ## Else, Process is ongoing
            else:

                ## Using the regularizing module to adjust the network
                network = regularizing(network)

                ## Store the network and w
                network_pre = copy.deepcopy(network)

                ## Set up the acceptable of the network as false
                network.acceptable = False
                
            
                ## Ignore the K hidden node
                network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight[:k-1],network.linear1.weight[k:]],0))
                network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias[:k-1],network.linear1.bias[k:]]))
                network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight[:,:k-1],network.linear2.weight[:,k:]],1))

                
                ## Using the matching module to adjust the network
                network = matching_for_reorganizing(network)

#                 print("是不是可以不要這個hidden node:",network.acceptable)

                ## If the resulting network is acceptable, this means that the k hidden node can be removed
                if network.acceptable:

#                     print("Drop out the nero number: %d / %d" %(k, p))
                    network.nb_node_pruned += 1
                    ## p--
                    p-=1

                ## Else, it means that the k hidden node cannot be removed
                else:

                    ## Restore the network and w
                    network = copy.deepcopy(network_pre)
#                     print("Cannot drop out the nero number: %d / %d" %(k, p))

                    ## k++
                    k+=1

# %%
evaluation_table_train = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
evaluation_table_test = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
performance_record = pd.DataFrame(columns=["Date","Mean of error", "SD of error"])

date, x_data, y_data= get_data(4)
x_data = sc.fit_transform(x_data)
y_data = sc.fit_transform(y_data[:,2].reshape(-1,1))
threshold_for_error = 8000/(sc.data_max_-sc.data_min_)

data = range(x_data.shape[0])
# window_size => the length of training block
window_size = 212
# step_window => step size of each window
step_window = 4
# the split data
splits = []

## Moving window mechnism
for i in range(window_size, len(data), step_window):
    train = np.array(data[i-window_size:i])
    test = np.array(data[i:i+step_window])
#     test = np.array(data[i-window_size:i+step_window])
    splits.append(('TRAIN:', train, 'TEST:', test))


start = time.time()
for i_block in range(len(splits)):
# for i_block in range(2):
    block_start = time.time()
    ## Record the number of each step
    nb_step4 = 0
    nb_step6_1 = 0
    nb_step6_2 = 0
    
#     print("The <<%d>> Window" %(i_block+1))
    
    x_train = x_data[splits[i_block][1]]
    x_test = x_data[splits[i_block][3]]
    y_train = y_data[splits[i_block][1]]
    y_test = y_data[splits[i_block][3]]
    
    x_train_scaled = torch.FloatTensor(x_train)
    x_test_scaled = torch.FloatTensor(x_test)
    y_train_scaled = torch.FloatTensor(y_train)
    y_test = sc.inverse_transform(y_test)

    if i_block == 0:
        
        lower = torch.mean(y_train_scaled)-torch.std(y_train_scaled)
        upper = torch.mean(y_train_scaled)+torch.std(y_train_scaled)
        nonoutlier_index = torch.nonzero((y_train_scaled[:,0]>lower)&(y_train_scaled[:,0]<upper), as_tuple =False).reshape([-1])
        
        initial_x = x_train_scaled[nonoutlier_index[:19]]
        initial_y = y_train_scaled[nonoutlier_index[:19]]
        
        x_train_scaled = np.delete(x_train_scaled, nonoutlier_index[:19], 0)
        y_train_scaled = np.delete(y_train_scaled, nonoutlier_index[:19], 0)
        
        network = Network(1,initial_x,initial_y)
        
        network.nb_node_acceptable = torch.IntTensor([1 for _ in range(initial_x.shape[0])])
        network.threshold_for_error = round(threshold_for_error[0],2)
        
        initializing(network, initial_x, initial_y)
        
#         print("<<Initializing後看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
#         print("threshold_for_error:",network.threshold_for_error)
        remainder = int(window_size) - initial_x.shape[0]
        nb_step4 += initial_x.shape[0]
        
    else:

        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        restart_index = int(x_train_scaled.shape[0])-step_window
#         print("其他區塊剛開始選的資料索引：",sorted_index[:restart_index])
        init_x = x_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,x_train_scaled.shape[1])
        init_y = y_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,1)
        network.setData(init_x, init_y)
        network.nb_node_acceptable = torch.IntTensor([network.linear1.bias.data.shape[0] for _ in range(init_x.shape[0])])
        network.nb_node_pruned = 0
        
#         print("<<其他區塊剛開始時看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
        
        remainder = int(window_size) - init_x.shape[0]
        x_train_scaled = np.delete(x_train_scaled, sorted_index[:restart_index], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[:restart_index], 0)
        nb_step4 += init_x.shape[0]

    for i in range(remainder):
#     for i in range(3):
        
        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        
        ## Add new data for training     
        network.addData(x_train_scaled[sorted_index[0]], y_train_scaled[sorted_index[0]])
        x_train_scaled = np.delete(x_train_scaled, sorted_index[0], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[0], 0)
        
        yo,loss = network.forward()
        pre_network = copy.deepcopy(network)
        
        if not torch.all(torch.abs(network.y-yo)<=network.threshold_for_error):

            network.acceptable = False
            network = matching(network)
            
            
            if network.acceptable == False:
                
                network = copy.deepcopy(pre_network)
                cramming(network)

                if network.acceptable == False:
                    sys.exit(0)  
                
                nb_step6_2 += 1

            else:
                nb_step6_1 += 1

        else:
            nb_step4 += 1

        network = reorganizing(network)
        yo,loss = network.forward()
        
        network.nb_node_acceptable = torch.cat([network.nb_node_acceptable, torch.IntTensor([network.linear1.bias.data.shape[0]])],0)

#     print("<<The performance of %d window>>"%(i_block+1))
    block_end = time.time()
    evaluation_table_train, evaluation_table_test, performance_record = validation(date.iloc[splits[i_block][1][-1],:], network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled,x_test_scaled, y_test, block_start, block_end,i_block+1,evaluation_table_train,evaluation_table_test,performance_record)

    evaluation_table_train.to_csv("evaluation_table_train.csv",index=False)
    evaluation_table_test.to_csv("evaluation_table_inferencing.csv",index=False)
    performance_record.to_csv("performance.csv", index=False)
# Out:
# The forecasted copper price for the coming third week(2015-11-23): 39308.88 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1644.38
# Std of error: 1335.78
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2015-11-30): 40171.44 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1644.38
# Std of error: 1335.78
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2015-12-07): 41256.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1644.38
# Std of error: 1335.78
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2015-12-14): 41906.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1644.38
# Std of error: 1335.78
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2015-12-21): 40763.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1636.59
# Std of error: 1321.18
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2015-12-28): 39963.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1636.59
# Std of error: 1321.18
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-01-04): 41019.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1636.59
# Std of error: 1321.18
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-01-11): 41289.47 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1636.59
# Std of error: 1321.18
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-01-18): 39662.99 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1603.16
# Std of error: 1288.49
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-01-25): 39774.23 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1603.16
# Std of error: 1288.49
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-02-01): 40255.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1603.16
# Std of error: 1288.49
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-02-08): 41060.80 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1603.16
# Std of error: 1288.49
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-02-15): 40038.29 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1515.06
# Std of error: 1244.90
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-02-22): 40798.47 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1515.06
# Std of error: 1244.90
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-02-29): 41495.87 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1515.06
# Std of error: 1244.90
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-03-07): 42057.91 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1515.06
# Std of error: 1244.90
# The accuracy(3000): 86.32%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-03-14): 41000.89 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1461.86
# Std of error: 1237.14
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-03-21): 40520.59 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1461.86
# Std of error: 1237.14
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-03-28): 40782.20 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1461.86
# Std of error: 1237.14
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-04-04): 40980.04 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1461.86
# Std of error: 1237.14
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-04-11): 40175.23 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1438.31
# Std of error: 1257.63
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-04-18): 39903.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1438.31
# Std of error: 1257.63
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-04-25): 39718.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1438.31
# Std of error: 1257.63
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-05-02): 39593.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1438.31
# Std of error: 1257.63
# The accuracy(3000): 88.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-05-09): 38491.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1430.44
# Std of error: 1286.50
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-05-16): 38395.86 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1430.44
# Std of error: 1286.50
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-05-23): 38591.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1430.44
# Std of error: 1286.50
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-05-30): 38302.41 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1430.44
# Std of error: 1286.50
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-06-06): 38248.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1404.14
# Std of error: 1259.34
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-06-13): 38930.23 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1404.14
# Std of error: 1259.34
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-06-20): 39587.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1404.14
# Std of error: 1259.34
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-06-27): 40231.48 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1404.14
# Std of error: 1259.34
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-07-04): 40174.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1399.54
# Std of error: 1225.32
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-07-11): 39732.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1399.54
# Std of error: 1225.32
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-07-18): 39285.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1399.54
# Std of error: 1225.32
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-07-25): 38618.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1399.54
# Std of error: 1225.32
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-08-01): 38011.09 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1401.56
# Std of error: 1200.91
# The accuracy(3000): 89.15%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-08-08): 37989.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1401.56
# Std of error: 1200.91
# The accuracy(3000): 89.15%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-08-15): 38266.74 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1401.56
# Std of error: 1200.91
# The accuracy(3000): 89.15%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-08-22): 37746.63 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1401.56
# Std of error: 1200.91
# The accuracy(3000): 89.15%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-08-29): 37022.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.40
# Std of error: 1190.90
# The accuracy(3000): 89.62%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-09-05): 37076.03 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.40
# Std of error: 1190.90
# The accuracy(3000): 89.62%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-09-12): 37358.42 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.40
# Std of error: 1190.90
# The accuracy(3000): 89.62%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-09-19): 37567.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.40
# Std of error: 1190.90
# The accuracy(3000): 89.62%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-09-26): 37655.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1328.09
# Std of error: 1160.49
# The accuracy(3000): 90.09%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-10-03): 37559.74 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1328.09
# Std of error: 1160.49
# The accuracy(3000): 90.09%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-10-10): 38258.64 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1328.09
# Std of error: 1160.49
# The accuracy(3000): 90.09%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-10-17): 39143.76 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1328.09
# Std of error: 1160.49
# The accuracy(3000): 90.09%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-10-24): 41288.06 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1414.07
# Std of error: 1376.29
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-10-31): 42569.01 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1414.07
# Std of error: 1376.29
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-11-07): 43517.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1414.07
# Std of error: 1376.29
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-11-14): 43999.16 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1414.07
# Std of error: 1376.29
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-11-21): 44277.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1448.31
# Std of error: 1411.08
# The accuracy(3000): 87.74%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-11-28): 43595.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1448.31
# Std of error: 1411.08
# The accuracy(3000): 87.74%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-12-05): 43077.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1448.31
# Std of error: 1411.08
# The accuracy(3000): 87.74%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-12-12): 42758.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1448.31
# Std of error: 1411.08
# The accuracy(3000): 87.74%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-12-19): 43245.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1484.69
# Std of error: 1413.96
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2016-12-26): 44121.86 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1484.69
# Std of error: 1413.96
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-01-02): 44370.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1484.69
# Std of error: 1413.96
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-01-09): 44606.89 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1484.69
# Std of error: 1413.96
# The accuracy(3000): 87.26%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-01-16): 45379.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1504.19
# Std of error: 1409.02
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-01-23): 46008.48 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1504.19
# Std of error: 1409.02
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-01-30): 46056.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1504.19
# Std of error: 1409.02
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-02-06): 45929.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1504.19
# Std of error: 1409.02
# The accuracy(3000): 85.85%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-02-13): 46400.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1447.60
# Std of error: 1373.49
# The accuracy(3000): 86.79%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-02-20): 46258.74 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1447.60
# Std of error: 1373.49
# The accuracy(3000): 86.79%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-02-27): 46302.84 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1447.60
# Std of error: 1373.49
# The accuracy(3000): 86.79%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-03-06): 46016.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1447.60
# Std of error: 1373.49
# The accuracy(3000): 86.79%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-03-13): 46287.79 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1371.97
# Std of error: 1323.68
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-03-20): 46472.47 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1371.97
# Std of error: 1323.68
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-03-27): 46282.90 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1371.97
# Std of error: 1323.68
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-04-03): 46718.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1371.97
# Std of error: 1323.68
# The accuracy(3000): 88.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-04-10): 47166.12 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1318.54
# Std of error: 1279.01
# The accuracy(3000): 91.04%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-04-17): 47083.77 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1318.54
# Std of error: 1279.01
# The accuracy(3000): 91.04%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-04-24): 46728.88 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1318.54
# Std of error: 1279.01
# The accuracy(3000): 91.04%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-05-01): 46669.22 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1318.54
# Std of error: 1279.01
# The accuracy(3000): 91.04%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-05-08): 46207.67 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1296.72
# Std of error: 1238.31
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-05-15): 46602.95 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1296.72
# Std of error: 1238.31
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-05-22): 46612.55 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1296.72
# Std of error: 1238.31
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-05-29): 46380.23 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1296.72
# Std of error: 1238.31
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-06-05): 46695.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.37
# Std of error: 1200.90
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-06-12): 46942.38 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.37
# Std of error: 1200.90
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-06-19): 46952.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.37
# Std of error: 1200.90
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-06-26): 46972.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.37
# Std of error: 1200.90
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-07-03): 47756.11 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1248.60
# Std of error: 1151.21
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-07-10): 48307.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1248.60
# Std of error: 1151.21
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-07-17): 49106.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1248.60
# Std of error: 1151.21
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-07-24): 49526.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1248.60
# Std of error: 1151.21
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-07-31): 50161.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1286.13
# Std of error: 1156.34
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-08-07): 50674.78 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1286.13
# Std of error: 1156.34
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-08-14): 51180.08 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1286.13
# Std of error: 1156.34
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-08-21): 51111.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1286.13
# Std of error: 1156.34
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-08-28): 50717.22 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1280.27
# Std of error: 1139.82
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-09-04): 49846.87 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1280.27
# Std of error: 1139.82
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-09-11): 50069.59 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1280.27
# Std of error: 1139.82
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-09-18): 50903.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1280.27
# Std of error: 1139.82
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-09-25): 51850.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1342.62
# Std of error: 1174.36
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-10-02): 51850.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1342.62
# Std of error: 1174.36
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-10-09): 51850.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1342.62
# Std of error: 1174.36
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-10-16): 51850.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1342.62
# Std of error: 1174.36
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-10-23): 52027.24 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.53
# Std of error: 1150.03
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-10-30): 52027.24 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.53
# Std of error: 1150.03
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-11-06): 52027.24 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.53
# Std of error: 1150.03
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-11-13): 52027.24 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1368.53
# Std of error: 1150.03
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-11-20): 51697.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1357.22
# Std of error: 1149.93
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-11-27): 51822.49 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1357.22
# Std of error: 1149.93
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-12-04): 52182.51 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1357.22
# Std of error: 1149.93
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-12-11): 52498.13 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1357.22
# Std of error: 1149.93
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-12-18): 52760.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1379.81
# Std of error: 1145.75
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2017-12-25): 52760.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1379.81
# Std of error: 1145.75
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-01-01): 52760.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1379.81
# Std of error: 1145.75
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-01-08): 52628.79 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1379.81
# Std of error: 1145.75
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-01-15): 51891.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1373.40
# Std of error: 1142.69
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-01-22): 51302.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1373.40
# Std of error: 1142.69
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-01-29): 50751.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1373.40
# Std of error: 1142.69
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-02-05): 50726.67 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1373.40
# Std of error: 1142.69
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-02-12): 50964.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1374.12
# Std of error: 1134.08
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-02-19): 51079.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1374.12
# Std of error: 1134.08
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-02-26): 50459.88 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1374.12
# Std of error: 1134.08
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-03-05): 49636.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1374.12
# Std of error: 1134.08
# The accuracy(3000): 92.45%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-03-12): 49298.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.66
# Std of error: 1093.33
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-03-19): 49563.49 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.66
# Std of error: 1093.33
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-03-26): 49391.84 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.66
# Std of error: 1093.33
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-04-02): 49779.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.66
# Std of error: 1093.33
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-04-09): 51335.56 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1338.35
# Std of error: 1088.29
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-04-16): 52024.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1338.35
# Std of error: 1088.29
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-04-23): 51282.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1338.35
# Std of error: 1088.29
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-04-30): 51448.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1338.35
# Std of error: 1088.29
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-05-07): 51487.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1325.94
# Std of error: 1084.01
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-05-14): 51643.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1325.94
# Std of error: 1084.01
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-05-21): 52252.20 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1325.94
# Std of error: 1084.01
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-05-28): 52295.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1325.94
# Std of error: 1084.01
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-06-04): 51747.59 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.95
# Std of error: 1089.40
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-06-11): 50844.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.95
# Std of error: 1089.40
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-06-18): 50230.20 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.95
# Std of error: 1089.40
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-06-25): 50298.83 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1333.95
# Std of error: 1089.40
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-07-02): 50263.25 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1330.87
# Std of error: 1094.45
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-07-09): 50732.02 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1330.87
# Std of error: 1094.45
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-07-16): 51041.87 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1330.87
# Std of error: 1094.45
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-07-23): 51342.12 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1330.87
# Std of error: 1094.45
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-07-30): 51184.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1359.10
# Std of error: 1095.80
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-08-06): 51130.39 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1359.10
# Std of error: 1095.80
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-08-13): 51089.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1359.10
# Std of error: 1095.80
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-08-20): 50763.26 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1359.10
# Std of error: 1095.80
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-08-27): 51100.89 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1364.96
# Std of error: 1099.12
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-09-03): 51290.80 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1364.96
# Std of error: 1099.12
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-09-10): 51892.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1364.96
# Std of error: 1099.12
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-09-17): 52241.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1364.96
# Std of error: 1099.12
# The accuracy(3000): 92.92%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-09-24): 52364.99 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1376.65
# Std of error: 1095.83
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-10-01): 52342.40 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1376.65
# Std of error: 1095.83
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-10-08): 51633.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1376.65
# Std of error: 1095.83
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-10-15): 51473.12 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1376.65
# Std of error: 1095.83
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-10-22): 50751.87 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1393.20
# Std of error: 1102.64
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-10-29): 50543.44 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1393.20
# Std of error: 1102.64
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-11-05): 50867.96 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1393.20
# Std of error: 1102.64
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-11-12): 50647.69 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1393.20
# Std of error: 1102.64
# The accuracy(3000): 93.40%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2018-11-19): 50526.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1385.52
# Std of error: 1104.58
# The accuracy(3000): 93.40%
# ...
# The forecasted copper price for the coming third week(2019-11-11): 46692.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1239.37
# Std of error: 1032.92
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-11-18): 47161.63 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1213.96
# Std of error: 982.08
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-11-25): 47387.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1213.96
# Std of error: 982.08
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-12-02): 48280.60 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1213.96
# Std of error: 982.08
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-12-09): 48527.80 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1213.96
# Std of error: 982.08
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-12-16): 48518.62 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1199.80
# Std of error: 990.28
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-12-23): 48656.11 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1199.80
# Std of error: 990.28
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2019-12-30): 48472.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1199.80
# Std of error: 990.28
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-01-06): 47402.55 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1199.80
# Std of error: 990.28
# The accuracy(3000): 96.70%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-01-13): 45943.25 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1212.70
# Std of error: 1010.61
# The accuracy(3000): 96.23%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-01-20): 46016.70 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1212.70
# Std of error: 1010.61
# The accuracy(3000): 96.23%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-01-27): 45816.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1212.70
# Std of error: 1010.61
# The accuracy(3000): 96.23%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-02-03): 45679.01 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1212.70
# Std of error: 1010.61
# The accuracy(3000): 96.23%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-02-10): 45095.16 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1225.13
# Std of error: 1044.49
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-02-17): 44662.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1225.13
# Std of error: 1044.49
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-02-24): 43542.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1225.13
# Std of error: 1044.49
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-03-02): 41955.33 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1225.13
# Std of error: 1044.49
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-03-09): 40249.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1233.73
# Std of error: 1152.94
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-03-16): 40728.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1233.73
# Std of error: 1152.94
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-03-23): 41691.81 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1233.73
# Std of error: 1152.94
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-03-30): 41958.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1233.73
# Std of error: 1152.94
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-04-06): 42908.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1249.56
# Std of error: 1131.67
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-04-13): 43604.09 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1249.56
# Std of error: 1131.67
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-04-20): 43834.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1249.56
# Std of error: 1131.67
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-04-27): 44421.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1249.56
# Std of error: 1131.67
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-05-04): 44809.03 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.33
# Std of error: 1104.63
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-05-11): 45343.33 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.33
# Std of error: 1104.63
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-05-18): 46361.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.33
# Std of error: 1104.63
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-05-25): 47198.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1259.33
# Std of error: 1104.63
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-06-01): 48160.56 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1270.99
# Std of error: 1101.17
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-06-08): 49013.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1270.99
# Std of error: 1101.17
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-06-15): 49426.26 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1270.99
# Std of error: 1101.17
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-06-22): 50199.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1270.99
# Std of error: 1101.17
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-06-29): 51291.08 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1288.02
# Std of error: 1104.66
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-07-06): 51291.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1288.02
# Std of error: 1104.66
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-07-13): 51154.22 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1288.02
# Std of error: 1104.66
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-07-20): 50405.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1288.02
# Std of error: 1104.66
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-07-27): 50817.42 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1264.99
# Std of error: 1098.03
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-08-03): 49942.23 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1264.99
# Std of error: 1098.03
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-08-10): 49102.51 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1264.99
# Std of error: 1098.03
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-08-17): 49137.32 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1264.99
# Std of error: 1098.03
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-08-24): 49232.38 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1242.80
# Std of error: 1071.48
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-08-31): 48892.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1242.80
# Std of error: 1071.48
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-09-07): 48738.47 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1242.80
# Std of error: 1071.48
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-09-14): 48560.52 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1242.80
# Std of error: 1071.48
# The accuracy(3000): 94.81%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-09-21): 49543.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.06
# Std of error: 1056.30
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-09-28): 50097.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.06
# Std of error: 1056.30
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-10-05): 49928.49 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.06
# Std of error: 1056.30
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-10-12): 49849.20 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.06
# Std of error: 1056.30
# The accuracy(3000): 95.28%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-10-19): 50584.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.25
# Std of error: 1040.13
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-10-26): 51274.96 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.25
# Std of error: 1040.13
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
# The forecasted copper price for the coming third week(2020-11-02): 52499.42 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1254.25
# Std of error: 1040.13
# The accuracy(3000): 95.75%
# ------------------------------------------------------------------------------------------------------------------------
