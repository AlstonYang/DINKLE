# %% [markdown]
# ### Import related package

# %%
## Import tensorflow package for modeling
import torch
from torch.autograd import Variable
import torch.optim as optim

## Data processing
import pandas as pd
import numpy as np

## Min-max normalization
from sklearn.preprocessing import MinMaxScaler

## Plot the graph
import matplotlib.pyplot as plt
# %matplotlib inline

## Initializing module
from sklearn.linear_model import LinearRegression
np.set_printoptions(suppress=True)

## Copy module
import copy

## Used to calculate the training time
import time

## Set the GUP environment
import os
import sys

from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker

# %%
os.chdir('/home/Oring-AI/Model_I/DINKLE/t+1')

# %%
## Set up the display
torch.set_printoptions(sci_mode=False)

# %% [markdown]
# ### Control memory usage space for GPU

# %%
## 查詢有無可用 GPU
torch.cuda.is_available()
## 查詢可用 GPU 的數量
torch.cuda.device_count()
##目前設備
print("目前設備：",torch.cuda.current_device())
## 目前設備名
print("目前設備名：",torch.cuda.get_device_name(0))
# Out:
# 目前設備： 0
# 目前設備名： GeForce GTX 1070 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# ## Print out some info

# %%
def accuracy_cacl(pred_value, actual_value):
    
#     yo, loss, tape = network.forward()
    performance = []
    performance.append(torch.mean(torch.abs(pred_value - actual_value)))
    performance.append(torch.std(torch.abs(pred_value - actual_value)))
    performance.append(torch.mean(torch.abs((pred_value - actual_value) / actual_value))) 
    performance.append(torch.sqrt(torch.mean((pred_value - actual_value)**2)))
    
    for i in range(2000,3001,1000):
        correct_times = torch.nonzero(torch.abs(pred_value - actual_value) <= i, as_tuple =False)
        accuracy = correct_times.shape[0]/pred_value.shape[0]
        performance.append(accuracy)
                       
    return performance

# %%
def plot_result(name, pred_value, actual_value,block_index):
    
#     fig, ax = plt.subplots(2,2,figsize=(20,10), sharex=True, sharey=True)
    fig, ax = plt.subplots(1,figsize=(20,10), sharex=True, sharey=True)
#     ax.set_xlim(0,pred_value.shape[0])  
    
    
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.plot(pred_value, label="LLAAT")
    ax.plot(actual_value, label="Actual")
    ax.set_title("Forecasted performance for l=%d" %(1))
    ax.legend()
        
    #fig.text(0.5, 0, "Stage of training", ha='center', fontsize=20)
    #fig.text(0, 0.5, "Copper price value", va='center', rotation='vertical')

    fig.suptitle("In the %s process in the M=%d window"%(name, block_index))
    fig.tight_layout()
#     fig.savefig("In the %s process in the M=%d window.png"%(name, block_index),dpi=300,bbox_inches='tight')

# %%
def plot_adopted_node(network,block_index):
    
    fig, ax = plt.subplots(figsize=(20,5))
#     ax.set_xticklabels([i for i in range(network.nb_node_acceptable.shape[0]+5)])
    
    ax.set_title("Total amount of adopted hidden nodes in the training process in the M=%d window"%(block_index))
    ax.plot(network.nb_node_acceptable,"-o")

    ax.set_xlabel("Stage of training")
    ax.set_ylabel("Hidden nodes")
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
#     fig.savefig("hidden nodes in the training process in the M=%d window"%(block_index),dpi=300,bbox_inches='tight')

# %%
def evaluation_table(evaluation_results, block_index, name, performance, nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node):

    
    new_result = pd.DataFrame({

        "Window_index":block_index,
        "Stage":name,
        "MAE" : round(performance[0].item(),2),
        "SD of absolute error":round(performance[1].item(),2),
        "MAPE" : "%.2f"%(performance[2]*100).item(),
        "RMSE" : round(performance[3].item(),2),
#         "Accuracy(2000)" : [round(performance[4]*100,2)],
        "Accuracy(3000)" : [round(performance[5]*100,2)],
        "Step4":nb_step4,
        "Step6.1":nb_step6_1,
        "Step6.2":nb_step6_2,
        "Time":time,
        "Adopted_hidden_node":adopted_hidden_node
    })

    evaluation_results = evaluation_results.append(new_result, ignore_index=True)
    
    return evaluation_results

# %%
def validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled, x_test, y_test, start, end, block_index, evaluation_results_train, evaluation_results_test):

    ## Training_Step
#    print("<<Training step>>")
    print("The training time(s):",end - start)
    time = end - start
    yo, loss= network.forward()
    
    ## N - outlier
    pre_train = yo.data.cpu()
    true_train = network.y.data.cpu()
    
    pred_value_train = torch.FloatTensor(sc.inverse_transform(pre_train))
    actual_value_train = torch.FloatTensor(sc.inverse_transform(true_train))
    accuracy_train = accuracy_cacl(pred_value_train,actual_value_train)

    ## B
    pred_value_test = torch.FloatTensor(sc.inverse_transform(network.forecast(x_test).data.cpu()))
    accuracy_test = accuracy_cacl(pred_value_test, y_test)
    
#     total_time = nb_step4 + nb_step6_1 + nb_step6_2
#     print("<<The percentage of each step>>")
#     print("Step 4: %.2f%%"%((nb_step4/total_time)*100))
#     print("Step 6.1: %.2f%%"%((nb_step6_1/total_time)*100))
#     print("Step 6.2: %.2f%%"%((nb_step6_2/total_time)*100))
    
#     print("-"*60)
#     print("Total frequency of cramming occurrences:",nb_step6_2)

#     print("-"*60)
#     print("The amount of hidden node that be pruned:",network.nb_node_pruned)

#     print("-"*60)
    adopted_hidden_node = network.nb_node_acceptable[-1].item()
#     print("The amount of adopted hidden nodes:",network.nb_node_acceptable[-1].item())

#     print("-"*60)
#     print("<<Accuracy in training step>>")
#     print("The MAE for l = 1: %.2f" %(accuracy_train[0]))
#     print("The MAPE for l = 1: %.2f%%" %(accuracy_train[1]))
#     print("The RMSE for l = 1: %.2f" %(accuracy_train[2]))
#     print("The accuracy(2000) for l = 1: %.2f%%" %(accuracy_train[3]*100))
#     print("The accuracy(3000) for l = 1: %.2f%%" %(accuracy_train[4]*100))

    print("The forecast copper price for the first week:", pred_value_test[-4:].tolist())
    print("<<Performance measurement>>")
    print("The MAE: %.1f" %(accuracy_test[0]))
    print("The standard deviation of absolute error: %.1f" %(accuracy_test[1]))
    print("The MAPE: %.1f%%" %(accuracy_test[2]))
    print("The RMSE: %.1f" %(accuracy_test[3]))
#    print("The accuracy(2000) for l = 1: %.1f%%" %(accuracy_test[4]*100))
    print("The accuracy(3000): %.1f%%" %(accuracy_test[5]*100))
    print("-"*120)

    
    evaluation_table_train = evaluation_table(evaluation_results_train, block_index, "Training", accuracy_train,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    evaluation_table_test = evaluation_table(evaluation_results_test, block_index, "Inferencing", accuracy_test,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    pre_LDSS = sc.inverse_transform(network.forecast(x_test).data.cpu())
#     pd.DataFrame(pre_LDSS).to_csv("pre_LDSS_%d.csv"%(block_index), index=False)
    
#     plot_result("training",pred_value_train, actual_value_train,block_index)
#     plot_result("inferencing",pred_value_test, y_test,block_index)
#     plot_adopted_node(network,block_index)
    
    return(evaluation_table_train, evaluation_table_test)

# %% [markdown]
# ### Preprocessing the data

# %%
def read(path):
    return pd.read_csv(path)

# %%
def buildTrain(train, pastWeek=4, futureWeek=4, defaultWeek=1):
    X_train, Y_train = [], []
    for i in range(train.shape[0]-futureWeek-pastWeek):
        X = np.array(train.iloc[i:i+defaultWeek])
        X = np.append(X,train["CCSP"].iloc[i+defaultWeek:i+pastWeek])
        X_train.append(X.reshape(X.size))
        Y_train.append(np.array(train.iloc[i+pastWeek:i+pastWeek+futureWeek]["CCSP"]))
    return np.array(X_train), np.array(Y_train)

# %% [markdown]
# ### Min-max normalization

# %%
## Use min-max normalization to scale the data to the range from 1 to 0
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ### Design get_data() to get data

# %%
def get_data(futureWeek):
    
    ## Read weekly copper price data
    path = "WeeklyFinalData.csv"
    data = read(path)
    
    date = data["Date"]
    data.drop("Date", axis=1, inplace=True)
    
    ## Add time lag (pastWeek=4, futureWeek=1)
    x_data, y_data = buildTrain(data, futureWeek=futureWeek)


    return (x_data, y_data)

# %% [markdown]
# ### Network class

# %%
class Network(torch.nn.Module):
    
    def __init__(self, nb_neuro, x_train_scaled, y_train_scaled):
        
        super(Network, self).__init__()
        self.linear1 = torch.nn.Linear(x_train_scaled.shape[1], nb_neuro).cuda()
        self.linear2 = torch.nn.Linear(nb_neuro, 1).cuda()
        
        
        # Stop criteria - threshold
        self.threshold_for_error = 0.12
        self.threshold_for_lr = 1e-4
        
        # Input data 
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
        
        # Learning rate
        self.learning_rate = 1e-3
        
        # Whether the network is acceptable, default as False
        self.acceptable = False
        
        # Some record for experiment
        self.nb_node_pruned = 0
        self.nb_node_acceptable=torch.IntTensor([nb_neuro])
        
        self.limit = nb_neuro
        
    ## Forecast the test data
    def forecast(self, x_test):
    
        x_test = torch.FloatTensor(x_test).cuda()
        activation_value = self.linear1(x_test).clamp(min=0)
        forecast_value = self.linear2(activation_value)
       
        return forecast_value

    ## Reset the x and y data
    def setData(self, x_train_scaled, y_train_scaled):
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
    
    ## Add the new data to the x and y data
    def addData(self, new_x_train, new_y_train):

        self.x = torch.cat([self.x, new_x_train.reshape(1,-1).cuda()],0)
        self.y = torch.cat([self.y, new_y_train.reshape(-1,1).cuda()],0)
    
    ## forward operation
    def forward(self, reg_strength=0):
       
        y1 = self.linear1(self.x).clamp(min=0)
        yo = self.linear2(y1)

        # performance measure
        param_val= torch.sum(torch.pow(self.linear2.bias.data,2))+torch.sum(torch.pow(self.linear2.weight.data,2))+torch.sum(torch.pow(self.linear1.bias.data,2))+torch.sum(torch.pow(self.linear1.weight.data,2))
        reg_term= reg_strength/((self.linear2.bias.data.shape[0]*(self.linear2.weight.data.shape[1]+1)) +(self.linear1.bias.data.shape[0]*(self.linear1.weight.data.shape[1]+1)))*param_val
        loss = torch.nn.functional.mse_loss(yo,self.y)+reg_term
        loss = loss.cuda()
        return(yo, loss)

    # backward operation
    def backward_Adadelta(self,loss):    

        optimizer = optim.Adadelta(self.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### Initializing module (Check)

# %%
def initializing(network, initial_x, initial_y):
#     print("Initializing module")
    ## Find each minimum output value y
    min_y = torch.min(initial_y, axis=0)
    ## Subtract min_y from each y
    res_y = initial_y-min_y.values
    
    ## Use linear regression to find the initial W1,b1,Wo,bo
    reg = LinearRegression().fit(initial_x, res_y)
    
    ## Set up the initial parameter of the network
    network.linear1.weight = torch.nn.Parameter(torch.FloatTensor(reg.coef_).cuda())
    network.linear1.bias = torch.nn.Parameter(torch.FloatTensor(reg.intercept_).cuda())
    network.linear2.weight=torch.nn.Parameter(torch.FloatTensor([[1]]).cuda())
    network.linear2.bias = torch.nn.Parameter(torch.FloatTensor(min_y.values).cuda())
    
#     print(reg.coef_)
#     print(reg.intercept_)

    ## Set up the acceptable of the initial network as True
    network.acceptable =True

# %% [markdown]
# ### Selecting module (Check)

# %%
def selecting(network, x_train_scaled, y_train_scaled):
    
#     print("<<Selecting module>>")
    loss = []
    temp_network = copy.deepcopy(network)
    
    ## Put each data into network to calculate the loss value
    for i in range(x_train_scaled.shape[0]):
        temp_network.setData(x_train_scaled[i].reshape(1,-1), y_train_scaled[i].reshape(-1,1))
        loss.append((temp_network.forward()[1].item(),i))
#         print(network.state_dict())
#         print(temp_network.y)
#         print("-"*20)
#         print(temp_network.forward()[1])
#         print("-"*20)
#     ## Sort the data according to the loss value from smallest to largest, and save the data index in sorted_index
    sorted_index = [sorted_data[1] for sorted_data in sorted(loss, key = lambda x:x[0])]
    
    
    ## Print out some info for debug
#     print("The loss value of k:",loss[sorted_index[0]])
#     print("The second_loss value of k:",loss[sorted_index[1]])
#     print("Selecting module finish!")
#     print("Loss",loss)
#     print(network.state_dict())
    
    return sorted_index

# %% [markdown]
# ### Matching

# %%
def matching(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(10000):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ### Matching for reorganizing

# %%
def matching_for_reorganizing(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module for reorganizing>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(500):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished(o) - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished(o) - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ## Cramming module (Check)

# %%
def cramming(network):
    
    torch.random.manual_seed(0)
#     print("<<Cramming module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Find unsatisfied data:K
    yo, loss = network.forward()
    undesired_index = torch.nonzero(torch.abs(yo-network.y) > network.threshold_for_error+0.001, as_tuple =False)

    ## Print out the undesired_index for debug
#     print("不滿足個數：",undesired_index.shape[0])
#     print("The index of the undesired data:",undesired_index)

    
    if undesired_index.shape[0] == 1:
        
        # Unsatisfied situation
        ## Find the index of the unsatisfied data
        k_data_num = undesired_index[0][0]

        undesired_data = torch.reshape(network.x[k_data_num,:], [1,-1])

        ## Remove the data that does not meet the error term
        left_data = network.x[:k_data_num,:]
        right_data = network.x[k_data_num+1:,:]
        remain_tensor = torch.cat([left_data, right_data], 0)


        ## Use the random method to find out the gamma and zeta
        while True:

            ## Find m-vector gamma: r
            ## Use the random method to generate the gamma that can make the conditions met
            gamma = torch.rand(size=[1,network.x.shape[1]]).cuda()
            subtract_undesired_data = torch.sub(remain_tensor, undesired_data)
            matmul_value = torch.mm(gamma,torch.t(subtract_undesired_data))

            if torch.all(matmul_value != 0):
                break

        while True:

            ## Find the tiny value: zeta
            ## Use the random method to generate the zeta that can make the conditions met
            zeta = torch.rand(size=[1]).cuda()

            if torch.all(torch.mul(torch.add(zeta,matmul_value),torch.sub(zeta,matmul_value))<0):
                break


        k_l = undesired_index[0][1]
        
        ## The weight of input layer to hidden layer I
        w10 = gamma
        w11 = gamma
        w12 = gamma

        W1_new = torch.cat([w10,w11,w12],0)
        

        ## The bias of input layer to hidden layer I
        matual_value = torch.mm(gamma,torch.t(undesired_data))
       
        
        b10 = torch.sub(zeta,matual_value)
        b11 = -1*matual_value
        b12 = torch.sub(-1*zeta,matual_value)

        b1_new = torch.reshape(torch.cat([b10,b11,b12],0),[3])

        ## The weight of hidden layer I to output layer
        gap = network.y[k_data_num, k_l]-yo[k_data_num, k_l]

        wo0_value = gap/zeta
        wo1_value = (-2*gap)/zeta
        wo2_value = gap/zeta

        Wo_new = torch.reshape(torch.cat([wo0_value,wo1_value,wo2_value],0),[1,-1])

        ## Add new neuroes to the network
        network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight.data, W1_new]))
        network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias.data, b1_new]))
        network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight.data, Wo_new],1))


        yo, loss = network.forward()
        
        ## Determine if cramming is successful and print out the corresponding information
        if torch.all(torch.abs(yo-network.y) <= network.threshold_for_error):
            network.acceptable = True 
#             print("Cramming success!")

        else:
#             print("Cramming failed!")
            pass
    
    else:
#         print("條件不合，不能Cramming")
        pass

# %% [markdown]
# ### Regularizing module (Check)

# %%
def regularizing(network):

#     print("<<Regularizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    ## Record the number of executions
    times_enlarge = 0
    times_shrink = 0
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3

    ## Set epoch to 100
    for i in range(100):

        ## Store the parameter of the network
        network_pre = copy.deepcopy(network)
        yo, loss = network.forward(1e-3)
        loss_pre = loss
        
        ## Backward operation to obtain w'
        network.backward_Adadelta(loss)
        yo, loss = network.forward(1e-3)

        # Confirm whether the adjusted loss value is smaller than the current one
        if loss <= loss_pre:
            
            ## Identify that all forecast value has met the error term
            if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):
                
                ## If true, multiply the learning rate by 1.2
                network.learning_rate *= 1.2
                times_enlarge += 1

            else:

                ## Else, restore w and end the process
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-因為沒有顧好預測誤差")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

        # If the adjusted loss value is not smaller than the current one
        else:

            ## If the learning rate is greater than the threshold for learning rate
            if network.learning_rate > network.threshold_for_lr:
                
                ## Restore the w and multiply the learning rate by 0.7
                network = copy.deepcopy(network_pre)
                network.learning_rate *= 0.7
                times_shrink += 1

             ## If the learning rate is smaller than the threshold for learning rate
            else:
                
                ## Restore the w
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-Learning不能這麼小")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

#     print("第\"%d\"回合Regularizing module完畢"%(i+1))
#     print("Number of enlarge:",times_enlarge)
#     print("Number of shrink:",times_shrink)
    return(network)

# %% [markdown]
# ### Reorganizing module (Check)

# %%
def reorganizing(network):
#     print("<<Reorganizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    limit = 4
    if network.linear1.bias.shape[0] <= limit:
        network = regularizing(network)
        return(network)
    
    else:
        
        ## Set up the k = 1, and p = the number of hidden node
        k = 1
    #     p = network.W1.shape[1]
        p = network.linear1.weight.data.shape[0]

        while True:

            ## If k > p, end of Process
            if k > p or p<=limit:

#                 print("Reorganizing result: The final number of neuro is ",p)
                return(network)

            ## Else, Process is ongoing
            else:

                ## Using the regularizing module to adjust the network
                network = regularizing(network)

                ## Store the network and w
                network_pre = copy.deepcopy(network)

                ## Set up the acceptable of the network as false
                network.acceptable = False
                
            
                ## Ignore the K hidden node
                network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight[:k-1],network.linear1.weight[k:]],0))
                network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias[:k-1],network.linear1.bias[k:]]))
                network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight[:,:k-1],network.linear2.weight[:,k:]],1))

                
                ## Using the matching module to adjust the network
                network = matching_for_reorganizing(network)

#                 print("是不是可以不要這個hidden node:",network.acceptable)

                ## If the resulting network is acceptable, this means that the k hidden node can be removed
                if network.acceptable:

#                     print("Drop out the nero number: %d / %d" %(k, p))
                    network.nb_node_pruned += 1
                    ## p--
                    p-=1

                ## Else, it means that the k hidden node cannot be removed
                else:

                    ## Restore the network and w
                    network = copy.deepcopy(network_pre)
#                     print("Cannot drop out the nero number: %d / %d" %(k, p))

                    ## k++
                    k+=1

# %%
evaluation_table_train = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
evaluation_table_test = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
    
x_data, y_data= get_data(4)
x_data = sc.fit_transform(x_data)
y_data = sc.fit_transform(y_data[:,0].reshape(-1,1))
threshold_for_error = 6000/(sc.data_max_-sc.data_min_)

data = range(x_data.shape[0])
# window_size => the length of training block
window_size = 212
# step_window => step size of each window
step_window = 4
# the split data
splits = []

## Moving window mechnism
for i in range(window_size, len(data), step_window):
    train = np.array(data[i-window_size:i])
    test = np.array(data[i-window_size:i+step_window])
#     test = np.array(data[i-window_size:i+step_window])
    splits.append(('TRAIN:', train, 'TEST:', test))


start = time.time()
for i_block in range(len(splits)):
# for i_block in range(2):
    block_start = time.time()
    ## Record the number of each step
    nb_step4 = 0
    nb_step6_1 = 0
    nb_step6_2 = 0
    
    print("The <<%d>> Window" %(i_block+1))
    
    x_train = x_data[splits[i_block][1]]
    x_test = x_data[splits[i_block][3]]
    y_train = y_data[splits[i_block][1]]
    y_test = y_data[splits[i_block][3]]
    
    x_train_scaled = torch.FloatTensor(x_train)
    x_test_scaled = torch.FloatTensor(x_test)
    y_train_scaled = torch.FloatTensor(y_train)
    y_test = sc.inverse_transform(y_test)

    if i_block == 0:
        
        lower = torch.mean(y_train_scaled)-0.1*torch.std(y_train_scaled)
        upper = torch.mean(y_train_scaled)+0.1*torch.std(y_train_scaled)
        nonoutlier_index = torch.nonzero((y_train_scaled[:,0]>lower)&(y_train_scaled[:,0]<upper), as_tuple =False).reshape([-1])
        
        initial_x = x_train_scaled[nonoutlier_index[:19]]
        initial_y = y_train_scaled[nonoutlier_index[:19]]
        
        x_train_scaled = np.delete(x_train_scaled, nonoutlier_index[:19], 0)
        y_train_scaled = np.delete(y_train_scaled, nonoutlier_index[:19], 0)
        
        network = Network(1,initial_x,initial_y)
        
        network.nb_node_acceptable = torch.IntTensor([1 for _ in range(initial_x.shape[0])])
        network.threshold_for_error = round(threshold_for_error[0],2)
        
        initializing(network, initial_x, initial_y)
        
#         print("<<Initializing後看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
#         print("threshold_for_error:",network.threshold_for_error)
        remainder = int(window_size) - initial_x.shape[0]
        nb_step4 += initial_x.shape[0]
        
    else:

        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        restart_index = int(x_train_scaled.shape[0])-step_window
#         print("其他區塊剛開始選的資料索引：",sorted_index[:restart_index])
        init_x = x_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,x_train_scaled.shape[1])
        init_y = y_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,1)
        network.setData(init_x, init_y)
        network.nb_node_acceptable = torch.IntTensor([network.linear1.bias.data.shape[0] for _ in range(init_x.shape[0])])
        network.nb_node_pruned = 0
        
#         print("<<其他區塊剛開始時看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
        
        remainder = int(window_size) - init_x.shape[0]
        x_train_scaled = np.delete(x_train_scaled, sorted_index[:restart_index], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[:restart_index], 0)
        nb_step4 += init_x.shape[0]

    for i in range(remainder):
#    for i in range(3):
        
        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        
        ## Add new data for training     
        network.addData(x_train_scaled[sorted_index[0]], y_train_scaled[sorted_index[0]])
        x_train_scaled = np.delete(x_train_scaled, sorted_index[0], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[0], 0)
        
        yo,loss = network.forward()
        pre_network = copy.deepcopy(network)
        
        if not torch.all(torch.abs(network.y-yo)<=network.threshold_for_error):

            network.acceptable = False
            network = matching(network)
            
            
            if network.acceptable == False:
                
                network = copy.deepcopy(pre_network)
                cramming(network)

                if network.acceptable == False:
                    sys.exit(0)  
                
                nb_step6_2 += 1

            else:
                nb_step6_1 += 1

        else:
            nb_step4 += 1

        network = reorganizing(network)
        yo,loss = network.forward()
        
        network.nb_node_acceptable = torch.cat([network.nb_node_acceptable, torch.IntTensor([network.linear1.bias.data.shape[0]])],0)

#     print("<<The performance of %d window>>"%(i_block+1))
    block_end = time.time()
    evaluation_table_train, evaluation_table_test = validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled,x_test_scaled, y_test, block_start, block_end,i_block+1,evaluation_table_train,evaluation_table_test)

    evaluation_table_train.to_csv("evaluation_table_train.csv",index=False)
    evaluation_table_test.to_csv("evaluation_table_inferencing.csv",index=False)
# Out:
# The <<1>> Window
# The training time(s): 66.29910445213318
# The forecast copper price for the first week: [[37231.2109375], [37231.2109375], [37567.234375], [37826.2890625]]
# <<Performance measurement>>
# The MAE: 841.8
# The standard deviation of absolute error: 832.7
# The MAPE: 0.0%
# The RMSE: 1182.7
# The accuracy(3000): 97.7%
# ----------------------------------------------------------------------------------------------------
# The <<2>> Window
# The training time(s): 1.2431104183197021
# The forecast copper price for the first week: [[37177.7890625], [36764.3984375], [37417.28515625], [37640.76171875]]
# <<Performance measurement>>
# The MAE: 831.4
# The standard deviation of absolute error: 811.0
# The MAPE: 0.0%
# The RMSE: 1160.1
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<3>> Window
# The training time(s): 1.249570369720459
# The forecast copper price for the first week: [[37388.83984375], [37498.18359375], [37767.3359375], [37892.4609375]]
# <<Performance measurement>>
# The MAE: 823.3
# The standard deviation of absolute error: 796.6
# The MAPE: 0.0%
# The RMSE: 1144.4
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<4>> Window
# The training time(s): 1.2566554546356201
# The forecast copper price for the first week: [[38020.80078125], [38764.94921875], [39480.1875], [39363.6484375]]
# <<Performance measurement>>
# The MAE: 816.7
# The standard deviation of absolute error: 795.0
# The MAPE: 0.0%
# The RMSE: 1138.5
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<5>> Window
# The training time(s): 1.3419747352600098
# The forecast copper price for the first week: [[38458.0], [37919.64453125], [38356.28515625], [38548.24609375]]
# <<Performance measurement>>
# The MAE: 800.9
# The standard deviation of absolute error: 789.8
# The MAPE: 0.0%
# The RMSE: 1123.5
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<6>> Window
# The training time(s): 1.2933769226074219
# The forecast copper price for the first week: [[38095.0703125], [37592.296875], [37237.52734375], [37057.7734375]]
# <<Performance measurement>>
# The MAE: 810.4
# The standard deviation of absolute error: 790.2
# The MAPE: 0.0%
# The RMSE: 1130.6
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<7>> Window
# The training time(s): 1.2706475257873535
# The forecast copper price for the first week: [[36364.47265625], [36522.0234375], [36697.2890625], [36739.53515625]]
# <<Performance measurement>>
# The MAE: 786.5
# The standard deviation of absolute error: 778.8
# The MAPE: 0.0%
# The RMSE: 1105.5
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<8>> Window
# The training time(s): 1.4552497863769531
# The forecast copper price for the first week: [[37047.28515625], [37782.72265625], [38410.15234375], [38863.578125]]
# <<Performance measurement>>
# The MAE: 745.1
# The standard deviation of absolute error: 771.3
# The MAPE: 0.0%
# The RMSE: 1071.2
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<9>> Window
# The training time(s): 1.1699862480163574
# The forecast copper price for the first week: [[38417.53125], [38200.7578125], [37764.8125], [37032.296875]]
# <<Performance measurement>>
# The MAE: 738.1
# The standard deviation of absolute error: 765.5
# The MAPE: 0.0%
# The RMSE: 1062.1
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<10>> Window
# The training time(s): 1.3351547718048096
# The forecast copper price for the first week: [[36467.85546875], [36372.22265625], [36904.09765625], [36837.3046875]]
# <<Performance measurement>>
# The MAE: 725.2
# The standard deviation of absolute error: 762.2
# The MAPE: 0.0%
# The RMSE: 1050.8
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<11>> Window
# The training time(s): 1.1841628551483154
# The forecast copper price for the first week: [[36795.4453125], [36911.1328125], [37334.1484375], [37418.7265625]]
# <<Performance measurement>>
# The MAE: 724.4
# The standard deviation of absolute error: 758.8
# The MAPE: 0.0%
# The RMSE: 1047.7
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<12>> Window
# The training time(s): 1.4228692054748535
# The forecast copper price for the first week: [[37487.3203125], [37847.30859375], [38777.578125], [40764.78515625]]
# <<Performance measurement>>
# The MAE: 744.4
# The standard deviation of absolute error: 795.9
# The MAPE: 0.0%
# The RMSE: 1088.4
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<13>> Window
# The training time(s): 1.3909482955932617
# The forecast copper price for the first week: [[43596.71484375], [45029.41796875], [45925.265625], [46221.5078125]]
# <<Performance measurement>>
# The MAE: 762.9
# The standard deviation of absolute error: 803.6
# The MAPE: 0.0%
# The RMSE: 1106.7
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<14>> Window
# The training time(s): 1.2232186794281006
# The forecast copper price for the first week: [[46676.234375], [45206.10546875], [44428.48828125], [44863.5390625]]
# <<Performance measurement>>
# The MAE: 737.4
# The standard deviation of absolute error: 740.2
# The MAPE: 0.0%
# The RMSE: 1043.6
# The accuracy(3000): 97.7%
# ----------------------------------------------------------------------------------------------------
# The <<15>> Window
# The training time(s): 1.2348384857177734
# The forecast copper price for the first week: [[46351.9140625], [47177.71875], [47267.3671875], [47437.05078125]]
# <<Performance measurement>>
# The MAE: 717.9
# The standard deviation of absolute error: 722.9
# The MAPE: 0.0%
# The RMSE: 1017.6
# The accuracy(3000): 97.7%
# ----------------------------------------------------------------------------------------------------
# The <<16>> Window
# The training time(s): 1.279055118560791
# The forecast copper price for the first week: [[47337.515625], [48904.484375], [48661.09765625], [48099.2421875]]
# <<Performance measurement>>
# The MAE: 717.2
# The standard deviation of absolute error: 715.2
# The MAPE: 0.0%
# The RMSE: 1011.7
# The accuracy(3000): 97.7%
# ----------------------------------------------------------------------------------------------------
# The <<17>> Window
# The training time(s): 1.2672529220581055
# The forecast copper price for the first week: [[47303.80859375], [47364.29296875], [47419.00390625], [47372.6328125]]
# <<Performance measurement>>
# The MAE: 701.5
# The standard deviation of absolute error: 706.4
# The MAPE: 0.0%
# The RMSE: 994.4
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<18>> Window
# The training time(s): 1.357922077178955
# The forecast copper price for the first week: [[47975.26953125], [47606.296875], [47172.90234375], [47160.15234375]]
# <<Performance measurement>>
# The MAE: 709.8
# The standard deviation of absolute error: 704.7
# The MAPE: 0.0%
# The RMSE: 999.1
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<19>> Window
# The training time(s): 1.2662162780761719
# The forecast copper price for the first week: [[46974.15625], [46292.34765625], [46593.91015625], [47227.72265625]]
# <<Performance measurement>>
# The MAE: 713.9
# The standard deviation of absolute error: 708.7
# The MAPE: 0.0%
# The RMSE: 1004.8
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<20>> Window
# The training time(s): 1.2826497554779053
# The forecast copper price for the first week: [[46814.90625], [46938.0703125], [47149.3984375], [46852.25]]
# <<Performance measurement>>
# The MAE: 685.6
# The standard deviation of absolute error: 700.8
# The MAPE: 0.0%
# The RMSE: 979.2
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<21>> Window
# The training time(s): 1.2624030113220215
# The forecast copper price for the first week: [[47201.6484375], [47438.3671875], [47496.92578125], [47765.86328125]]
# <<Performance measurement>>
# The MAE: 680.1
# The standard deviation of absolute error: 695.7
# The MAPE: 0.0%
# The RMSE: 971.8
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<22>> Window
# The training time(s): 1.2854828834533691
# The forecast copper price for the first week: [[49062.5390625], [50029.14453125], [50309.5234375], [50454.2109375]]
# <<Performance measurement>>
# The MAE: 634.1
# The standard deviation of absolute error: 581.2
# The MAPE: 0.0%
# The RMSE: 859.3
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<23>> Window
# The training time(s): 1.3131859302520752
# The forecast copper price for the first week: [[51142.9765625], [52204.24609375], [52699.2265625], [51424.82421875]]
# <<Performance measurement>>
# The MAE: 638.3
# The standard deviation of absolute error: 574.5
# The MAPE: 0.0%
# The RMSE: 857.9
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<24>> Window
# The training time(s): 1.2666206359863281
# The forecast copper price for the first week: [[50311.5078125], [49894.296875], [50943.74609375], [52323.78125]]
# <<Performance measurement>>
# The MAE: 656.9
# The standard deviation of absolute error: 598.5
# The MAPE: 0.0%
# The RMSE: 887.7
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<25>> Window
# The training time(s): 1.269465684890747
# The forecast copper price for the first week: [[53927.1953125], [54493.68359375], [53501.70703125], [53475.8828125]]
# <<Performance measurement>>
# The MAE: 650.3
# The standard deviation of absolute error: 586.5
# The MAPE: 0.0%
# The RMSE: 874.8
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<26>> Window
# The training time(s): 1.2300400733947754
# The forecast copper price for the first week: [[53141.99609375], [52992.8046875], [52812.953125], [51948.76171875]]
# <<Performance measurement>>
# The MAE: 645.9
# The standard deviation of absolute error: 578.0
# The MAPE: 0.0%
# The RMSE: 865.9
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<27>> Window
# The training time(s): 1.2760648727416992
# The forecast copper price for the first week: [[51764.890625], [52663.4921875], [53586.4609375], [53834.703125]]
# <<Performance measurement>>
# The MAE: 653.0
# The standard deviation of absolute error: 587.9
# The MAPE: 0.0%
# The RMSE: 877.7
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<28>> Window
# The training time(s): 1.2861113548278809
# The forecast copper price for the first week: [[54219.4140625], [54084.6640625], [53086.63671875], [52668.015625]]
# <<Performance measurement>>
# The MAE: 651.2
# The standard deviation of absolute error: 577.1
# The MAPE: 0.0%
# The RMSE: 869.3
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<29>> Window
# The training time(s): 1.3979711532592773
# The forecast copper price for the first week: [[51994.984375], [51836.24609375], [52189.2265625], [52264.2421875]]
# <<Performance measurement>>
# The MAE: 647.3
# The standard deviation of absolute error: 571.5
# The MAPE: 0.0%
# The RMSE: 862.6
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<30>> Window
# The training time(s): 1.2789578437805176
# The forecast copper price for the first week: [[52399.7265625], [52355.08203125], [51130.3125], [49902.02734375]]
# <<Performance measurement>>
# The MAE: 658.6
# The standard deviation of absolute error: 575.2
# The MAPE: 0.0%
# The RMSE: 873.5
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<31>> Window
# The training time(s): 1.2937772274017334
# The forecast copper price for the first week: [[50364.8984375], [50941.37109375], [51237.05078125], [51574.078125]]
# <<Performance measurement>>
# The MAE: 643.7
# The standard deviation of absolute error: 546.4
# The MAPE: 0.0%
# The RMSE: 843.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<32>> Window
# The training time(s): 1.2646832466125488
# The forecast copper price for the first week: [[52031.7578125], [52357.70703125], [51812.98046875], [52063.9296875]]
# <<Performance measurement>>
# The MAE: 651.3
# The standard deviation of absolute error: 544.4
# The MAPE: 0.0%
# The RMSE: 848.0
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<33>> Window
# The training time(s): 1.274892807006836
# The forecast copper price for the first week: [[51919.52734375], [52869.984375], [53669.671875], [52748.45703125]]
# <<Performance measurement>>
# The MAE: 656.3
# The standard deviation of absolute error: 545.7
# The MAPE: 0.0%
# The RMSE: 852.7
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<34>> Window
# The training time(s): 1.2869975566864014
# The forecast copper price for the first week: [[52131.046875], [50905.9609375], [49638.42578125], [49718.953125]]
# <<Performance measurement>>
# The MAE: 671.8
# The standard deviation of absolute error: 552.7
# The MAPE: 0.0%
# The RMSE: 869.1
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<35>> Window
# The training time(s): 1.288025140762329
# The forecast copper price for the first week: [[50221.5234375], [50666.921875], [50562.8515625], [50352.6484375]]
# <<Performance measurement>>
# The MAE: 673.8
# The standard deviation of absolute error: 554.0
# The MAPE: 0.0%
# The RMSE: 871.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<36>> Window
# The training time(s): 1.3766427040100098
# The forecast copper price for the first week: [[49973.14453125], [50196.328125], [49657.328125], [49748.1953125]]
# <<Performance measurement>>
# The MAE: 684.0
# The standard deviation of absolute error: 558.0
# The MAPE: 0.0%
# The RMSE: 881.9
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<37>> Window
# The training time(s): 1.2794897556304932
# The forecast copper price for the first week: [[50814.078125], [51560.05859375], [51676.6015625], [51730.2421875]]
# <<Performance measurement>>
# The MAE: 682.6
# The standard deviation of absolute error: 553.9
# The MAPE: 0.0%
# The RMSE: 878.2
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<38>> Window
# The training time(s): 1.2989451885223389
# The forecast copper price for the first week: [[51675.921875], [51309.91796875], [50602.3671875], [50617.4375]]
# <<Performance measurement>>
# The MAE: 695.2
# The standard deviation of absolute error: 555.3
# The MAPE: 0.0%
# The RMSE: 888.9
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<39>> Window
# The training time(s): 1.3261241912841797
# The forecast copper price for the first week: [[50173.44140625], [50354.56640625], [50436.46875], [50534.36328125]]
# <<Performance measurement>>
# The MAE: 685.8
# The standard deviation of absolute error: 541.6
# The MAPE: 0.0%
# The RMSE: 873.1
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<40>> Window
# The training time(s): 1.0376906394958496
# The forecast copper price for the first week: [[50205.8515625], [49560.23046875], [48623.55859375], [48291.2734375]]
# <<Performance measurement>>
# The MAE: 680.5
# The standard deviation of absolute error: 535.8
# The MAPE: 0.0%
# The RMSE: 865.4
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<41>> Window
# The training time(s): 1.3222277164459229
# The forecast copper price for the first week: [[47796.875], [47624.6640625], [47424.92578125], [47661.04296875]]
# <<Performance measurement>>
# The MAE: 662.6
# The standard deviation of absolute error: 528.3
# The MAPE: 0.0%
# The RMSE: 846.7
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<42>> Window
# The training time(s): 1.3250823020935059
# The forecast copper price for the first week: [[47852.24609375], [48138.83984375], [48924.1875], [50122.33984375]]
# <<Performance measurement>>
# The MAE: 646.0
# The standard deviation of absolute error: 516.4
# The MAPE: 0.0%
# The RMSE: 826.3
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<43>> Window
# The training time(s): 1.3766694068908691
# The forecast copper price for the first week: [[50088.4609375], [50088.4765625], [50249.6875], [49627.31640625]]
# <<Performance measurement>>
# The MAE: 628.7
# The standard deviation of absolute error: 514.9
# The MAPE: 0.0%
# The RMSE: 811.9
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<44>> Window
# The training time(s): 1.3785998821258545
# The forecast copper price for the first week: [[49491.44921875], [49757.87109375], [49894.3046875], [49900.0078125]]
# <<Performance measurement>>
# The MAE: 624.4
# The standard deviation of absolute error: 516.7
# The MAPE: 0.0%
# The RMSE: 809.7
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<45>> Window
# The training time(s): 1.3297581672668457
# The forecast copper price for the first week: [[49518.6875], [48800.734375], [48467.73046875], [48440.34375]]
# <<Performance measurement>>
# The MAE: 634.2
# The standard deviation of absolute error: 520.0
# The MAPE: 0.0%
# The RMSE: 819.4
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<46>> Window
# The training time(s): 1.0451459884643555
# The forecast copper price for the first week: [[48020.1171875], [47704.25], [47625.1171875], [47795.9921875]]
# <<Performance measurement>>
# The MAE: 634.3
# The standard deviation of absolute error: 520.1
# The MAPE: 0.0%
# The RMSE: 819.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<47>> Window
# The training time(s): 1.2540788650512695
# The forecast copper price for the first week: [[48432.71484375], [48369.515625], [48098.7109375], [49099.58203125]]
# <<Performance measurement>>
# The MAE: 647.8
# The standard deviation of absolute error: 536.3
# The MAPE: 0.0%
# The RMSE: 840.2
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<48>> Window
# The training time(s): 1.3412396907806396
# The forecast copper price for the first week: [[49238.58203125], [49102.09375], [48268.22265625], [47949.44921875]]
# <<Performance measurement>>
# The MAE: 668.9
# The standard deviation of absolute error: 561.6
# The MAPE: 0.0%
# The RMSE: 872.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<49>> Window
# The training time(s): 1.2745962142944336
# The forecast copper price for the first week: [[47683.61328125], [47733.00390625], [48049.62109375], [48783.54296875]]
# <<Performance measurement>>
# The MAE: 667.5
# The standard deviation of absolute error: 543.7
# The MAPE: 0.0%
# The RMSE: 860.1
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<50>> Window
# The training time(s): 1.275768756866455
# The forecast copper price for the first week: [[48471.83203125], [47680.47265625], [47698.90234375], [47486.83984375]]
# <<Performance measurement>>
# The MAE: 656.6
# The standard deviation of absolute error: 531.3
# The MAPE: 0.0%
# The RMSE: 843.9
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<51>> Window
# The training time(s): 1.2769975662231445
# The forecast copper price for the first week: [[46909.36328125], [47128.0078125], [47411.13671875], [47490.2578125]]
# <<Performance measurement>>
# The MAE: 617.5
# The standard deviation of absolute error: 520.3
# The MAPE: 0.0%
# The RMSE: 806.7
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<52>> Window
# The training time(s): 1.2540218830108643
# The forecast copper price for the first week: [[47199.22265625], [46990.84375], [47223.29296875], [46906.69921875]]
# <<Performance measurement>>
# The MAE: 601.7
# The standard deviation of absolute error: 521.6
# The MAPE: 0.0%
# The RMSE: 795.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<53>> Window
# The training time(s): 1.3028888702392578
# The forecast copper price for the first week: [[48009.3359375], [48423.0625], [48780.55078125], [48695.23046875]]
# <<Performance measurement>>
# The MAE: 594.6
# The standard deviation of absolute error: 514.0
# The MAPE: 0.0%
# The RMSE: 785.2
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<54>> Window
# The training time(s): 1.2686998844146729
# The forecast copper price for the first week: [[48472.30078125], [48473.453125], [47929.2578125], [46202.74609375]]
# <<Performance measurement>>
# The MAE: 593.9
# The standard deviation of absolute error: 515.3
# The MAPE: 0.0%
# The RMSE: 785.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<55>> Window
# The training time(s): 1.2997546195983887
# The forecast copper price for the first week: [[45074.74609375], [45496.203125], [45776.8359375], [45540.8828125]]
# <<Performance measurement>>
# The MAE: 586.4
# The standard deviation of absolute error: 514.5
# The MAPE: 0.0%
# The RMSE: 779.3
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<56>> Window
# The training time(s): 1.2988414764404297
# The forecast copper price for the first week: [[45086.140625], [43914.8203125], [41565.99609375], [39494.8359375]]
# <<Performance measurement>>
# The MAE: 615.9
# The standard deviation of absolute error: 577.0
# The MAPE: 0.0%
# The RMSE: 843.1
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<57>> Window
# The training time(s): 1.2773396968841553
# The forecast copper price for the first week: [[40367.234375], [42685.046875], [44201.79296875], [43910.78515625]]
# <<Performance measurement>>
# The MAE: 623.4
# The standard deviation of absolute error: 574.4
# The MAPE: 0.0%
# The RMSE: 846.8
# The accuracy(3000): 99.1%
# ----------------------------------------------------------------------------------------------------
# The <<58>> Window
# The training time(s): 1.2384669780731201
# The forecast copper price for the first week: [[44218.9375], [44716.03515625], [45028.52734375], [45390.23828125]]
# <<Performance measurement>>
# The MAE: 632.0
# The standard deviation of absolute error: 565.2
# The MAPE: 0.0%
# The RMSE: 847.0
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<59>> Window
# The training time(s): 1.2950968742370605
# The forecast copper price for the first week: [[45185.5625], [45757.171875], [47339.53125], [47786.88671875]]
# <<Performance measurement>>
# The MAE: 627.1
# The standard deviation of absolute error: 553.4
# The MAPE: 0.0%
# The RMSE: 835.5
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<60>> Window
# The training time(s): 1.2648396492004395
# The forecast copper price for the first week: [[48580.75390625], [49524.8515625], [50017.57421875], [51696.59375]]
# <<Performance measurement>>
# The MAE: 631.9
# The standard deviation of absolute error: 556.9
# The MAPE: 0.0%
# The RMSE: 841.4
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<61>> Window
# The training time(s): 1.2937240600585938
# The forecast copper price for the first week: [[51843.8359375], [51421.40234375], [50797.23046875], [49442.21484375]]
# <<Performance measurement>>
# The MAE: 629.0
# The standard deviation of absolute error: 569.1
# The MAPE: 0.0%
# The RMSE: 847.4
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<62>> Window
# The training time(s): 1.3755736351013184
# The forecast copper price for the first week: [[50285.48828125], [49916.46875], [49717.7109375], [49856.7265625]]
# <<Performance measurement>>
# The MAE: 656.1
# The standard deviation of absolute error: 600.4
# The MAPE: 0.0%
# The RMSE: 888.4
# The accuracy(3000): 100.0%
# ----------------------------------------------------------------------------------------------------
# The <<63>> Window
# The training time(s): 1.4187374114990234
# The forecast copper price for the first week: [[50091.8125], [49536.3203125], [49326.00390625], [49576.66015625]]
# <<Performance measurement>>
# The MAE: 677.6
# The standard deviation of absolute error: 599.0
# The MAPE: 0.0%
# The RMSE: 903.5
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<64>> Window
# The training time(s): 1.254481554031372
# The forecast copper price for the first week: [[50773.6953125], [51200.9609375], [50936.87109375], [50844.7734375]]
# <<Performance measurement>>
# The MAE: 673.0
# The standard deviation of absolute error: 568.4
# The MAPE: 0.0%
# The RMSE: 880.0
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
# The <<65>> Window
# The training time(s): 1.336292028427124
# The forecast copper price for the first week: [[51188.34375], [51752.93359375], [52832.7265625], [54780.109375]]
# <<Performance measurement>>
# The MAE: 678.0
# The standard deviation of absolute error: 580.9
# The MAPE: 0.0%
# The RMSE: 892.0
# The accuracy(3000): 99.5%
# ----------------------------------------------------------------------------------------------------
