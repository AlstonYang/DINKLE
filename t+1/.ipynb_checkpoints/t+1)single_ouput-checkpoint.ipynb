# %% [markdown]
# ### Import related package

# %%
## Import tensorflow package for modeling
import torch
from torch.autograd import Variable
import torch.optim as optim

## Data processing
import pandas as pd
import numpy as np

## Min-max normalization
from sklearn.preprocessing import MinMaxScaler

## Plot the graph
import matplotlib.pyplot as plt
# %matplotlib inline

## Initializing module
from sklearn.linear_model import LinearRegression
np.set_printoptions(suppress=True)

## Copy module
import copy

## Used to calculate the training time
import time
from datetime import datetime, timedelta
## Set the GUP environment
import os
import sys

from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker

# %%
os.chdir('/home/Oring-AI/Model_I/DINKLE/t+1')

# %%
## Set up the display
torch.set_printoptions(sci_mode=False)

# %% [markdown]
# ### Control memory usage space for GPU

# %%
## 查詢有無可用 GPU
torch.cuda.is_available()
## 查詢可用 GPU 的數量
torch.cuda.device_count()
##目前設備
print("目前設備：",torch.cuda.current_device())
## 目前設備名
print("目前設備名：",torch.cuda.get_device_name(0))
# Out:
# 目前設備： 0
# 目前設備名： GeForce GTX 1070 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# ## Print out some info

# %%
def accuracy_cacl(pred_value, actual_value):
    
#     yo, loss, tape = network.forward()
    performance = []
    performance.append(torch.mean(torch.abs(pred_value - actual_value)))
    performance.append(torch.std(torch.abs(pred_value - actual_value)))
    performance.append(torch.mean(torch.abs((pred_value - actual_value) / actual_value))) 
    performance.append(torch.sqrt(torch.mean((pred_value - actual_value)**2)))
    
    for i in range(2000,3001,1000):
        correct_times = torch.nonzero(torch.abs(pred_value - actual_value) <= i, as_tuple =False)
        accuracy = correct_times.shape[0]/pred_value.shape[0]
        performance.append(accuracy)
                       
    return performance

# %%
def plot_result(name, pred_value, actual_value,block_index):
    
#     fig, ax = plt.subplots(2,2,figsize=(20,10), sharex=True, sharey=True)
    fig, ax = plt.subplots(1,figsize=(20,10), sharex=True, sharey=True)
#     ax.set_xlim(0,pred_value.shape[0])  
    
    
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.plot(pred_value, label="LLAAT")
    ax.plot(actual_value, label="Actual")
    ax.set_title("Forecasted performance for l=%d" %(1))
    ax.legend()
        
    #fig.text(0.5, 0, "Stage of training", ha='center', fontsize=20)
    #fig.text(0, 0.5, "Copper price value", va='center', rotation='vertical')

    fig.suptitle("In the %s process in the M=%d window"%(name, block_index))
    fig.tight_layout()
#     fig.savefig("In the %s process in the M=%d window.png"%(name, block_index),dpi=300,bbox_inches='tight')

# %%
def plot_adopted_node(network,block_index):
    
    fig, ax = plt.subplots(figsize=(20,5))
#     ax.set_xticklabels([i for i in range(network.nb_node_acceptable.shape[0]+5)])
    
    ax.set_title("Total amount of adopted hidden nodes in the training process in the M=%d window"%(block_index))
    ax.plot(network.nb_node_acceptable,"-o")

    ax.set_xlabel("Stage of training")
    ax.set_ylabel("Hidden nodes")
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
#     fig.savefig("hidden nodes in the training process in the M=%d window"%(block_index),dpi=300,bbox_inches='tight')

# %%
def evaluation_table(evaluation_results, block_index, name, performance, nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node):

    
    new_result = pd.DataFrame({

        "Window_index":block_index,
        "Stage":name,
        "MAE" : round(performance[0].item(),2),
        "SD of absolute error":round(performance[1].item(),2),
        "MAPE" : "%.2f"%(performance[2]*100).item(),
        "RMSE" : round(performance[3].item(),2),
#         "Accuracy(2000)" : [round(performance[4]*100,2)],
        "Accuracy(3000)" : [round(performance[5]*100,2)],
        "Step4":nb_step4,
        "Step6.1":nb_step6_1,
        "Step6.2":nb_step6_2,
        "Time":time,
        "Adopted_hidden_node":adopted_hidden_node
    })

    evaluation_results = evaluation_results.append(new_result, ignore_index=True)
    
    return evaluation_results

# %%
def validation(last_date, network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled, x_test, y_test, start, end, block_index, evaluation_results_train, evaluation_results_test,performance_record):

    ## Training_Step
#    print("<<Training step>>")
#     print("The training time(s):",end - start)
    time = end - start
    yo, loss= network.forward()
    
    ## N - outlier
    pre_train = yo.data.cpu()
    true_train = network.y.data.cpu()
    
    pred_value_train = torch.FloatTensor(sc.inverse_transform(pre_train))
    actual_value_train = torch.FloatTensor(sc.inverse_transform(true_train))
    accuracy_train = accuracy_cacl(pred_value_train,actual_value_train)

    ## B
    pred_value_test = torch.FloatTensor(sc.inverse_transform(network.forecast(x_test).data.cpu()))
    accuracy_test = accuracy_cacl(pred_value_test, y_test)
    
#     total_time = nb_step4 + nb_step6_1 + nb_step6_2
#     print("<<The percentage of each step>>")
#     print("Step 4: %.2f%%"%((nb_step4/total_time)*100))
#     print("Step 6.1: %.2f%%"%((nb_step6_1/total_time)*100))
#     print("Step 6.2: %.2f%%"%((nb_step6_2/total_time)*100))
    
#     print("-"*60)
#     print("Total frequency of cramming occurrences:",nb_step6_2)

#     print("-"*60)
#     print("The amount of hidden node that be pruned:",network.nb_node_pruned)

#     print("-"*60)
    adopted_hidden_node = network.nb_node_acceptable[-1].item()
#     print("The amount of adopted hidden nodes:",network.nb_node_acceptable[-1].item())

#     print("-"*60)
#     print("<<Accuracy in training step>>")
#     print("The MAE for l = 1: %.2f" %(accuracy_train[0]))
#     print("The MAPE for l = 1: %.2f%%" %(accuracy_train[1]))
#     print("The RMSE for l = 1: %.2f" %(accuracy_train[2]))
#     print("The accuracy(2000) for l = 1: %.2f%%" %(accuracy_train[3]*100))
#     print("The accuracy(3000) for l = 1: %.2f%%" %(accuracy_train[4]*100))

    for i in range(pred_value_test.shape[0]):

        date = datetime.date(last_date[0]+timedelta(days=7*(i+1)))
        print("The forecasted copper price for the coming week(%s): %.2f CNY$/Ton" %(date, pred_value_test[i]))
        print("<<Performance measurement>>")
        print("Mean of error: %.2f" %(accuracy_train[0]))
        print("Std of error: %.2f" %(accuracy_train[1]))
        print("The accuracy(3000): %.2f%%" %(accuracy_train[5]*100))
        print("-"*120)

       
              
        training_record = pd.DataFrame({
            
            "Date": [date],
            "Mean of error": round(accuracy_train[0].item(),2),
            "SD of error": round(accuracy_train[1].item(),2)
        })
        
        performance_record = performance_record.append(training_record)
        
    evaluation_table_train = evaluation_table(evaluation_results_train, block_index, "Training", accuracy_train,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    evaluation_table_test = evaluation_table(evaluation_results_test, block_index, "Inferencing", accuracy_test,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    pre_LDSS = sc.inverse_transform(network.forecast(x_test).data.cpu())
#     pd.DataFrame(pre_LDSS).to_csv("pre_LDSS_%d.csv"%(block_index), index=False)
    
#     plot_result("training",pred_value_train, actual_value_train,block_index)
#     plot_result("inferencing",pred_value_test, y_test,block_index)
#     plot_adopted_node(network,block_index)
    
    return(evaluation_table_train, evaluation_table_test,performance_record)

# %% [markdown]
# ### Preprocessing the data

# %%
def read(path):
    return pd.read_csv(path)

# %%
def buildTrain(train, pastWeek=4, futureWeek=4, defaultWeek=1):
    X_train, Y_train = [], []
    for i in range(train.shape[0]-futureWeek-pastWeek):
        X = np.array(train.iloc[i:i+defaultWeek])
        X = np.append(X,train["CCSP"].iloc[i+defaultWeek:i+pastWeek])
        X_train.append(X.reshape(X.size))
        Y_train.append(np.array(train.iloc[i+pastWeek:i+pastWeek+futureWeek]["CCSP"]))
    return np.array(X_train), np.array(Y_train)

# %% [markdown]
# ### Min-max normalization

# %%
## Use min-max normalization to scale the data to the range from 1 to 0
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ### Design get_data() to get data

# %%
def get_data(futureWeek):
    
    ## Read weekly copper price data
    path = "WeeklyFinalData.csv"
    data = read(path)
    
    date = pd.DataFrame(data["Date"])
    date["Date"] = pd.to_datetime(date["Date"], format="%Y/%m/%d")
#     datetime.strptime("2018-01-31", "%Y-%m-%d")
    data.drop("Date", axis=1, inplace=True)
    
    ## Add time lag (pastWeek=4, futureWeek=1)
    x_data, y_data = buildTrain(data, futureWeek=futureWeek)


    return (date, x_data, y_data)

# %% [markdown]
# ### Network class

# %%
class Network(torch.nn.Module):
    
    def __init__(self, nb_neuro, x_train_scaled, y_train_scaled):
        
        super(Network, self).__init__()
        self.linear1 = torch.nn.Linear(x_train_scaled.shape[1], nb_neuro).cuda()
        self.linear2 = torch.nn.Linear(nb_neuro, 1).cuda()
        
        
        # Stop criteria - threshold
        self.threshold_for_error = 0.12
        self.threshold_for_lr = 1e-4
        
        # Input data 
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
        
        # Learning rate
        self.learning_rate = 1e-3
        
        # Whether the network is acceptable, default as False
        self.acceptable = False
        
        # Some record for experiment
        self.nb_node_pruned = 0
        self.nb_node_acceptable=torch.IntTensor([nb_neuro])
        
        self.limit = nb_neuro
        
    ## Forecast the test data
    def forecast(self, x_test):
    
        x_test = torch.FloatTensor(x_test).cuda()
        activation_value = self.linear1(x_test).clamp(min=0)
        forecast_value = self.linear2(activation_value)
       
        return forecast_value

    ## Reset the x and y data
    def setData(self, x_train_scaled, y_train_scaled):
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
    
    ## Add the new data to the x and y data
    def addData(self, new_x_train, new_y_train):

        self.x = torch.cat([self.x, new_x_train.reshape(1,-1).cuda()],0)
        self.y = torch.cat([self.y, new_y_train.reshape(-1,1).cuda()],0)
    
    ## forward operation
    def forward(self, reg_strength=0):
       
        y1 = self.linear1(self.x).clamp(min=0)
        yo = self.linear2(y1)

        # performance measure
        param_val= torch.sum(torch.pow(self.linear2.bias.data,2))+torch.sum(torch.pow(self.linear2.weight.data,2))+torch.sum(torch.pow(self.linear1.bias.data,2))+torch.sum(torch.pow(self.linear1.weight.data,2))
        reg_term= reg_strength/((self.linear2.bias.data.shape[0]*(self.linear2.weight.data.shape[1]+1)) +(self.linear1.bias.data.shape[0]*(self.linear1.weight.data.shape[1]+1)))*param_val
        loss = torch.nn.functional.mse_loss(yo,self.y)+reg_term
        loss = loss.cuda()
        return(yo, loss)

    # backward operation
    def backward_Adadelta(self,loss):    

        optimizer = optim.Adadelta(self.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### Initializing module (Check)

# %%
def initializing(network, initial_x, initial_y):
#     print("Initializing module")
    ## Find each minimum output value y
    min_y = torch.min(initial_y, axis=0)
    ## Subtract min_y from each y
    res_y = initial_y-min_y.values
    
    ## Use linear regression to find the initial W1,b1,Wo,bo
    reg = LinearRegression().fit(initial_x, res_y)
    
    ## Set up the initial parameter of the network
    network.linear1.weight = torch.nn.Parameter(torch.FloatTensor(reg.coef_).cuda())
    network.linear1.bias = torch.nn.Parameter(torch.FloatTensor(reg.intercept_).cuda())
    network.linear2.weight=torch.nn.Parameter(torch.FloatTensor([[1]]).cuda())
    network.linear2.bias = torch.nn.Parameter(torch.FloatTensor(min_y.values).cuda())
    
#     print(reg.coef_)
#     print(reg.intercept_)

    ## Set up the acceptable of the initial network as True
    network.acceptable =True

# %% [markdown]
# ### Selecting module (Check)

# %%
def selecting(network, x_train_scaled, y_train_scaled):
    
#     print("<<Selecting module>>")
    loss = []
    temp_network = copy.deepcopy(network)
    
    ## Put each data into network to calculate the loss value
    for i in range(x_train_scaled.shape[0]):
        temp_network.setData(x_train_scaled[i].reshape(1,-1), y_train_scaled[i].reshape(-1,1))
        loss.append((temp_network.forward()[1].item(),i))
#         print(network.state_dict())
#         print(temp_network.y)
#         print("-"*20)
#         print(temp_network.forward()[1])
#         print("-"*20)
#     ## Sort the data according to the loss value from smallest to largest, and save the data index in sorted_index
    sorted_index = [sorted_data[1] for sorted_data in sorted(loss, key = lambda x:x[0])]
    
    
    ## Print out some info for debug
#     print("The loss value of k:",loss[sorted_index[0]])
#     print("The second_loss value of k:",loss[sorted_index[1]])
#     print("Selecting module finish!")
#     print("Loss",loss)
#     print(network.state_dict())
    
    return sorted_index

# %% [markdown]
# ### Matching

# %%
def matching(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(10000):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ### Matching for reorganizing

# %%
def matching_for_reorganizing(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module for reorganizing>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(500):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished(o) - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished(o) - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ## Cramming module (Check)

# %%
def cramming(network):
    
    torch.random.manual_seed(0)
#     print("<<Cramming module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Find unsatisfied data:K
    yo, loss = network.forward()
    undesired_index = torch.nonzero(torch.abs(yo-network.y) > network.threshold_for_error+0.001, as_tuple =False)

    ## Print out the undesired_index for debug
#     print("不滿足個數：",undesired_index.shape[0])
#     print("The index of the undesired data:",undesired_index)

    
    if undesired_index.shape[0] == 1:
        
        # Unsatisfied situation
        ## Find the index of the unsatisfied data
        k_data_num = undesired_index[0][0]

        undesired_data = torch.reshape(network.x[k_data_num,:], [1,-1])

        ## Remove the data that does not meet the error term
        left_data = network.x[:k_data_num,:]
        right_data = network.x[k_data_num+1:,:]
        remain_tensor = torch.cat([left_data, right_data], 0)


        ## Use the random method to find out the gamma and zeta
        while True:

            ## Find m-vector gamma: r
            ## Use the random method to generate the gamma that can make the conditions met
            gamma = torch.rand(size=[1,network.x.shape[1]]).cuda()
            subtract_undesired_data = torch.sub(remain_tensor, undesired_data)
            matmul_value = torch.mm(gamma,torch.t(subtract_undesired_data))

            if torch.all(matmul_value != 0):
                break

        while True:

            ## Find the tiny value: zeta
            ## Use the random method to generate the zeta that can make the conditions met
            zeta = torch.rand(size=[1]).cuda()

            if torch.all(torch.mul(torch.add(zeta,matmul_value),torch.sub(zeta,matmul_value))<0):
                break


        k_l = undesired_index[0][1]
        
        ## The weight of input layer to hidden layer I
        w10 = gamma
        w11 = gamma
        w12 = gamma

        W1_new = torch.cat([w10,w11,w12],0)
        

        ## The bias of input layer to hidden layer I
        matual_value = torch.mm(gamma,torch.t(undesired_data))
       
        
        b10 = torch.sub(zeta,matual_value)
        b11 = -1*matual_value
        b12 = torch.sub(-1*zeta,matual_value)

        b1_new = torch.reshape(torch.cat([b10,b11,b12],0),[3])

        ## The weight of hidden layer I to output layer
        gap = network.y[k_data_num, k_l]-yo[k_data_num, k_l]

        wo0_value = gap/zeta
        wo1_value = (-2*gap)/zeta
        wo2_value = gap/zeta

        Wo_new = torch.reshape(torch.cat([wo0_value,wo1_value,wo2_value],0),[1,-1])

        ## Add new neuroes to the network
        network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight.data, W1_new]))
        network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias.data, b1_new]))
        network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight.data, Wo_new],1))


        yo, loss = network.forward()
        
        ## Determine if cramming is successful and print out the corresponding information
        if torch.all(torch.abs(yo-network.y) <= network.threshold_for_error):
            network.acceptable = True 
#             print("Cramming success!")

        else:
#             print("Cramming failed!")
            pass
    
    else:
#         print("條件不合，不能Cramming")
        pass

# %% [markdown]
# ### Regularizing module (Check)

# %%
def regularizing(network):

#     print("<<Regularizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    ## Record the number of executions
    times_enlarge = 0
    times_shrink = 0
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3

    ## Set epoch to 100
    for i in range(100):

        ## Store the parameter of the network
        network_pre = copy.deepcopy(network)
        yo, loss = network.forward(1e-3)
        loss_pre = loss
        
        ## Backward operation to obtain w'
        network.backward_Adadelta(loss)
        yo, loss = network.forward(1e-3)

        # Confirm whether the adjusted loss value is smaller than the current one
        if loss <= loss_pre:
            
            ## Identify that all forecast value has met the error term
            if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):
                
                ## If true, multiply the learning rate by 1.2
                network.learning_rate *= 1.2
                times_enlarge += 1

            else:

                ## Else, restore w and end the process
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-因為沒有顧好預測誤差")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

        # If the adjusted loss value is not smaller than the current one
        else:

            ## If the learning rate is greater than the threshold for learning rate
            if network.learning_rate > network.threshold_for_lr:
                
                ## Restore the w and multiply the learning rate by 0.7
                network = copy.deepcopy(network_pre)
                network.learning_rate *= 0.7
                times_shrink += 1

             ## If the learning rate is smaller than the threshold for learning rate
            else:
                
                ## Restore the w
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-Learning不能這麼小")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

#     print("第\"%d\"回合Regularizing module完畢"%(i+1))
#     print("Number of enlarge:",times_enlarge)
#     print("Number of shrink:",times_shrink)
    return(network)

# %% [markdown]
# ### Reorganizing module (Check)

# %%
def reorganizing(network):
#     print("<<Reorganizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    limit = 4
    if network.linear1.bias.shape[0] <= limit:
        network = regularizing(network)
        return(network)
    
    else:
        
        ## Set up the k = 1, and p = the number of hidden node
        k = 1
    #     p = network.W1.shape[1]
        p = network.linear1.weight.data.shape[0]

        while True:

            ## If k > p, end of Process
            if k > p or p<=limit:

#                 print("Reorganizing result: The final number of neuro is ",p)
                return(network)

            ## Else, Process is ongoing
            else:

                ## Using the regularizing module to adjust the network
                network = regularizing(network)

                ## Store the network and w
                network_pre = copy.deepcopy(network)

                ## Set up the acceptable of the network as false
                network.acceptable = False
                
            
                ## Ignore the K hidden node
                network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight[:k-1],network.linear1.weight[k:]],0))
                network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias[:k-1],network.linear1.bias[k:]]))
                network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight[:,:k-1],network.linear2.weight[:,k:]],1))

                
                ## Using the matching module to adjust the network
                network = matching_for_reorganizing(network)

#                 print("是不是可以不要這個hidden node:",network.acceptable)

                ## If the resulting network is acceptable, this means that the k hidden node can be removed
                if network.acceptable:

#                     print("Drop out the nero number: %d / %d" %(k, p))
                    network.nb_node_pruned += 1
                    ## p--
                    p-=1

                ## Else, it means that the k hidden node cannot be removed
                else:

                    ## Restore the network and w
                    network = copy.deepcopy(network_pre)
#                     print("Cannot drop out the nero number: %d / %d" %(k, p))

                    ## k++
                    k+=1

# %%
evaluation_table_train = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
evaluation_table_test = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
performance_record = pd.DataFrame(columns=["Date","Mean of error", "SD of error"])

date, x_data, y_data= get_data(4)
x_data = sc.fit_transform(x_data)
y_data = sc.fit_transform(y_data[:,0].reshape(-1,1))
threshold_for_error = 6000/(sc.data_max_-sc.data_min_)

data = range(x_data.shape[0])
# window_size => the length of training block
window_size = 212
# step_window => step size of each window
step_window = 4
# the split data
splits = []

## Moving window mechnism
for i in range(window_size, len(data), step_window):
    train = np.array(data[i-window_size:i])
    test = np.array(data[i:i+step_window])
#     test = np.array(data[i-window_size:i+step_window])
    splits.append(('TRAIN:', train, 'TEST:', test))


start = time.time()
for i_block in range(len(splits)):
# for i_block in range(2):
    block_start = time.time()
    ## Record the number of each step
    nb_step4 = 0
    nb_step6_1 = 0
    nb_step6_2 = 0
    
#     print("The <<%d>> Window" %(i_block+1))
    
    x_train = x_data[splits[i_block][1]]
    x_test = x_data[splits[i_block][3]]
    y_train = y_data[splits[i_block][1]]
    y_test = y_data[splits[i_block][3]]
    
    x_train_scaled = torch.FloatTensor(x_train)
    x_test_scaled = torch.FloatTensor(x_test)
    y_train_scaled = torch.FloatTensor(y_train)
    y_test = sc.inverse_transform(y_test)

    if i_block == 0:
        
        lower = torch.mean(y_train_scaled)-0.1*torch.std(y_train_scaled)
        upper = torch.mean(y_train_scaled)+0.1*torch.std(y_train_scaled)
        nonoutlier_index = torch.nonzero((y_train_scaled[:,0]>lower)&(y_train_scaled[:,0]<upper), as_tuple =False).reshape([-1])
        
        initial_x = x_train_scaled[nonoutlier_index[:19]]
        initial_y = y_train_scaled[nonoutlier_index[:19]]
        
        x_train_scaled = np.delete(x_train_scaled, nonoutlier_index[:19], 0)
        y_train_scaled = np.delete(y_train_scaled, nonoutlier_index[:19], 0)
        
        network = Network(1,initial_x,initial_y)
        
        network.nb_node_acceptable = torch.IntTensor([1 for _ in range(initial_x.shape[0])])
        network.threshold_for_error = round(threshold_for_error[0],2)
        
        initializing(network, initial_x, initial_y)
        
#         print("<<Initializing後看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
#         print("threshold_for_error:",network.threshold_for_error)
        remainder = int(window_size) - initial_x.shape[0]
        nb_step4 += initial_x.shape[0]
        
    else:

        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        restart_index = int(x_train_scaled.shape[0])-step_window
#         print("其他區塊剛開始選的資料索引：",sorted_index[:restart_index])
        init_x = x_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,x_train_scaled.shape[1])
        init_y = y_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,1)
        network.setData(init_x, init_y)
        network.nb_node_acceptable = torch.IntTensor([network.linear1.bias.data.shape[0] for _ in range(init_x.shape[0])])
        network.nb_node_pruned = 0
        
#         print("<<其他區塊剛開始時看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
        
        remainder = int(window_size) - init_x.shape[0]
        x_train_scaled = np.delete(x_train_scaled, sorted_index[:restart_index], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[:restart_index], 0)
        nb_step4 += init_x.shape[0]

    for i in range(remainder):
#     for i in range(3):
        
        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        
        ## Add new data for training     
        network.addData(x_train_scaled[sorted_index[0]], y_train_scaled[sorted_index[0]])
        x_train_scaled = np.delete(x_train_scaled, sorted_index[0], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[0], 0)
        
        yo,loss = network.forward()
        pre_network = copy.deepcopy(network)
        
        if not torch.all(torch.abs(network.y-yo)<=network.threshold_for_error):

            network.acceptable = False
            network = matching(network)
            
            
            if network.acceptable == False:
                
                network = copy.deepcopy(pre_network)
                cramming(network)

                if network.acceptable == False:
                    sys.exit(0)  
                
                nb_step6_2 += 1

            else:
                nb_step6_1 += 1

        else:
            nb_step4 += 1

        network = reorganizing(network)
        yo,loss = network.forward()
        
        network.nb_node_acceptable = torch.cat([network.nb_node_acceptable, torch.IntTensor([network.linear1.bias.data.shape[0]])],0)

#     print("<<The performance of %d window>>"%(i_block+1))
    block_end = time.time()
    evaluation_table_train, evaluation_table_test, performance_record = validation(date.iloc[splits[i_block][1][-1],:], network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled,x_test_scaled, y_test, block_start, block_end,i_block+1,evaluation_table_train,evaluation_table_test,performance_record)

    evaluation_table_train.to_csv("evaluation_table_train.csv",index=False)
    evaluation_table_test.to_csv("evaluation_table_inferencing.csv",index=False)
    performance_record.to_csv("performance.csv", index=False)
# Out:
# The forecast copper price for next week(2015-11-23): 50026.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 24.00
# Std of error: 41.04
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2015-11-30): 50026.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 24.00
# Std of error: 41.04
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2015-12-07): 50026.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 24.00
# Std of error: 41.04
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2015-12-14): 50026.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 24.00
# Std of error: 41.04
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2015-12-21): 38531.89 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1223.90
# Std of error: 1024.82
# The accuracy(3000): 93.84%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2015-12-28): 38093.04 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1223.90
# Std of error: 1024.82
# The accuracy(3000): 93.84%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-01-04): 39286.38 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1223.90
# Std of error: 1024.82
# The accuracy(3000): 93.84%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-01-11): 39739.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1223.90
# Std of error: 1024.82
# The accuracy(3000): 93.84%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-01-18): 38473.09 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1082.13
# Std of error: 905.32
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-01-25): 38751.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1082.13
# Std of error: 905.32
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-02-01): 39113.17 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1082.13
# Std of error: 905.32
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-02-08): 39355.40 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 1082.13
# Std of error: 905.32
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-02-15): 38688.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 997.11
# Std of error: 865.76
# The accuracy(3000): 96.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-02-22): 39402.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 997.11
# Std of error: 865.76
# The accuracy(3000): 96.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-02-29): 39782.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 997.11
# Std of error: 865.76
# The accuracy(3000): 96.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-03-07): 39607.60 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 997.11
# Std of error: 865.76
# The accuracy(3000): 96.68%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-03-14): 38666.62 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 953.60
# Std of error: 852.09
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-03-21): 37963.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 953.60
# Std of error: 852.09
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-03-28): 38418.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 953.60
# Std of error: 852.09
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-04-04): 38598.02 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 953.60
# Std of error: 852.09
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-04-11): 38157.38 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 914.88
# Std of error: 838.65
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-04-18): 38130.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 914.88
# Std of error: 838.65
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-04-25): 37889.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 914.88
# Std of error: 838.65
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-05-02): 37719.27 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 914.88
# Std of error: 838.65
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-05-09): 36589.01 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 900.77
# Std of error: 838.06
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-05-16): 36508.78 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 900.77
# Std of error: 838.06
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-05-23): 36641.81 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 900.77
# Std of error: 838.06
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-05-30): 36646.11 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 900.77
# Std of error: 838.06
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-06-06): 37085.32 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 852.50
# Std of error: 818.97
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-06-13): 37922.76 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 852.50
# Std of error: 818.97
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-06-20): 38490.67 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 852.50
# Std of error: 818.97
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-06-27): 39034.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 852.50
# Std of error: 818.97
# The accuracy(3000): 96.21%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-07-04): 38729.60 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 829.46
# Std of error: 808.04
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-07-11): 38630.75 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 829.46
# Std of error: 808.04
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-07-18): 38204.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 829.46
# Std of error: 808.04
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-07-25): 37490.03 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 829.46
# Std of error: 808.04
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-08-01): 37099.49 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 814.72
# Std of error: 798.95
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-08-08): 37008.69 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 814.72
# Std of error: 798.95
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-08-15): 37533.86 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 814.72
# Std of error: 798.95
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-08-22): 37319.39 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 814.72
# Std of error: 798.95
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-08-29): 37211.11 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 799.30
# Std of error: 787.32
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-09-05): 37478.01 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 799.30
# Std of error: 787.32
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-09-12): 37805.83 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 799.30
# Std of error: 787.32
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-09-19): 38030.62 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 799.30
# Std of error: 787.32
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-09-26): 38148.18 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 758.46
# Std of error: 731.58
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-10-03): 38362.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 758.46
# Std of error: 731.58
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-10-10): 39106.58 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 758.46
# Std of error: 731.58
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-10-17): 40464.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 758.46
# Std of error: 731.58
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-10-24): 42902.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 782.34
# Std of error: 775.25
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-10-31): 44337.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 782.34
# Std of error: 775.25
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-11-07): 45369.99 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 782.34
# Std of error: 775.25
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-11-14): 45635.40 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 782.34
# Std of error: 775.25
# The accuracy(3000): 97.16%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-11-21): 46234.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 777.84
# Std of error: 734.84
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-11-28): 44979.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 777.84
# Std of error: 734.84
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-12-05): 44321.48 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 777.84
# Std of error: 734.84
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-12-12): 44654.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 777.84
# Std of error: 734.84
# The accuracy(3000): 98.10%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-12-19): 45861.86 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 765.04
# Std of error: 706.78
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2016-12-26): 46543.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 765.04
# Std of error: 706.78
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-01-02): 46728.76 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 765.04
# Std of error: 706.78
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-01-09): 47179.58 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 765.04
# Std of error: 706.78
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-01-16): 47377.00 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 751.34
# Std of error: 687.99
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-01-23): 48797.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 751.34
# Std of error: 687.99
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-01-30): 48617.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 751.34
# Std of error: 687.99
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-02-06): 48091.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 751.34
# Std of error: 687.99
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-02-13): 47676.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 742.94
# Std of error: 675.75
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-02-20): 47678.58 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 742.94
# Std of error: 675.75
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-02-27): 47607.74 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 742.94
# Std of error: 675.75
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-03-06): 47448.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 742.94
# Std of error: 675.75
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-03-13): 48211.33 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 730.55
# Std of error: 665.63
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-03-20): 47977.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 730.55
# Std of error: 665.63
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-03-27): 47542.92 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 730.55
# Std of error: 665.63
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-04-03): 47381.25 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 730.55
# Std of error: 665.63
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-04-10): 47027.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 732.93
# Std of error: 667.19
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-04-17): 46508.82 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 732.93
# Std of error: 667.19
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-04-24): 46969.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 732.93
# Std of error: 667.19
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-05-01): 47547.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 732.93
# Std of error: 667.19
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-05-08): 46945.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.97
# Std of error: 655.94
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-05-15): 47160.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.97
# Std of error: 655.94
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-05-22): 47376.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.97
# Std of error: 655.94
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-05-29): 47041.88 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.97
# Std of error: 655.94
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-06-05): 47316.64 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.26
# Std of error: 658.49
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-06-12): 47528.51 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.26
# Std of error: 658.49
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-06-19): 47592.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.26
# Std of error: 658.49
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-06-26): 47891.31 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 711.26
# Std of error: 658.49
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-07-03): 48995.00 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 677.18
# Std of error: 604.72
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-07-10): 49831.26 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 677.18
# Std of error: 604.72
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-07-17): 50137.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 677.18
# Std of error: 604.72
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-07-24): 50411.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 677.18
# Std of error: 604.72
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-07-31): 51157.13 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.18
# Std of error: 591.47
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-08-07): 52265.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.18
# Std of error: 591.47
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-08-14): 52768.94 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.18
# Std of error: 591.47
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-08-21): 51768.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.18
# Std of error: 591.47
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-08-28): 50594.82 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 671.25
# Std of error: 586.68
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-09-04): 50345.44 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 671.25
# Std of error: 586.68
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-09-11): 51157.48 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 671.25
# Std of error: 586.68
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-09-18): 52469.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 671.25
# Std of error: 586.68
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-09-25): 53833.41 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 674.26
# Std of error: 600.71
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-10-02): 54460.44 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 674.26
# Std of error: 600.71
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-10-09): 53693.72 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 674.26
# Std of error: 600.71
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-10-16): 53808.00 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 674.26
# Std of error: 600.71
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-10-23): 53445.90 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.05
# Std of error: 594.37
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-10-30): 53158.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.05
# Std of error: 594.37
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-11-06): 52926.22 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.05
# Std of error: 594.37
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-11-13): 52146.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.05
# Std of error: 594.37
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-11-20): 51984.04 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 651.24
# Std of error: 591.98
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-11-27): 52691.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 651.24
# Std of error: 591.98
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-12-04): 53401.85 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 651.24
# Std of error: 591.98
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-12-11): 53667.79 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 651.24
# Std of error: 591.98
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-12-18): 54201.29 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.09
# Std of error: 595.79
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2017-12-25): 54286.29 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.09
# Std of error: 595.79
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-01-01): 53304.44 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.09
# Std of error: 595.79
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-01-08): 52827.19 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.09
# Std of error: 595.79
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-01-15): 52120.88 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 663.28
# Std of error: 585.41
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-01-22): 52038.41 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 663.28
# Std of error: 585.41
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-01-29): 52406.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 663.28
# Std of error: 585.41
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-02-05): 52516.17 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 663.28
# Std of error: 585.41
# The accuracy(3000): 99.05%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-02-12): 52817.26 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 659.38
# Std of error: 578.59
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-02-19): 52801.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 659.38
# Std of error: 578.59
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-02-26): 51537.25 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 659.38
# Std of error: 578.59
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-03-05): 50317.02 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 659.38
# Std of error: 578.59
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-03-12): 50581.40 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.11
# Std of error: 567.98
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-03-19): 51075.35 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.11
# Std of error: 567.98
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-03-26): 51320.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.11
# Std of error: 567.98
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-04-02): 51679.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 662.11
# Std of error: 567.98
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-04-09): 52319.41 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 661.03
# Std of error: 564.19
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-04-16): 52748.63 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 661.03
# Std of error: 564.19
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-04-23): 52066.28 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 661.03
# Std of error: 564.19
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-04-30): 52279.71 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 661.03
# Std of error: 564.19
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-05-07): 52077.07 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 667.82
# Std of error: 561.58
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-05-14): 52849.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 667.82
# Std of error: 561.58
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-05-21): 53620.75 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 667.82
# Std of error: 561.58
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-05-28): 52865.61 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 667.82
# Std of error: 561.58
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-06-04): 52436.16 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 680.56
# Std of error: 558.24
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-06-11): 51257.47 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 680.56
# Std of error: 558.24
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-06-18): 50020.77 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 680.56
# Std of error: 558.24
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-06-25): 50070.65 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 680.56
# Std of error: 558.24
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-07-02): 50388.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 685.49
# Std of error: 564.49
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-07-09): 50822.96 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 685.49
# Std of error: 564.49
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-07-16): 50731.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 685.49
# Std of error: 564.49
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-07-23): 50575.62 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 685.49
# Std of error: 564.49
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-07-30): 50194.08 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 700.01
# Std of error: 566.67
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-08-06): 50418.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 700.01
# Std of error: 566.67
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-08-13): 49957.77 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 700.01
# Std of error: 566.67
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-08-20): 50005.74 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 700.01
# Std of error: 566.67
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-08-27): 50950.00 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 704.28
# Std of error: 573.07
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-09-03): 51577.35 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 704.28
# Std of error: 573.07
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-09-10): 51753.82 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 704.28
# Std of error: 573.07
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-09-17): 51807.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 704.28
# Std of error: 573.07
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-09-24): 51785.03 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 709.61
# Std of error: 563.27
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-10-01): 51398.80 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 709.61
# Std of error: 563.27
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-10-08): 50773.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 709.61
# Std of error: 563.27
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-10-15): 50723.12 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 709.61
# Std of error: 563.27
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-10-22): 50273.27 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 708.00
# Std of error: 563.36
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-10-29): 50343.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 708.00
# Std of error: 563.36
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-11-05): 50517.73 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 708.00
# Std of error: 563.36
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-11-12): 50549.57 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 708.00
# Std of error: 563.36
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-11-19): 50349.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 693.20
# Std of error: 544.80
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-11-26): 49781.14 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 693.20
# Std of error: 544.80
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-12-03): 48716.30 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 693.20
# Std of error: 544.80
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-12-10): 48430.97 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 693.20
# Std of error: 544.80
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-12-17): 47901.45 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 691.77
# Std of error: 541.13
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-12-24): 47729.77 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 691.77
# Std of error: 541.13
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2018-12-31): 47429.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 691.77
# Std of error: 541.13
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-01-07): 47601.27 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 691.77
# Std of error: 541.13
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-01-14): 47825.35 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.33
# Std of error: 519.29
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-01-21): 48109.28 CNY$/Ton
# ...
# The forecast copper price for next week(2019-10-21): 47570.01 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 642.82
# Std of error: 527.57
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-10-28): 47367.55 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 642.82
# Std of error: 527.57
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-11-04): 47662.70 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 642.82
# Std of error: 527.57
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-11-11): 47321.09 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 642.82
# Std of error: 527.57
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-11-18): 48208.86 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 628.77
# Std of error: 518.41
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-11-25): 48671.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 628.77
# Std of error: 518.41
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-12-02): 49075.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 628.77
# Std of error: 518.41
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-12-09): 49028.10 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 628.77
# Std of error: 518.41
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-12-16): 48792.95 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 619.56
# Std of error: 514.06
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-12-23): 48778.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 619.56
# Std of error: 514.06
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2019-12-30): 48358.69 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 619.56
# Std of error: 514.06
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-01-06): 46827.02 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 619.56
# Std of error: 514.06
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-01-13): 45630.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 620.43
# Std of error: 522.53
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-01-20): 46022.11 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 620.43
# Std of error: 522.53
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-01-27): 46182.35 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 620.43
# Std of error: 522.53
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-02-03): 45945.29 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 620.43
# Std of error: 522.53
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-02-10): 45403.28 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 616.94
# Std of error: 519.48
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-02-17): 44369.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 616.94
# Std of error: 519.48
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-02-24): 42273.29 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 616.94
# Std of error: 519.48
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-03-02): 40203.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 616.94
# Std of error: 519.48
# The accuracy(3000): 100.00%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-03-09): 40899.75 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 649.66
# Std of error: 576.49
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-03-16): 43096.48 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 649.66
# Std of error: 576.49
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-03-23): 44598.68 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 649.66
# Std of error: 576.49
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-03-30): 44333.85 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 649.66
# Std of error: 576.49
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-04-06): 44586.93 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 657.70
# Std of error: 578.86
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-04-13): 45163.66 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 657.70
# Std of error: 578.86
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-04-20): 45489.98 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 657.70
# Std of error: 578.86
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-04-27): 45807.79 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 657.70
# Std of error: 578.86
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-05-04): 45454.05 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.10
# Std of error: 570.24
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-05-11): 45925.27 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.10
# Std of error: 570.24
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-05-18): 47379.63 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.10
# Std of error: 570.24
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-05-25): 47847.77 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 672.10
# Std of error: 570.24
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-06-01): 48516.04 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.66
# Std of error: 561.50
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-06-08): 49466.31 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.66
# Std of error: 561.50
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-06-15): 49915.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.66
# Std of error: 561.50
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-06-22): 51448.96 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 664.66
# Std of error: 561.50
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-06-29): 51669.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 669.58
# Std of error: 569.83
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-07-06): 51281.75 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 669.58
# Std of error: 569.83
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-07-13): 50760.80 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 669.58
# Std of error: 569.83
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-07-20): 49427.46 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 669.58
# Std of error: 569.83
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-07-27): 50039.36 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 668.18
# Std of error: 581.73
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-08-03): 49645.50 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 668.18
# Std of error: 581.73
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-08-10): 49289.84 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 668.18
# Std of error: 581.73
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-08-17): 49434.06 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 668.18
# Std of error: 581.73
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-08-24): 49617.54 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 696.12
# Std of error: 609.02
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-08-31): 49114.27 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 696.12
# Std of error: 609.02
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-09-07): 48962.64 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 696.12
# Std of error: 609.02
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-09-14): 49158.32 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 696.12
# Std of error: 609.02
# The accuracy(3000): 99.53%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-09-21): 50412.28 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 712.28
# Std of error: 604.60
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-09-28): 50800.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 712.28
# Std of error: 604.60
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-10-05): 50569.15 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 712.28
# Std of error: 604.60
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-10-12): 50498.70 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 712.28
# Std of error: 604.60
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-10-19): 51400.43 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 707.40
# Std of error: 583.18
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-10-26): 52388.34 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 707.40
# Std of error: 583.18
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
# The forecast copper price for next week(2020-11-02): 54204.21 CNY$/Ton
# <<Performance measurement>>
# Mean of error: 707.40
# Std of error: 583.18
# The accuracy(3000): 98.58%
# ------------------------------------------------------------------------------------------------------------------------
