# %% [markdown]
# ### Import related package

# %%
## Import tensorflow package for modeling
import torch
from torch.autograd import Variable
import torch.optim as optim

## Data processing
import pandas as pd
import numpy as np

## Min-max normalization
from sklearn.preprocessing import MinMaxScaler

## Plot the graph
import matplotlib.pyplot as plt
# %matplotlib inline

## Initializing module
from sklearn.linear_model import LinearRegression
np.set_printoptions(suppress=True)

## Copy module
import copy

## Used to calculate the training time
import time

## Set the GUP environment
import os
import sys

from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker

# %%
os.chdir('/home/Oring-AI/Model_I/DINKLE/t+2')

# %%
## Set up the display
torch.set_printoptions(sci_mode=False)

# %% [markdown]
# ### Control memory usage space for GPU

# %%
## 查詢有無可用 GPU
torch.cuda.is_available()
## 查詢可用 GPU 的數量
torch.cuda.device_count()
##目前設備
print("目前設備：",torch.cuda.current_device())
## 目前設備名
print("目前設備名：",torch.cuda.get_device_name(0))
# Out:
# 目前設備： 0
# 目前設備名： GeForce GTX 1070 Ti

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# ## Print out some info

# %%
def accuracy_cacl(pred_value, actual_value):
    
#     yo, loss, tape = network.forward()
    performance = []
    performance.append(torch.mean(torch.abs(pred_value - actual_value)))
    performance.append(torch.std(torch.abs(pred_value - actual_value)))
    performance.append(torch.mean(torch.abs((pred_value - actual_value) / actual_value))) 
    performance.append(torch.sqrt(torch.mean((pred_value - actual_value)**2)))
    
    for i in range(2000,3001,1000):
        correct_times = torch.nonzero(torch.abs(pred_value - actual_value) <= i, as_tuple =False)
        accuracy = correct_times.shape[0]/pred_value.shape[0]
        performance.append(accuracy)
                       
    return performance

# %%
def plot_result(name, pred_value, actual_value,block_index):
    
#     fig, ax = plt.subplots(2,2,figsize=(20,10), sharex=True, sharey=True)
    fig, ax = plt.subplots(1,figsize=(20,10), sharex=True, sharey=True)
#     ax.set_xlim(0,pred_value.shape[0])  
    
    
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.plot(pred_value, label="LLAAT")
    ax.plot(actual_value, label="Actual")
    ax.set_title("Forecasted performance for l=%d" %(1))
    ax.legend()
        
    #fig.text(0.5, 0, "Stage of training", ha='center', fontsize=20)
    #fig.text(0, 0.5, "Copper price value", va='center', rotation='vertical')

    fig.suptitle("In the %s process in the M=%d window"%(name, block_index))
    fig.tight_layout()
#     fig.savefig("In the %s process in the M=%d window.png"%(name, block_index),dpi=300,bbox_inches='tight')

# %%
def plot_adopted_node(network,block_index):
    
    fig, ax = plt.subplots(figsize=(20,5))
#     ax.set_xticklabels([i for i in range(network.nb_node_acceptable.shape[0]+5)])
    
    ax.set_title("Total amount of adopted hidden nodes in the training process in the M=%d window"%(block_index))
    ax.plot(network.nb_node_acceptable,"-o")

    ax.set_xlabel("Stage of training")
    ax.set_ylabel("Hidden nodes")
    
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))
#     fig.savefig("hidden nodes in the training process in the M=%d window"%(block_index),dpi=300,bbox_inches='tight')

# %%
def evaluation_table(evaluation_results, block_index, name, performance, nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node):

    
    new_result = pd.DataFrame({

        "Window_index":block_index,
        "Stage":name,
        "MAE" : round(performance[0].item(),2),
        "SD of absolute error":round(performance[1].item(),2),
        "MAPE" : "%.2f"%(performance[2]*100).item(),
        "RMSE" : round(performance[3].item(),2),
#         "Accuracy(2000)" : [round(performance[4]*100,2)],
        "Accuracy(3000)" : [round(performance[5]*100,2)],
        "Step4":nb_step4,
        "Step6.1":nb_step6_1,
        "Step6.2":nb_step6_2,
        "Time":time,
        "Adopted_hidden_node":adopted_hidden_node
    })

    evaluation_results = evaluation_results.append(new_result, ignore_index=True)
    
    return evaluation_results

# %%
def validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled, x_test, y_test, start, end, block_index, evaluation_results_train, evaluation_results_test):

    ## Training_Step
#    print("<<Training step>>")
    print("The training time(s):",end - start)
    time = end - start
    yo, loss= network.forward()
    
    ## N - outlier
    pre_train = yo.data.cpu()
    true_train = network.y.data.cpu()
    
    pred_value_train = torch.FloatTensor(sc.inverse_transform(pre_train))
    actual_value_train = torch.FloatTensor(sc.inverse_transform(true_train))
    accuracy_train = accuracy_cacl(pred_value_train,actual_value_train)

    ## B
    pred_value_test = torch.FloatTensor(sc.inverse_transform(network.forecast(x_test).data.cpu()))
    accuracy_test = accuracy_cacl(pred_value_test, y_test)
    
#     total_time = nb_step4 + nb_step6_1 + nb_step6_2
#     print("<<The percentage of each step>>")
#     print("Step 4: %.2f%%"%((nb_step4/total_time)*100))
#     print("Step 6.1: %.2f%%"%((nb_step6_1/total_time)*100))
#     print("Step 6.2: %.2f%%"%((nb_step6_2/total_time)*100))
    
#     print("-"*60)
#     print("Total frequency of cramming occurrences:",nb_step6_2)

#     print("-"*60)
#     print("The amount of hidden node that be pruned:",network.nb_node_pruned)

#     print("-"*60)
    adopted_hidden_node = network.nb_node_acceptable[-1].item()
#     print("The amount of adopted hidden nodes:",network.nb_node_acceptable[-1].item())

#     print("-"*60)
#     print("<<Accuracy in training step>>")
#     print("The MAE for l = 1: %.2f" %(accuracy_train[0]))
#     print("The MAPE for l = 1: %.2f%%" %(accuracy_train[1]))
#     print("The RMSE for l = 1: %.2f" %(accuracy_train[2]))
#     print("The accuracy(2000) for l = 1: %.2f%%" %(accuracy_train[3]*100))
#     print("The accuracy(3000) for l = 1: %.2f%%" %(accuracy_train[4]*100))

    print("The forecast copper price for the second week:", pred_value_test[-4:].tolist())
    print("<<Performance measurement>>")
    print("The MAE: %.1f" %(accuracy_test[0]))
    print("The standard deviation of absolute error: %.1f" %(accuracy_test[1]))
    print("The MAPE: %.1f%%" %(accuracy_test[2]))
    print("The RMSE: %.1f" %(accuracy_test[3]))
#    print("The accuracy(2000) for l = 1: %.1f%%" %(accuracy_test[4]*100))
    print("The accuracy(3000): %.1f%%" %(accuracy_test[5]*100))
    print("-"*120)

    
    evaluation_table_train = evaluation_table(evaluation_results_train, block_index, "Training", accuracy_train,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    evaluation_table_test = evaluation_table(evaluation_results_test, block_index, "Inferencing", accuracy_test,nb_step4, nb_step6_1, nb_step6_2, time,adopted_hidden_node)
    pre_LDSS = sc.inverse_transform(network.forecast(x_test).data.cpu())
#     pd.DataFrame(pre_LDSS).to_csv("pre_LDSS_%d.csv"%(block_index), index=False)
    
#     plot_result("training",pred_value_train, actual_value_train,block_index)
#     plot_result("inferencing",pred_value_test, y_test,block_index)
#     plot_adopted_node(network,block_index)
    
    return(evaluation_table_train, evaluation_table_test)

# %% [markdown]
# ### Preprocessing the data

# %%
def read(path):
    return pd.read_csv(path)

# %%
def buildTrain(train, pastWeek=4, futureWeek=4, defaultWeek=1):
    X_train, Y_train = [], []
    for i in range(train.shape[0]-futureWeek-pastWeek):
        X = np.array(train.iloc[i:i+defaultWeek])
        X = np.append(X,train["CCSP"].iloc[i+defaultWeek:i+pastWeek])
        X_train.append(X.reshape(X.size))
        Y_train.append(np.array(train.iloc[i+pastWeek:i+pastWeek+futureWeek]["CCSP"]))
    return np.array(X_train), np.array(Y_train)

# %% [markdown]
# ### Min-max normalization

# %%
## Use min-max normalization to scale the data to the range from 1 to 0
sc = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# ### Design get_data() to get data

# %%
def get_data(futureWeek):
    
    ## Read weekly copper price data
    path = "WeeklyFinalData.csv"
    data = read(path)
    
    date = data["Date"]
    data.drop("Date", axis=1, inplace=True)
    
    ## Add time lag (pastWeek=4, futureWeek=1)
    x_data, y_data = buildTrain(data, futureWeek=futureWeek)


    return (x_data, y_data)

# %% [markdown]
# ### Network class

# %%
class Network(torch.nn.Module):
    
    def __init__(self, nb_neuro, x_train_scaled, y_train_scaled):
        
        super(Network, self).__init__()
        self.linear1 = torch.nn.Linear(x_train_scaled.shape[1], nb_neuro).cuda()
        self.linear2 = torch.nn.Linear(nb_neuro, 1).cuda()
        
        
        # Stop criteria - threshold
        self.threshold_for_error = 0.12
        self.threshold_for_lr = 1e-4
        
        # Input data 
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
        
        # Learning rate
        self.learning_rate = 1e-3
        
        # Whether the network is acceptable, default as False
        self.acceptable = False
        
        # Some record for experiment
        self.nb_node_pruned = 0
        self.nb_node_acceptable=torch.IntTensor([nb_neuro])
        
        self.limit = nb_neuro
        
    ## Forecast the test data
    def forecast(self, x_test):
    
        x_test = torch.FloatTensor(x_test).cuda()
        activation_value = self.linear1(x_test).clamp(min=0)
        forecast_value = self.linear2(activation_value)
       
        return forecast_value

    ## Reset the x and y data
    def setData(self, x_train_scaled, y_train_scaled):
        self.x = torch.FloatTensor(x_train_scaled).cuda()
        self.y = torch.FloatTensor(y_train_scaled).cuda()
    
    ## Add the new data to the x and y data
    def addData(self, new_x_train, new_y_train):

        self.x = torch.cat([self.x, new_x_train.reshape(1,-1).cuda()],0)
        self.y = torch.cat([self.y, new_y_train.reshape(-1,1).cuda()],0)
    
    ## forward operation
    def forward(self, reg_strength=0):
       
        y1 = self.linear1(self.x).clamp(min=0)
        yo = self.linear2(y1)

        # performance measure
        param_val= torch.sum(torch.pow(self.linear2.bias.data,2))+torch.sum(torch.pow(self.linear2.weight.data,2))+torch.sum(torch.pow(self.linear1.bias.data,2))+torch.sum(torch.pow(self.linear1.weight.data,2))
        reg_term= reg_strength/((self.linear2.bias.data.shape[0]*(self.linear2.weight.data.shape[1]+1)) +(self.linear1.bias.data.shape[0]*(self.linear1.weight.data.shape[1]+1)))*param_val
        loss = torch.nn.functional.mse_loss(yo,self.y)+reg_term
        loss = loss.cuda()
        return(yo, loss)

    # backward operation
    def backward_Adadelta(self,loss):    

        optimizer = optim.Adadelta(self.parameters(), lr=self.learning_rate)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ### Initializing module (Check)

# %%
def initializing(network, initial_x, initial_y):
#     print("Initializing module")
    ## Find each minimum output value y
    min_y = torch.min(initial_y, axis=0)
    ## Subtract min_y from each y
    res_y = initial_y-min_y.values
    
    ## Use linear regression to find the initial W1,b1,Wo,bo
    reg = LinearRegression().fit(initial_x, res_y)
    
    ## Set up the initial parameter of the network
    network.linear1.weight = torch.nn.Parameter(torch.FloatTensor(reg.coef_).cuda())
    network.linear1.bias = torch.nn.Parameter(torch.FloatTensor(reg.intercept_).cuda())
    network.linear2.weight=torch.nn.Parameter(torch.FloatTensor([[1]]).cuda())
    network.linear2.bias = torch.nn.Parameter(torch.FloatTensor(min_y.values).cuda())
    
#     print(reg.coef_)
#     print(reg.intercept_)

    ## Set up the acceptable of the initial network as True
    network.acceptable =True

# %% [markdown]
# ### Selecting module (Check)

# %%
def selecting(network, x_train_scaled, y_train_scaled):
    
#     print("<<Selecting module>>")
    loss = []
    temp_network = copy.deepcopy(network)
    
    ## Put each data into network to calculate the loss value
    for i in range(x_train_scaled.shape[0]):
        temp_network.setData(x_train_scaled[i].reshape(1,-1), y_train_scaled[i].reshape(-1,1))
        loss.append((temp_network.forward()[1].item(),i))
#         print(network.state_dict())
#         print(temp_network.y)
#         print("-"*20)
#         print(temp_network.forward()[1])
#         print("-"*20)
#     ## Sort the data according to the loss value from smallest to largest, and save the data index in sorted_index
    sorted_index = [sorted_data[1] for sorted_data in sorted(loss, key = lambda x:x[0])]
    
    
    ## Print out some info for debug
#     print("The loss value of k:",loss[sorted_index[0]])
#     print("The second_loss value of k:",loss[sorted_index[1]])
#     print("Selecting module finish!")
#     print("Loss",loss)
#     print(network.state_dict())
    
    return sorted_index

# %% [markdown]
# ### Matching

# %%
def matching(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(10000):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ### Matching for reorganizing

# %%
def matching_for_reorganizing(network):

    times_enlarge=0
    times_shrink=0
    
#     print("<<Matching module for reorganizing>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3
    network.acceptable = False
    initial_network = copy.deepcopy(network)
    yo, loss = network.forward()
    
    if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

        network.acceptable = True
#         print("Matching(o) first finished - the network is acceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(network)
    
    else:
        
        for i in range(500):
            
            yo, loss = network.forward()
            network_pre = copy.deepcopy(network)
            loss_pre = loss

            # Backward and check the loss performance of the network with new learning rate
            network.backward_Adadelta(loss)
            yo, loss = network.forward()

            # Confirm whether the loss value of the adjusted network is smaller than the current one
            if loss <= loss_pre and torch.all(torch.abs(yo-network.y) < network.threshold_for_error):

                # If true, multiply the learning rate by 1.2
                network.acceptable = True
#                 print("Matching finished(o) - the network is acceptable")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

            elif loss <= loss_pre:
                
                times_enlarge+=1
                network.learning_rate *= 1.2


            else:         

                # Identify whether the current learning rate is less than the threshold
                if network.learning_rate <= network.threshold_for_lr:

                    # If true, set the acceptable of the network as false and return it
                    network.acceptable = False
#                     print("Matching finished(o) - the network is Unacceptable")
#                     print("Number of enlarge:",times_enlarge)
#                     print("Number of shrink:",times_shrink)
                    return(initial_network)

                # On the contrary, restore w and adjust the learning rate
                else:
                    
                    # Restore the papameter of the network
                    network = copy.deepcopy(network_pre)
                    times_shrink+=1
                    network.learning_rate *= 0.7
                
        network.acceptable = False
#         print("Matching的第%d回合"%(i+1))
#         print("Matching finished - the network is Unacceptable")
#         print("Number of enlarge:",times_enlarge)
#         print("Number of shrink:",times_shrink)
        return(initial_network)

# %% [markdown]
# ## Cramming module (Check)

# %%
def cramming(network):
    
    torch.random.manual_seed(0)
#     print("<<Cramming module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    ## Find unsatisfied data:K
    yo, loss = network.forward()
    undesired_index = torch.nonzero(torch.abs(yo-network.y) > network.threshold_for_error+0.001, as_tuple =False)

    ## Print out the undesired_index for debug
#     print("不滿足個數：",undesired_index.shape[0])
#     print("The index of the undesired data:",undesired_index)

    
    if undesired_index.shape[0] == 1:
        
        # Unsatisfied situation
        ## Find the index of the unsatisfied data
        k_data_num = undesired_index[0][0]

        undesired_data = torch.reshape(network.x[k_data_num,:], [1,-1])

        ## Remove the data that does not meet the error term
        left_data = network.x[:k_data_num,:]
        right_data = network.x[k_data_num+1:,:]
        remain_tensor = torch.cat([left_data, right_data], 0)


        ## Use the random method to find out the gamma and zeta
        while True:

            ## Find m-vector gamma: r
            ## Use the random method to generate the gamma that can make the conditions met
            gamma = torch.rand(size=[1,network.x.shape[1]]).cuda()
            subtract_undesired_data = torch.sub(remain_tensor, undesired_data)
            matmul_value = torch.mm(gamma,torch.t(subtract_undesired_data))

            if torch.all(matmul_value != 0):
                break

        while True:

            ## Find the tiny value: zeta
            ## Use the random method to generate the zeta that can make the conditions met
            zeta = torch.rand(size=[1]).cuda()

            if torch.all(torch.mul(torch.add(zeta,matmul_value),torch.sub(zeta,matmul_value))<0):
                break


        k_l = undesired_index[0][1]
        
        ## The weight of input layer to hidden layer I
        w10 = gamma
        w11 = gamma
        w12 = gamma

        W1_new = torch.cat([w10,w11,w12],0)
        

        ## The bias of input layer to hidden layer I
        matual_value = torch.mm(gamma,torch.t(undesired_data))
       
        
        b10 = torch.sub(zeta,matual_value)
        b11 = -1*matual_value
        b12 = torch.sub(-1*zeta,matual_value)

        b1_new = torch.reshape(torch.cat([b10,b11,b12],0),[3])

        ## The weight of hidden layer I to output layer
        gap = network.y[k_data_num, k_l]-yo[k_data_num, k_l]

        wo0_value = gap/zeta
        wo1_value = (-2*gap)/zeta
        wo2_value = gap/zeta

        Wo_new = torch.reshape(torch.cat([wo0_value,wo1_value,wo2_value],0),[1,-1])

        ## Add new neuroes to the network
        network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight.data, W1_new]))
        network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias.data, b1_new]))
        network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight.data, Wo_new],1))


        yo, loss = network.forward()
        
        ## Determine if cramming is successful and print out the corresponding information
        if torch.all(torch.abs(yo-network.y) <= network.threshold_for_error):
            network.acceptable = True 
#             print("Cramming success!")

        else:
#             print("Cramming failed!")
            pass
    
    else:
#         print("條件不合，不能Cramming")
        pass

# %% [markdown]
# ### Regularizing module (Check)

# %%
def regularizing(network):

#     print("<<Regularizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    ## Record the number of executions
    times_enlarge = 0
    times_shrink = 0
    ## Set up the learning rate of the network
    network.learning_rate = 1e-3

    ## Set epoch to 100
    for i in range(100):

        ## Store the parameter of the network
        network_pre = copy.deepcopy(network)
        yo, loss = network.forward(1e-3)
        loss_pre = loss
        
        ## Backward operation to obtain w'
        network.backward_Adadelta(loss)
        yo, loss = network.forward(1e-3)

        # Confirm whether the adjusted loss value is smaller than the current one
        if loss <= loss_pre:
            
            ## Identify that all forecast value has met the error term
            if torch.all(torch.abs(yo-network.y) < network.threshold_for_error):
                
                ## If true, multiply the learning rate by 1.2
                network.learning_rate *= 1.2
                times_enlarge += 1

            else:

                ## Else, restore w and end the process
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-因為沒有顧好預測誤差")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

        # If the adjusted loss value is not smaller than the current one
        else:

            ## If the learning rate is greater than the threshold for learning rate
            if network.learning_rate > network.threshold_for_lr:
                
                ## Restore the w and multiply the learning rate by 0.7
                network = copy.deepcopy(network_pre)
                network.learning_rate *= 0.7
                times_shrink += 1

             ## If the learning rate is smaller than the threshold for learning rate
            else:
                
                ## Restore the w
                network = copy.deepcopy(network_pre)
#                 print("Regularizing結束-Learning不能這麼小")
#                 print("Number of enlarge:",times_enlarge)
#                 print("Number of shrink:",times_shrink)
                return(network)

#     print("第\"%d\"回合Regularizing module完畢"%(i+1))
#     print("Number of enlarge:",times_enlarge)
#     print("Number of shrink:",times_shrink)
    return(network)

# %% [markdown]
# ### Reorganizing module (Check)

# %%
def reorganizing(network):
#     print("<<Reorganizing module>>")
#     print("threshold_for_error:",network.threshold_for_error)
    
    limit = 4
    if network.linear1.bias.shape[0] <= limit:
        network = regularizing(network)
        return(network)
    
    else:
        
        ## Set up the k = 1, and p = the number of hidden node
        k = 1
    #     p = network.W1.shape[1]
        p = network.linear1.weight.data.shape[0]

        while True:

            ## If k > p, end of Process
            if k > p or p<=limit:

#                 print("Reorganizing result: The final number of neuro is ",p)
                return(network)

            ## Else, Process is ongoing
            else:

                ## Using the regularizing module to adjust the network
                network = regularizing(network)

                ## Store the network and w
                network_pre = copy.deepcopy(network)

                ## Set up the acceptable of the network as false
                network.acceptable = False
                
            
                ## Ignore the K hidden node
                network.linear1.weight = torch.nn.Parameter(torch.cat([network.linear1.weight[:k-1],network.linear1.weight[k:]],0))
                network.linear1.bias = torch.nn.Parameter(torch.cat([network.linear1.bias[:k-1],network.linear1.bias[k:]]))
                network.linear2.weight = torch.nn.Parameter(torch.cat([network.linear2.weight[:,:k-1],network.linear2.weight[:,k:]],1))

                
                ## Using the matching module to adjust the network
                network = matching_for_reorganizing(network)

#                 print("是不是可以不要這個hidden node:",network.acceptable)

                ## If the resulting network is acceptable, this means that the k hidden node can be removed
                if network.acceptable:

#                     print("Drop out the nero number: %d / %d" %(k, p))
                    network.nb_node_pruned += 1
                    ## p--
                    p-=1

                ## Else, it means that the k hidden node cannot be removed
                else:

                    ## Restore the network and w
                    network = copy.deepcopy(network_pre)
#                     print("Cannot drop out the nero number: %d / %d" %(k, p))

                    ## k++
                    k+=1

# %%
evaluation_table_train = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
evaluation_table_test = pd.DataFrame(columns=["Window_index","Stage","MAE","SD of absolute error","MAPE","RMSE","Accuracy(3000)","Step4","Step6.1","Step6.2","Time","Adopted_hidden_node"])
    
x_data, y_data= get_data(4)
x_data = sc.fit_transform(x_data)
y_data = sc.fit_transform(y_data[:,1].reshape(-1,1))
threshold_for_error = 8000/(sc.data_max_-sc.data_min_)

data = range(x_data.shape[0])
# window_size => the length of training block
window_size = 212
# step_window => step size of each window
step_window = 4
# the split data
splits = []

## Moving window mechnism
for i in range(window_size, len(data), step_window):
    train = np.array(data[i-window_size:i])
#     test = np.array(data[i:i+step_window])
    test = np.array(data[i-window_size:i+step_window])
    splits.append(('TRAIN:', train, 'TEST:', test))


start = time.time()
for i_block in range(len(splits)):
# for i_block in range(2):
    block_start = time.time()
    ## Record the number of each step
    nb_step4 = 0
    nb_step6_1 = 0
    nb_step6_2 = 0
    
    print("The <<%d>> Window" %(i_block+1))
    
    x_train = x_data[splits[i_block][1]]
    x_test = x_data[splits[i_block][3]]
    y_train = y_data[splits[i_block][1]]
    y_test = y_data[splits[i_block][3]]
    
    x_train_scaled = torch.FloatTensor(x_train)
    x_test_scaled = torch.FloatTensor(x_test)
    y_train_scaled = torch.FloatTensor(y_train)
    y_test = sc.inverse_transform(y_test)

    if i_block == 0:
        lower = torch.mean(y_train_scaled)-0.1*torch.std(y_train_scaled)
        upper = torch.mean(y_train_scaled)+0.1*torch.std(y_train_scaled)
        nonoutlier_index = torch.nonzero((y_train_scaled[:,0]>lower)&(y_train_scaled[:,0]<upper), as_tuple =False).reshape([-1])
        
        initial_x = x_train_scaled[nonoutlier_index[:19]]
        initial_y = y_train_scaled[nonoutlier_index[:19]]
        
        x_train_scaled = np.delete(x_train_scaled, nonoutlier_index[:19], 0)
        y_train_scaled = np.delete(y_train_scaled, nonoutlier_index[:19], 0)
        
        network = Network(1,initial_x,initial_y)
        
        network.nb_node_acceptable = torch.IntTensor([1 for _ in range(initial_x.shape[0])])
        network.threshold_for_error = round(threshold_for_error[0],2)
        
        initializing(network, initial_x, initial_y)
        nb_step4 += initial_x.shape[0]
#         print("<<Initializing後看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
#         print("threshold_for_error:",network.threshold_for_error)
        remainder = int(window_size) - initial_x.shape[0]
    
    else:

        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        restart_index = int(x_train_scaled.shape[0])-step_window
#         print("其他區塊剛開始選的資料索引：",sorted_index[:restart_index])
        init_x = x_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,x_train_scaled.shape[1])
        init_y = y_train_scaled[sorted_index[:int(x_train_scaled.shape[0])-step_window]].reshape(-1,1)
        network.setData(init_x, init_y)
        network.nb_node_acceptable = torch.IntTensor([network.linear1.bias.data.shape[0] for _ in range(init_x.shape[0])])
        network.nb_node_pruned = 0
        
#         print("<<其他區塊剛開始時看一下差異>>")
#         yo,loss = network.forward()
#         print(torch.abs(network.y-yo))
        
        remainder = int(window_size) - init_x.shape[0]
        x_train_scaled = np.delete(x_train_scaled, sorted_index[:restart_index], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[:restart_index], 0)
        nb_step4 += init_x.shape[0]

    for i in range(remainder):
#    for i in range(3):
        
        sorted_index = selecting(network, x_train_scaled, y_train_scaled)
        
        ## Add new data for training     
        network.addData(x_train_scaled[sorted_index[0]], y_train_scaled[sorted_index[0]])
        x_train_scaled = np.delete(x_train_scaled, sorted_index[0], 0)
        y_train_scaled = np.delete(y_train_scaled, sorted_index[0], 0)
        
        yo,loss = network.forward()
        pre_network = copy.deepcopy(network)
        
        if not torch.all(torch.abs(network.y-yo)<=network.threshold_for_error):

            network.acceptable = False
            network = matching(network)
            
            
            if network.acceptable == False:
                
                network = copy.deepcopy(pre_network)
                cramming(network)

                if network.acceptable == False:
                    sys.exit(0)  
                
                nb_step6_2 += 1

            else:
                nb_step6_1 += 1

        else:
            nb_step4 += 1

        network = reorganizing(network)
        yo,loss = network.forward()
        
        network.nb_node_acceptable = torch.cat([network.nb_node_acceptable, torch.IntTensor([network.linear1.bias.data.shape[0]])],0)

#     print("<<The performance of %d window>>"%(i_block+1))
    block_end = time.time()
    evaluation_table_train, evaluation_table_test = validation(network, nb_step4, nb_step6_1, nb_step6_2, x_train_scaled, y_train_scaled,x_test_scaled, y_test, block_start, block_end,i_block+1,evaluation_table_train,evaluation_table_test)

    evaluation_table_train.to_csv("evaluation_table_train.csv",index=False)
    evaluation_table_test.to_csv("evaluation_table_inferencing.csv",index=False)
# Out:
# The <<1>> Window
# The training time(s): 67.30842351913452
# The forecast copper price for the second week: [[43165.5703125], [43382.1484375], [43010.828125], [43208.2421875]]
# <<Performance measurement>>
# The MAE: 1958.2
# The standard deviation of absolute error: 1715.4
# The MAPE: 0.0%
# The RMSE: 2600.7
# The accuracy(3000): 81.0%
# ----------------------------------------------------------------------------------------------------
# The <<2>> Window
# The training time(s): 1.2732701301574707
# The forecast copper price for the second week: [[42002.70703125], [41578.28125], [42194.60546875], [42012.4765625]]
# <<Performance measurement>>
# The MAE: 2023.2
# The standard deviation of absolute error: 1710.2
# The MAPE: 0.0%
# The RMSE: 2646.7
# The accuracy(3000): 80.1%
# ----------------------------------------------------------------------------------------------------
# The <<3>> Window
# The training time(s): 1.247502326965332
# The forecast copper price for the second week: [[40891.17578125], [40288.8671875], [40288.8671875], [40288.8671875]]
# <<Performance measurement>>
# The MAE: 2002.4
# The standard deviation of absolute error: 1640.8
# The MAPE: 0.0%
# The RMSE: 2586.3
# The accuracy(3000): 77.8%
# ----------------------------------------------------------------------------------------------------
# The <<4>> Window
# The training time(s): 1.296356201171875
# The forecast copper price for the second week: [[40146.58203125], [40146.58203125], [40146.58203125], [40146.58203125]]
# <<Performance measurement>>
# The MAE: 2005.0
# The standard deviation of absolute error: 1553.7
# The MAPE: 0.0%
# The RMSE: 2534.3
# The accuracy(3000): 78.2%
# ----------------------------------------------------------------------------------------------------
# The <<5>> Window
# The training time(s): 1.3372347354888916
# The forecast copper price for the second week: [[39936.640625], [39936.640625], [39936.640625], [39936.640625]]
# <<Performance measurement>>
# The MAE: 1997.0
# The standard deviation of absolute error: 1527.8
# The MAPE: 0.0%
# The RMSE: 2512.2
# The accuracy(3000): 76.9%
# ----------------------------------------------------------------------------------------------------
# The <<6>> Window
# The training time(s): 1.2731850147247314
# The forecast copper price for the second week: [[39530.265625], [39530.265625], [39530.265625], [39530.265625]]
# <<Performance measurement>>
# The MAE: 1954.4
# The standard deviation of absolute error: 1514.9
# The MAPE: 0.0%
# The RMSE: 2470.6
# The accuracy(3000): 76.9%
# ----------------------------------------------------------------------------------------------------
# The <<7>> Window
# The training time(s): 1.2491216659545898
# The forecast copper price for the second week: [[38909.93359375], [38909.93359375], [38909.93359375], [38909.93359375]]
# <<Performance measurement>>
# The MAE: 1834.2
# The standard deviation of absolute error: 1490.7
# The MAPE: 0.0%
# The RMSE: 2361.4
# The accuracy(3000): 77.3%
# ----------------------------------------------------------------------------------------------------
# The <<8>> Window
# The training time(s): 1.222926378250122
# The forecast copper price for the second week: [[38395.30078125], [38395.30078125], [38395.30078125], [38395.30078125]]
# <<Performance measurement>>
# The MAE: 1710.3
# The standard deviation of absolute error: 1461.0
# The MAPE: 0.0%
# The RMSE: 2247.2
# The accuracy(3000): 81.9%
# ----------------------------------------------------------------------------------------------------
# The <<9>> Window
# The training time(s): 1.2671480178833008
# The forecast copper price for the second week: [[38140.55078125], [38140.55078125], [38140.55078125], [38140.55078125]]
# <<Performance measurement>>
# The MAE: 1664.4
# The standard deviation of absolute error: 1436.9
# The MAPE: 0.0%
# The RMSE: 2196.6
# The accuracy(3000): 82.4%
# ----------------------------------------------------------------------------------------------------
# The <<10>> Window
# The training time(s): 1.319990634918213
# The forecast copper price for the second week: [[37907.7421875], [37907.7421875], [37907.7421875], [37907.7421875]]
# <<Performance measurement>>
# The MAE: 1617.5
# The standard deviation of absolute error: 1423.2
# The MAPE: 0.0%
# The RMSE: 2152.3
# The accuracy(3000): 82.4%
# ----------------------------------------------------------------------------------------------------
# The <<11>> Window
# The training time(s): 1.3306326866149902
# The forecast copper price for the second week: [[37758.0390625], [37758.0390625], [37758.0390625], [37758.0390625]]
# <<Performance measurement>>
# The MAE: 1560.5
# The standard deviation of absolute error: 1419.2
# The MAPE: 0.0%
# The RMSE: 2107.2
# The accuracy(3000): 82.9%
# ----------------------------------------------------------------------------------------------------
# The <<12>> Window
# The training time(s): 1.262869119644165
# The forecast copper price for the second week: [[37695.609375], [37695.609375], [37695.609375], [37695.609375]]
# <<Performance measurement>>
# The MAE: 1592.6
# The standard deviation of absolute error: 1507.9
# The MAPE: 0.0%
# The RMSE: 2190.8
# The accuracy(3000): 83.3%
# ----------------------------------------------------------------------------------------------------
# The <<13>> Window
# The training time(s): 30.786348581314087
# The forecast copper price for the second week: [[40432.12890625], [40368.8515625], [40355.921875], [40499.3515625]]
# <<Performance measurement>>
# The MAE: 1396.1
# The standard deviation of absolute error: 1436.1
# The MAPE: 0.0%
# The RMSE: 2000.5
# The accuracy(3000): 85.6%
# ----------------------------------------------------------------------------------------------------
# The <<14>> Window
# The training time(s): 1.2658088207244873
# The forecast copper price for the second week: [[45707.93359375], [45364.78515625], [45256.046875], [45737.72265625]]
# <<Performance measurement>>
# The MAE: 1199.6
# The standard deviation of absolute error: 1215.0
# The MAPE: 0.0%
# The RMSE: 1705.4
# The accuracy(3000): 90.7%
# ----------------------------------------------------------------------------------------------------
# The <<15>> Window
# The training time(s): 1.319509506225586
# The forecast copper price for the second week: [[46906.53515625], [46839.8984375], [46977.58203125], [46941.328125]]
# <<Performance measurement>>
# The MAE: 1126.8
# The standard deviation of absolute error: 1170.7
# The MAPE: 0.0%
# The RMSE: 1622.9
# The accuracy(3000): 92.1%
# ----------------------------------------------------------------------------------------------------
# The <<16>> Window
# The training time(s): 1.3814506530761719
# The forecast copper price for the second week: [[47096.75390625], [47692.65234375], [46881.5234375], [46432.97265625]]
# <<Performance measurement>>
# The MAE: 1087.6
# The standard deviation of absolute error: 1146.5
# The MAPE: 0.0%
# The RMSE: 1578.4
# The accuracy(3000): 93.1%
# ----------------------------------------------------------------------------------------------------
# The <<17>> Window
# The training time(s): 1.3205373287200928
# The forecast copper price for the second week: [[45992.125], [46121.3125], [46161.21875], [46403.86328125]]
# <<Performance measurement>>
# The MAE: 1031.0
# The standard deviation of absolute error: 1110.7
# The MAPE: 0.0%
# The RMSE: 1513.6
# The accuracy(3000): 93.1%
# ----------------------------------------------------------------------------------------------------
# The <<18>> Window
# The training time(s): 1.2791285514831543
# The forecast copper price for the second week: [[46892.734375], [46767.3203125], [46546.22265625], [46501.7890625]]
# <<Performance measurement>>
# The MAE: 1022.1
# The standard deviation of absolute error: 1094.5
# The MAPE: 0.0%
# The RMSE: 1495.7
# The accuracy(3000): 93.5%
# ----------------------------------------------------------------------------------------------------
# The <<19>> Window
# The training time(s): 1.2563073635101318
# The forecast copper price for the second week: [[46213.0859375], [46023.87109375], [46341.06640625], [46851.59375]]
# <<Performance measurement>>
# The MAE: 1010.2
# The standard deviation of absolute error: 1079.5
# The MAPE: 0.0%
# The RMSE: 1476.6
# The accuracy(3000): 93.5%
# ----------------------------------------------------------------------------------------------------
# The <<20>> Window
# The training time(s): 1.2762181758880615
# The forecast copper price for the second week: [[46658.40625], [46465.9140625], [46675.09375], [46240.7265625]]
# <<Performance measurement>>
# The MAE: 965.2
# The standard deviation of absolute error: 1057.1
# The MAPE: 0.0%
# The RMSE: 1429.7
# The accuracy(3000): 94.9%
# ----------------------------------------------------------------------------------------------------
# The <<21>> Window
# The training time(s): 1.312993049621582
# The forecast copper price for the second week: [[45974.87109375], [46006.984375], [46299.89453125], [46325.41015625]]
# <<Performance measurement>>
# The MAE: 987.0
# The standard deviation of absolute error: 1063.7
# The MAPE: 0.0%
# The RMSE: 1449.3
# The accuracy(3000): 95.4%
# ----------------------------------------------------------------------------------------------------
# The <<22>> Window
# The training time(s): 1.2938613891601562
# The forecast copper price for the second week: [[47542.28125], [47765.03515625], [47232.14453125], [46748.60546875]]
# <<Performance measurement>>
# The MAE: 1003.6
# The standard deviation of absolute error: 1082.7
# The MAPE: 0.0%
# The RMSE: 1474.5
# The accuracy(3000): 94.9%
# ----------------------------------------------------------------------------------------------------
# The <<23>> Window
# The training time(s): 1.3441879749298096
# The forecast copper price for the second week: [[47543.9921875], [48701.66015625], [49445.2734375], [48298.17578125]]
# <<Performance measurement>>
# The MAE: 1026.6
# The standard deviation of absolute error: 1087.3
# The MAPE: 0.0%
# The RMSE: 1493.5
# The accuracy(3000): 94.9%
# ----------------------------------------------------------------------------------------------------
# The <<24>> Window
# The training time(s): 1.3073174953460693
# The forecast copper price for the second week: [[48395.96875], [48104.09375], [49284.35546875], [50818.33203125]]
# <<Performance measurement>>
# The MAE: 1076.0
# The standard deviation of absolute error: 1146.3
# The MAPE: 0.0%
# The RMSE: 1570.2
# The accuracy(3000): 93.5%
# ----------------------------------------------------------------------------------------------------
# The <<25>> Window
# The training time(s): 1.289323329925537
# The forecast copper price for the second week: [[53808.5], [54772.60546875], [53370.8828125], [51982.84375]]
# <<Performance measurement>>
# The MAE: 1066.9
# The standard deviation of absolute error: 1019.7
# The MAPE: 0.0%
# The RMSE: 1474.2
# The accuracy(3000): 95.4%
# ----------------------------------------------------------------------------------------------------
# The <<26>> Window
# The training time(s): 1.279792308807373
# The forecast copper price for the second week: [[52309.671875], [52531.9609375], [51885.5390625], [51535.03515625]]
# <<Performance measurement>>
# The MAE: 1066.5
# The standard deviation of absolute error: 991.9
# The MAPE: 0.0%
# The RMSE: 1454.9
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<27>> Window
# The training time(s): 1.3495604991912842
# The forecast copper price for the second week: [[51622.1796875], [52426.859375], [52761.63671875], [52891.11328125]]
# <<Performance measurement>>
# The MAE: 1073.5
# The standard deviation of absolute error: 991.0
# The MAPE: 0.0%
# The RMSE: 1459.4
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<28>> Window
# The training time(s): 1.3326694965362549
# The forecast copper price for the second week: [[53776.015625], [53848.81640625], [53787.16796875], [53613.81640625]]
# <<Performance measurement>>
# The MAE: 1081.0
# The standard deviation of absolute error: 964.5
# The MAPE: 0.0%
# The RMSE: 1447.3
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<29>> Window
# The training time(s): 10.866770029067993
# The forecast copper price for the second week: [[53544.578125], [53721.97265625], [54797.5390625], [54951.07421875]]
# <<Performance measurement>>
# The MAE: 1100.1
# The standard deviation of absolute error: 980.1
# The MAPE: 0.0%
# The RMSE: 1471.8
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<30>> Window
# The training time(s): 20.381729125976562
# The forecast copper price for the second week: [[55200.953125], [55113.69140625], [53848.41015625], [51875.6953125]]
# <<Performance measurement>>
# The MAE: 1125.5
# The standard deviation of absolute error: 962.5
# The MAPE: 0.0%
# The RMSE: 1479.5
# The accuracy(3000): 94.9%
# ----------------------------------------------------------------------------------------------------
# The <<31>> Window
# The training time(s): 31.142607927322388
# The forecast copper price for the second week: [[51680.51171875], [52118.375], [52560.91015625], [52453.39453125]]
# <<Performance measurement>>
# The MAE: 1082.2
# The standard deviation of absolute error: 907.3
# The MAPE: 0.0%
# The RMSE: 1410.8
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<32>> Window
# The training time(s): 28.632261276245117
# The forecast copper price for the second week: [[51715.14453125], [52003.4140625], [51448.6875], [51003.03515625]]
# <<Performance measurement>>
# The MAE: 1074.8
# The standard deviation of absolute error: 899.0
# The MAPE: 0.0%
# The RMSE: 1399.9
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<33>> Window
# The training time(s): 28.685700178146362
# The forecast copper price for the second week: [[50580.95703125], [51318.0], [51638.99609375], [50746.12890625]]
# <<Performance measurement>>
# The MAE: 1076.0
# The standard deviation of absolute error: 897.9
# The MAPE: 0.0%
# The RMSE: 1400.1
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<34>> Window
# The training time(s): 28.53654456138611
# The forecast copper price for the second week: [[50386.21875], [49493.35546875], [48376.10546875], [48462.5859375]]
# <<Performance measurement>>
# The MAE: 1088.2
# The standard deviation of absolute error: 889.2
# The MAPE: 0.0%
# The RMSE: 1404.0
# The accuracy(3000): 95.4%
# ----------------------------------------------------------------------------------------------------
# The <<35>> Window
# The training time(s): 28.690458297729492
# The forecast copper price for the second week: [[49268.31640625], [49269.875], [49197.41796875], [49184.94921875]]
# <<Performance measurement>>
# The MAE: 1069.4
# The standard deviation of absolute error: 889.5
# The MAPE: 0.0%
# The RMSE: 1389.7
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<36>> Window
# The training time(s): 28.40875244140625
# The forecast copper price for the second week: [[49392.29296875], [49319.05859375], [48021.0546875], [48435.54296875]]
# <<Performance measurement>>
# The MAE: 1085.6
# The standard deviation of absolute error: 884.9
# The MAPE: 0.0%
# The RMSE: 1399.3
# The accuracy(3000): 95.8%
# ----------------------------------------------------------------------------------------------------
# The <<37>> Window
# The training time(s): 28.51829195022583
# The forecast copper price for the second week: [[49451.54296875], [49823.1796875], [49492.8359375], [49895.63671875]]
# <<Performance measurement>>
# The MAE: 1089.9
# The standard deviation of absolute error: 881.9
# The MAPE: 0.0%
# The RMSE: 1400.7
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<38>> Window
# The training time(s): 28.615111827850342
# The forecast copper price for the second week: [[50504.95703125], [50444.96484375], [49690.00390625], [50118.515625]]
# <<Performance measurement>>
# The MAE: 1094.5
# The standard deviation of absolute error: 878.8
# The MAPE: 0.0%
# The RMSE: 1402.3
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<39>> Window
# The training time(s): 28.567532300949097
# The forecast copper price for the second week: [[49599.65625], [49621.47265625], [49397.0859375], [49585.6328125]]
# <<Performance measurement>>
# The MAE: 1080.1
# The standard deviation of absolute error: 889.9
# The MAPE: 0.0%
# The RMSE: 1398.2
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<40>> Window
# The training time(s): 28.6042423248291
# The forecast copper price for the second week: [[49743.109375], [48911.796875], [48835.44140625], [48348.49609375]]
# <<Performance measurement>>
# The MAE: 1087.8
# The standard deviation of absolute error: 882.4
# The MAPE: 0.0%
# The RMSE: 1399.4
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<41>> Window
# The training time(s): 28.735069036483765
# The forecast copper price for the second week: [[47899.89453125], [47675.5078125], [47686.41796875], [48087.66015625]]
# <<Performance measurement>>
# The MAE: 1075.4
# The standard deviation of absolute error: 884.1
# The MAPE: 0.0%
# The RMSE: 1390.9
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<42>> Window
# The training time(s): 28.60761857032776
# The forecast copper price for the second week: [[48111.09375], [48562.203125], [49328.84765625], [50068.2265625]]
# <<Performance measurement>>
# The MAE: 1065.4
# The standard deviation of absolute error: 870.2
# The MAPE: 0.0%
# The RMSE: 1374.3
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<43>> Window
# The training time(s): 28.730615377426147
# The forecast copper price for the second week: [[49649.109375], [49648.328125], [49918.6796875], [49332.7890625]]
# <<Performance measurement>>
# The MAE: 1053.9
# The standard deviation of absolute error: 865.2
# The MAPE: 0.0%
# The RMSE: 1362.3
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<44>> Window
# The training time(s): 28.70566964149475
# The forecast copper price for the second week: [[49537.8046875], [49638.3125], [49894.640625], [49902.4296875]]
# <<Performance measurement>>
# The MAE: 1060.8
# The standard deviation of absolute error: 860.3
# The MAPE: 0.0%
# The RMSE: 1364.5
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<45>> Window
# The training time(s): 28.688064336776733
# The forecast copper price for the second week: [[49692.109375], [49025.96875], [48678.484375], [48571.7421875]]
# <<Performance measurement>>
# The MAE: 1076.4
# The standard deviation of absolute error: 867.1
# The MAPE: 0.0%
# The RMSE: 1381.0
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<46>> Window
# The training time(s): 28.98201847076416
# The forecast copper price for the second week: [[48060.88671875], [48089.71484375], [48151.26171875], [48090.4921875]]
# <<Performance measurement>>
# The MAE: 1036.1
# The standard deviation of absolute error: 840.1
# The MAPE: 0.0%
# The RMSE: 1332.7
# The accuracy(3000): 96.8%
# ----------------------------------------------------------------------------------------------------
# The <<47>> Window
# The training time(s): 28.47888207435608
# The forecast copper price for the second week: [[48653.07421875], [48395.1875], [48024.328125], [49163.39453125]]
# <<Performance measurement>>
# The MAE: 1048.9
# The standard deviation of absolute error: 845.3
# The MAPE: 0.0%
# The RMSE: 1345.9
# The accuracy(3000): 96.8%
# ----------------------------------------------------------------------------------------------------
# The <<48>> Window
# The training time(s): 28.97661566734314
# The forecast copper price for the second week: [[48375.4296875], [47885.3671875], [47160.79296875], [46762.66796875]]
# <<Performance measurement>>
# The MAE: 1042.0
# The standard deviation of absolute error: 817.7
# The MAPE: 0.0%
# The RMSE: 1323.4
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<49>> Window
# The training time(s): 28.70629119873047
# The forecast copper price for the second week: [[46634.1484375], [46901.38671875], [46992.54296875], [47378.984375]]
# <<Performance measurement>>
# The MAE: 1030.7
# The standard deviation of absolute error: 822.4
# The MAPE: 0.0%
# The RMSE: 1317.4
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<50>> Window
# The training time(s): 28.772677659988403
# The forecast copper price for the second week: [[47485.72265625], [46856.9765625], [46860.87109375], [46768.15625]]
# <<Performance measurement>>
# The MAE: 994.5
# The standard deviation of absolute error: 810.0
# The MAPE: 0.0%
# The RMSE: 1281.4
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<51>> Window
# The training time(s): 28.787047624588013
# The forecast copper price for the second week: [[46496.19921875], [47096.1171875], [47221.5546875], [47587.73828125]]
# <<Performance measurement>>
# The MAE: 947.6
# The standard deviation of absolute error: 759.2
# The MAPE: 0.0%
# The RMSE: 1213.1
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<52>> Window
# The training time(s): 28.703066110610962
# The forecast copper price for the second week: [[47294.7890625], [47189.609375], [47044.6953125], [46034.18359375]]
# <<Performance measurement>>
# The MAE: 923.8
# The standard deviation of absolute error: 747.2
# The MAPE: 0.0%
# The RMSE: 1187.1
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<53>> Window
# The training time(s): 28.493345022201538
# The forecast copper price for the second week: [[46769.66796875], [46421.40234375], [46951.19921875], [46874.84765625]]
# <<Performance measurement>>
# The MAE: 936.4
# The standard deviation of absolute error: 759.0
# The MAPE: 0.0%
# The RMSE: 1204.2
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<54>> Window
# The training time(s): 28.881839275360107
# The forecast copper price for the second week: [[47419.10546875], [47694.9140625], [47428.45703125], [45978.5234375]]
# <<Performance measurement>>
# The MAE: 924.2
# The standard deviation of absolute error: 741.3
# The MAPE: 0.0%
# The RMSE: 1183.7
# The accuracy(3000): 98.6%
# ----------------------------------------------------------------------------------------------------
# The <<55>> Window
# The training time(s): 28.631842851638794
# The forecast copper price for the second week: [[44910.34765625], [45413.65625], [45384.05078125], [45200.95703125]]
# <<Performance measurement>>
# The MAE: 907.4
# The standard deviation of absolute error: 746.0
# The MAPE: 0.0%
# The RMSE: 1173.6
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<56>> Window
# The training time(s): 28.61771273612976
# The forecast copper price for the second week: [[44575.328125], [43560.921875], [41415.2421875], [40038.9375]]
# <<Performance measurement>>
# The MAE: 936.4
# The standard deviation of absolute error: 829.5
# The MAPE: 0.0%
# The RMSE: 1249.7
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<57>> Window
# The training time(s): 28.603453397750854
# The forecast copper price for the second week: [[40584.33203125], [41111.109375], [42664.37109375], [42312.79296875]]
# <<Performance measurement>>
# The MAE: 933.6
# The standard deviation of absolute error: 821.2
# The MAPE: 0.0%
# The RMSE: 1242.1
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<58>> Window
# The training time(s): 28.538193464279175
# The forecast copper price for the second week: [[42894.21484375], [43032.3125], [42948.55859375], [43596.78125]]
# <<Performance measurement>>
# The MAE: 943.3
# The standard deviation of absolute error: 818.0
# The MAPE: 0.0%
# The RMSE: 1247.4
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<59>> Window
# The training time(s): 28.82624840736389
# The forecast copper price for the second week: [[43945.87890625], [44800.5703125], [46369.703125], [46795.1015625]]
# <<Performance measurement>>
# The MAE: 963.3
# The standard deviation of absolute error: 838.9
# The MAPE: 0.0%
# The RMSE: 1276.1
# The accuracy(3000): 97.2%
# ----------------------------------------------------------------------------------------------------
# The <<60>> Window
# The training time(s): 28.716827630996704
# The forecast copper price for the second week: [[48369.26171875], [48828.16015625], [48915.421875], [50162.78125]]
# <<Performance measurement>>
# The MAE: 965.6
# The standard deviation of absolute error: 859.0
# The MAPE: 0.0%
# The RMSE: 1291.1
# The accuracy(3000): 96.3%
# ----------------------------------------------------------------------------------------------------
# The <<61>> Window
# The training time(s): 28.876712560653687
# The forecast copper price for the second week: [[50375.15234375], [50349.44140625], [50112.59375], [50028.44921875]]
# <<Performance measurement>>
# The MAE: 949.8
# The standard deviation of absolute error: 826.1
# The MAPE: 0.0%
# The RMSE: 1257.6
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<62>> Window
# The training time(s): 28.83263063430786
# The forecast copper price for the second week: [[52192.93359375], [52065.16015625], [51711.44140625], [51875.0546875]]
# <<Performance measurement>>
# The MAE: 928.4
# The standard deviation of absolute error: 822.4
# The MAPE: 0.0%
# The RMSE: 1239.0
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<63>> Window
# The training time(s): 28.581433296203613
# The forecast copper price for the second week: [[51837.6953125], [51513.58203125], [50905.875], [51184.796875]]
# <<Performance measurement>>
# The MAE: 925.2
# The standard deviation of absolute error: 816.4
# The MAPE: 0.0%
# The RMSE: 1232.7
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<64>> Window
# The training time(s): 28.587556838989258
# The forecast copper price for the second week: [[50951.0703125], [51136.5], [50665.91796875], [50508.53515625]]
# <<Performance measurement>>
# The MAE: 941.5
# The standard deviation of absolute error: 820.5
# The MAPE: 0.0%
# The RMSE: 1247.6
# The accuracy(3000): 98.1%
# ----------------------------------------------------------------------------------------------------
# The <<65>> Window
# The training time(s): 28.731358766555786
# The forecast copper price for the second week: [[50748.484375], [51335.9375], [52219.453125], [53864.94140625]]
# <<Performance measurement>>
# The MAE: 986.5
# The standard deviation of absolute error: 896.8
# The MAPE: 0.0%
# The RMSE: 1331.8
# The accuracy(3000): 96.7%
# ----------------------------------------------------------------------------------------------------
